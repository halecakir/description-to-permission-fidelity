# %%
import sys
import os
import csv
import random

import pickle
import scipy
import pandas as pd
import numpy as np

seed = 10

import dynet_config

# Declare GPU as the default device type
dynet_config.set_gpu()
# Set some parameters manualy
dynet_config.set(mem=400, random_seed=seed)
# Initialize dynet import using above configuration in the current scope
import dynet as dy


from utils.io_utils import IOUtils
from utils.nlp_utils import NLPUtils

from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.model_selection import KFold

random.seed(seed)
np.random.seed(seed)

# %%
class Data:
    def __init__(self):
        self.w2i = None
        self.entries = None
        self.train_entries = None
        self.test_entries = None
        self.ext_embedding = None
        self.reviews = None
        self.predicted_reviews = None

    def to(self, device):
        if self.entries:
            for entry in self.entries:
                entry.index_tensor = entry.index_tensor.to(device=device)
        if self.reviews:
            for doc_id in self.reviews:
                for review in self.reviews[doc_id]:
                    review.index_tensor = review.index_tensor.to(device=device)
        if self.predicted_reviews:
            for doc_id in self.predicted_reviews:
                for review in self.predicted_reviews[doc_id]:
                    review.index_tensor = review.index_tensor.to(device=device)

    def load(self, infile):
        with open(infile, "rb") as target:
            self.ext_embeddings, self.entries, self.w2i = pickle.load(target)

    def save_data(self, infile):
        with open(infile, "rb") as target:
            self.ext_embeddings, self.entries, self.w2i = pickle.dump(target)

    def load_predicted_reviews(self, infile):
        with open(infile, "rb") as target:
            self.predicted_reviews = pickle.load(target)
        for app_id in self.predicted_reviews.keys():
            self.predicted_reviews[app_id].sort(
                key=lambda x: x.prediction_result.item(), reverse=True
            )

    def load_reviews(self, infile):
        with open(infile, "rb") as target:
            self.reviews = pickle.load(target)


class Model:
    def __init__(self, data, opt):
        self.opt = opt
        self.model = dy.ParameterCollection()
        self.trainer = dy.MomentumSGDTrainer(self.model)
        self.w2i = data.w2i
        self.wdims = opt.embedding_size
        self.ldims = opt.hidden_size
        self.attsize = opt.attention_size

        self.ext_embeddings = data.ext_embeddings
        # Model Parameters
        self.wlookup = self.model.add_lookup_parameters((len(self.w2i), self.wdims))

        self.__load_external_embeddings()

        if self.opt.encoder_dir == "single":
            if self.opt.encoder_type == "lstm":
                self.sentence_rnn = [
                    dy.VanillaLSTMBuilder(1, self.wdims, self.ldims, self.model)
                ]
            elif self.opt.encoder_type == "gru":
                self.sentence_rnn = [
                    dy.GRUBuilder(1, self.wdims, self.ldims, self.model)
                ]
            self.attention_w = self.model.add_parameters((self.attsize, self.ldims))
            self.attention_b = self.model.add_parameters(self.attsize)
            self.att_context = self.model.add_parameters(self.attsize)
            self.mlp_w = self.model.add_parameters((1, self.ldims + 2 * self.ldims))
            self.mlp_b = self.model.add_parameters(1)
        elif self.opt.encoder_dir == "bidirectional":
            if self.opt.encoder_type == "lstm":
                self.sentence_rnn = [
                    dy.VanillaLSTMBuilder(1, self.wdims, self.ldims, self.model),
                    dy.VanillaLSTMBuilder(1, self.wdims, self.ldims, self.model),
                ]
            elif self.opt.encoder_type == "gru":
                self.sentence_rnn = [
                    dy.GRUBuilder(1, self.wdims, self.ldims, self.model),
                    dy.GRUBuilder(1, self.wdims, self.ldims, self.model),
                ]

            self.attention_w = self.model.add_parameters((self.attsize, 2 * self.ldims))
            self.attention_b = self.model.add_parameters(self.attsize)
            self.att_context = self.model.add_parameters(self.attsize)
            self.mlp_w = self.model.add_parameters((1, 2 * self.ldims + 4 * self.ldims))
            self.mlp_b = self.model.add_parameters(1)
            

    def __load_external_embeddings(self):
        print("Initializing word embeddings by pre-trained vectors")
        count = 0
        for word in self.w2i:
            if word in self.ext_embeddings:
                count += 1
                self.wlookup.init_row(self.w2i[word], self.ext_embeddings[word])
        print(
            "Vocab size: %d; #words having pretrained vectors: %d"
            % (len(self.w2i), count)
        )

    def save(self):
        self.model.save(self.opt.model_checkpoint)

    def load(self):
        self.model.populate(self.opt.model_checkpoint)

def write_file(filename, string):
    with open(filename, "a") as target:
        target.write("{}\n".format(string))
        target.flush()


def encode_sequence(model, seq, rnn_builder):
    def predict_sequence(builder, inputs):
        s_init = builder.initial_state()
        return s_init.transduce(inputs)

    if model.opt.encoder_dir == "bidirectional":
        f_in = [entry for entry in seq]
        b_in = [rentry for rentry in reversed(seq)]
        forward_sequence = predict_sequence(rnn_builder[0], f_in)
        backward_sequence = predict_sequence(rnn_builder[1], b_in)
        return [
            dy.concatenate([s1, s2])
            for s1, s2 in zip(forward_sequence, backward_sequence)
        ]
    elif model.opt.encoder_dir == "single":
        f_in = [entry for entry in seq]
        state = rnn_builder[0].initial_state()
        states = []
        for entry in seq:
            state = state.add_input(entry)
            states.append(state.output())
        return states


def max_pooling(encoded_sequence):
    values = np.array([encoding.value() for encoding in encoded_sequence])
    min_indexes = np.argmax(values, axis=0)
    pooled_context = dy.concatenate(
        [encoded_sequence[row][col] for col, row in enumerate(min_indexes)]
    )
    return pooled_context


def min_pooling(encoded_sequence):
    values = np.array([encoding.value() for encoding in encoded_sequence])
    min_indexes = np.argmin(values, axis=0)
    pooled_context = dy.concatenate(
        [encoded_sequence[row][col] for col, row in enumerate(min_indexes)]
    )
    return pooled_context


def average_pooling(encoded_sequence):
    averages = []
    for col in range(encoded_sequence[0].dim()[0][0]):
        avg = []
        for row in range(len(encoded_sequence)):
            avg.append(encoded_sequence[row][col])
        averages.append(dy.average(avg))
    return dy.concatenate(averages)


def train_item(args, model, sentence):
    loss = None
    seq = [
        model.wlookup[int(model.w2i.get(entry, 0))]
        for entry in sentence.preprocessed_sentence
    ]
    if len(seq) > 0:
        encoded_sequence = encode_sequence(model, seq, model.sentence_rnn)
        global_max = max_pooling(encoded_sequence)
        global_min = average_pooling(encoded_sequence)
        if len(encoded_sequence) > 0:
            att_mlp_outputs = []
            for e in encoded_sequence:
                mlp_out = (model.attention_w * e) + model.attention_b
                att_mlp_outputs.append(mlp_out)

            lst = []
            for o in att_mlp_outputs:
                lst.append(dy.exp(dy.sum_elems(dy.cmult(o, model.att_context))))

            sum_all = dy.esum(lst)

            probs = [dy.cdiv(e, sum_all) for e in lst]
            att_context = dy.esum(
                [dy.cmult(p, h) for p, h in zip(probs, encoded_sequence)]
            )
            context = dy.concatenate([att_context, global_max, global_min])
            #context = dy.concatenate([att_context])
            y_pred = dy.logistic((model.mlp_w * context) + model.mlp_b)

            if sentence.permissions[args.permission_type]:
                loss = dy.binary_log_loss(y_pred, dy.scalarInput(1))
            else:
                loss = dy.binary_log_loss(y_pred, dy.scalarInput(0))

            loss.backward()
            model.trainer.update()
            loss_val = loss.scalar_value()
            dy.renew_cg()
            return loss_val
    return 0


def test_item(model, sentence):
    seq = [
        model.wlookup[int(model.w2i.get(entry, 0))]
        for entry in sentence.preprocessed_sentence
    ]
    if len(seq) > 0:
        encoded_sequence = encode_sequence(model, seq, model.sentence_rnn)
        global_max = max_pooling(encoded_sequence)
        global_min = average_pooling(encoded_sequence)
        if len(encoded_sequence) > 0:
            att_mlp_outputs = []
            for e in encoded_sequence:
                mlp_out = (model.attention_w * e) + model.attention_b
                att_mlp_outputs.append(mlp_out)

            lst = []
            for o in att_mlp_outputs:
                lst.append(dy.exp(dy.sum_elems(dy.cmult(o, model.att_context))))

            sum_all = dy.esum(lst)

            probs = [dy.cdiv(e, sum_all) for e in lst]
            att_context = dy.esum(
                [dy.cmult(p, h) for p, h in zip(probs, encoded_sequence)]
            )
            context = dy.concatenate([att_context, global_max, global_min])
            #context = dy.concatenate([att_context])
            y_pred = dy.logistic((model.mlp_w * context) + model.mlp_b)
            sentence.prediction_result = y_pred.scalar_value()
            dy.renew_cg()
            return sentence.prediction_result
    return 0

def show_attention_weights(model, sentence):
    seq = [
        model.wlookup[int(model.w2i.get(entry, 0))]
        for entry in sentence.preprocessed_sentence
    ]
    if len(seq) > 0:
        encoded_sequence = encode_sequence(model, seq, model.sentence_rnn)
        if len(encoded_sequence) > 0:
            att_mlp_outputs = []
            for e in encoded_sequence:
                mlp_out = (model.attention_w * e) + model.attention_b
                att_mlp_outputs.append(mlp_out)

            lst = []
            for o in att_mlp_outputs:
                lst.append(dy.exp(dy.sum_elems(dy.cmult(o, model.att_context))))

            sum_all = dy.esum(lst)
            probs = [dy.cdiv(e, sum_all).scalar_value() for e in lst]
            return probs


def train_all(args, model, data):
    write_file(args.outdir, "Training...")
    losses = []
    for index, sentence in enumerate(data.train_entries):
        loss = train_item(args, model, sentence)
        if index != 0:
            if index % model.opt.print_every == 0:
                write_file(
                    args.outdir,
                    "Index {} Loss {}".format(
                        index, np.mean(losses[index - model.opt.print_every :])
                    ),
                )
        losses.append(loss)


def test_all(args, model, data):
    def pr_roc_auc(predictions, gold):
        y_true = np.array(gold)
        y_scores = np.array(predictions)
        roc_auc = roc_auc_score(y_true, y_scores)
        pr_auc = average_precision_score(y_true, y_scores)
        return roc_auc, pr_auc

    write_file(args.outdir, "Predicting..")

    predictions, gold = [], []
    for index, sentence in enumerate(data.test_entries):
        pred = test_item(model, sentence)
        predictions.append(pred)
        gold.append(sentence.permissions[args.permission_type])
    return pr_roc_auc(predictions, gold)


def kfold_validation(args, data):
    data.entries = np.array(data.entries)
    random.shuffle(data.entries)

    kfold = KFold(n_splits=10, shuffle=True, random_state=seed)
    roc_l, pr_l = [], []
    for foldid, (train, test) in enumerate(kfold.split(data.entries)):
        write_file(args.outdir, "Fold {}".format(foldid + 1))

        model = Model(data, args)
        data.train_entries = data.entries[train]
        data.test_entries = data.entries[test]
        max_roc_auc, max_pr_auc = 0, 0
        for epoch in range(args.num_epoch):
            train_all(args, model, data)
            roc_auc, pr_auc = test_all(args, model, data)
            if pr_auc > max_pr_auc:
                max_pr_auc = pr_auc
                max_roc_auc = roc_auc
            write_file(
                args.outdir, "Epoch {} ROC {}  PR {}".format(epoch + 1, roc_auc, pr_auc)
            )
        model.save()
        write_file(args.outdir, "ROC {} PR {}".format(max_roc_auc, max_pr_auc))
        roc_l.append(max_roc_auc)
        pr_l.append(max_pr_auc)
    write_file(
        args.outdir, "Summary : ROC {} PR {}".format(np.mean(roc_l), np.mean(pr_l))
    )

# %%
class Arguments:
    permission_type = "READ_CONTACTS"
    saved_data = "/Users/huseyinalecakir/huseyin/Work/Security/datasets/saved-parameters/saved-data/ac-net/embeddings-sentences-w2i.pickle"
    outdir = "output.txt"
    stemmer = "porter"
    embedding_size = 300
    hidden_size = 128
    attention_size = 128
    output_size = 1
    print_every = 1000
    encoder_dir = "bidirectional"
    encoder_type = "gru"
    num_epoch = 1

# %%
args = Arguments()

# %%
data = Data()
data.load(args.saved_data)

# %%
"""data.entries = np.array(data.entries)
random.shuffle(data.entries)
from sklearn.model_selection import train_test_split
data.train_entries, data.test_entries = train_test_split(data.entries, test_size=0.10, random_state=5)"""

# %%
def load_train_test(infile):
    with open(infile, "rb") as target:
        data.entries, data.train_entries, data.test_entries = pickle.load(target)

def save_train_test(infile):
    with open(infile, "wb") as target:
        pickle.dump([data.entries, data.train_entries, data.test_entries], target)

# %%
#save_train_test("porter_train_test.pickle")
load_train_test("porter_train_test.pickle")

# %%
model = Model(data, args)
train_all(args, model, data)
roc_auc, pr_auc = test_all(args, model, data)
print(roc_auc, pr_auc)
# Out:
# Initializing word embeddings by pre-trained vectors
# Vocab size: 34941; #words having pretrained vectors: 34941
# 0.966919684812 0.706330492421

# %%
"""for entry in data.test_entries:
    if type(entry.prediction_result) != float:
        entry.prediction_result = 0"""

# %%
positives = [entry for entry in data.test_entries if entry.permissions["READ_CONTACTS"]==1]
negatives = [entry for entry in data.test_entries if entry.permissions["READ_CONTACTS"]==0]

sorted_positives = sorted(positives, key=lambda x: x.prediction_result, reverse=True)
sorted_negatives = sorted(negatives, key=lambda x: x.prediction_result, reverse=True)
threshold = 0.50
TP = sum([1 for entry in sorted_positives if entry.prediction_result >= threshold])
FN = sum([1 for entry in sorted_positives if entry.prediction_result < threshold])
TN = sum([1 for entry in sorted_negatives if entry.prediction_result < threshold])
FP = sum([1 for entry in sorted_negatives if entry.prediction_result >= threshold])

precision = TP/(TP+FP)
recall = TP/(TP+FN)
acc = (TN+TP)/(TN+FP+TP+FN)
fmeasure = (2 * precision * recall) / (precision + recall)


print("TP:{} - FN:{} - TN:{} - FP:{}".format(TP, FN, TN, FP))
print("Precision:{} - Recall:{}".format(precision, recall))
print("Accuracy:{}".format(acc))
print("F-measuse:{}".format(fmeasure))
# Out:
# TP:68 - FN:19 - TN:2332 - FP:53
# Precision:0.5619834710743802 - Recall:0.7816091954022989
# Accuracy:0.970873786407767
# F-measuse:0.6538461538461539

# %%
with open("attention_pooling_porter_statement_sentences.txt", "w") as target:
    neg_keys = {}
    for idx, entry in enumerate(sorted_negatives):
        if entry.prediction_result > 0:
            weights = show_attention_weights(model, entry)
            max_index = weights.index(max(weights))
            mit = entry.preprocessed_sentence[max_index] #most_important_token
            neg_keys[mit] = neg_keys[mit]+1 if mit in neg_keys else 1
            pairs = [(t,w)for t,w in zip(entry.preprocessed_sentence,weights)]
            target.write("{}\t{}\t{}\n".format(idx+1, entry.sentence, entry.prediction_result))
            #target.write("{}\n".format(str(entry.prediction_result)).replace(".", ","))
            print("{}::{}::{}\n".format(idx+1, entry.sentence, entry.prediction_result))
            for t,w in pairs:
                print("{}:{}".format(t,w))
                target.write("{0}:{1:.2f} ".format(t,w))
                print()
            target.write("\n")
    sorted_lst = sorted(neg_keys.items(), key=lambda kv: kv[1], reverse=True)
    target.write("KEYWORDS\n")
    for key, value in sorted_lst:
        target.write("{}:{}\n".format(key, value))
# Out:
# 1::Cloud backup through Dropbox and Google Drive::0.997931957244873
#
# cloud:0.7007781863212585
#
# backup:0.18211182951927185
#
# dropbox:0.029133319854736328
#
# googl:0.008050402626395226
#
# drive:0.07992634922266006
#
# 2::Block numbers from those you dont want to be able to contact you::0.9739790558815002
#
# block:0.719104528427124
#
# number:0.08201198279857635
#
# dont:0.05332046374678612
#
# want:0.11093131452798843
#
# abl:0.02472548373043537
#
# contact:0.009906229563057423
#
# 3::droid website: Twitter account: Steam Group: Google+ Beta Community (go here for beta access): osu::0.9520052075386047
#
# droid:0.5379595160484314
#
# websit:0.09138426929712296
#
# twitter:0.0808398500084877
#
# account:0.017151808366179466
#
# steam:0.027015291154384613
#
# group:0.030894270166754723
#
# googl:0.009797881357371807
#
# beta:0.022650862112641335
#
# commun:0.022624554112553596
#
# go:0.040931712836027145
#
# beta:0.05060546100139618
#
# access:0.02780371718108654
#
# osu:0.04034082591533661
#
# 4::Find apps that can access to your personal information(GPS location#read contact data::0.947903037071228
#
# find:0.07322757691144943
#
# app:0.7785128355026245
#
# access:0.08476860821247101
#
# person:0.016358867287635803
#
# inform:0.007116067688912153
#
# gp:0.009547657333314419
#
# locat:0.004642179701477289
#
# read:0.005133910570293665
#
# contact:0.009012691676616669
#
# data:0.011679435148835182
#
# 5::Use of this application requires a Facebook or Zynga With Friends account::0.940576434135437
#
# use:0.41366392374038696
#
# applic:0.1374557763338089
#
# requir:0.21235422790050507
#
# facebook:0.09635258466005325
#
# zynga:0.09458209574222565
#
# friend:0.03677961230278015
#
# account:0.008811725303530693
#
# 6::Gmail blocks spam before it hits your inbox to keep your account safe and clutter free 15GB of free storage::0.935869574546814
#
# gmail:0.1435011923313141
#
# block:0.11180972307920456
#
# spam:0.09024719148874283
#
# hit:0.17620615661144257
#
# inbox:0.04805757477879524
#
# keep:0.07665558904409409
#
# account:0.026215460151433945
#
# safe:0.039305079728364944
#
# clutter:0.05475027114152908
#
# free:0.11408289521932602
#
# free:0.08552136272192001
#
# storag:0.033647436648607254
#
# 7::New Slot machine games added EVERY WEEK Free coins bonus every 4 hours and the WHEEL OF FUN the best way to get a bigger slots bonus Progressive jackpots and the exciting bonus rounds Weekly promotions# Happy Hours# sales and gifts One of the biggest online slots communities where you can get even more free coins Facebook connect and invite your friends and receive even more slots bonuses Personalized service delivered by the best support team in the industry Dedicated personal account managers for our VIP players Follow House of Fun on Facebook and Twitter for exclusive offers and bonuses | fun slots has never been easier::0.9240785837173462
#
# new:0.13743485510349274
#
# slot:0.060622360557317734
#
# machin:0.035374965518713
#
# game:0.02385944314301014
#
# ad:0.01449278462678194
#
# everi:0.01073320209980011
#
# week:0.01019228808581829
#
# free:0.012879019603133202
#
# coin:0.010938321240246296
#
# bonu:0.013679968193173409
#
# everi:0.022549331188201904
#
# hour:0.021736953407526016
#
# wheel:0.01482904888689518
#
# fun:0.02168910950422287
#
# best:0.006564329378306866
#
# way:0.006077566649764776
#
# get:0.0031980029307305813
#
# bigger:0.0147297577932477
#
# slot:0.01980065554380417
#
# bonu:0.038217492401599884
#
# progress:0.02359749563038349
#
# jackpot:0.016152191907167435
#
# excit:0.01234380528330803
#
# bonu:0.009877408854663372
#
# round:0.0027941532898694277
#
# weekli:0.0026058510411530733
#
# promot:0.004197896458208561
#
# happi:0.007053332403302193
#
# hour:0.0057863881811499596
#
# sale:0.003107141237705946
#
# gift:0.0024021384306252003
#
# one:0.01720806024968624
#
# biggest:0.02553986757993698
#
# onlin:0.01528846099972725
#
# slot:0.026730524376034737
#
# commun:0.019248023629188538
#
# get:0.02088060788810253
#
# even:0.030910855159163475
#
# free:0.023742999881505966
#
# coin:0.008084256201982498
#
# facebook:0.007633827161043882
#
# connect:0.004828554578125477
#
# invit:0.0028487849049270153
#
# friend:0.0021984498016536236
#
# receiv:0.003040953306481242
#
# even:0.008976041339337826
#
# slot:0.012039409019052982
#
# bonus:0.00971151702105999
#
# person:0.004628049209713936
#
# servic:0.00401676818728447
#
# deliv:0.00797148235142231
#
# best:0.006412622053176165
#
# support:0.010439579375088215
#
# team:0.008157084695994854
#
# industri:0.008792910724878311
#
# dedic:0.008126810193061829
#
# person:0.004820502828806639
#
# account:0.0017484263516962528
#
# manag:0.0039686160162091255
#
# vip:0.005508861038833857
#
# player:0.006464106030762196
#
# follow:0.008054854348301888
#
# hous:0.007778639905154705
#
# fun:0.0061684404499828815
#
# facebook:0.0020499585662037134
#
# twitter:0.002748259110376239
#
# exclus:0.005221321247518063
#
# offer:0.006452028639614582
#
# bonus:0.008229251019656658
#
# fun:0.013872301205992699
#
# slot:0.01572355255484581
#
# never:0.008694234304130077
#
# easier:0.005523026920855045
#
# 8::Contact specific notifications for certain notification typesIf you've come from a Blackberry device and miss the features of BeBuzz / BerryBuzz then give LightFlow a try::0.9235370755195618
#
# contact:0.38172656297683716
#
# specif:0.21160438656806946
#
# notif:0.07781227678060532
#
# certain:0.04304097592830658
#
# notif:0.005997625179588795
#
# come:0.015241686254739761
#
# blackberri:0.02083093859255314
#
# devic:0.005782052408903837
#
# miss:0.007491525262594223
#
# featur:0.005653233267366886
#
# give:0.011246046982705593
#
# tri:0.21357275545597076
#
# 9::You can send texts# emoticons# pictures# voice messages# and other files to your FreePP contacts 3::0.9224923849105835
#
# send:0.820884108543396
#
# text:0.14774128794670105
#
# emoticon:0.016314158216118813
#
# pictur:0.007273068651556969
#
# voic:0.0025842636823654175
#
# messag:0.0016413371777161956
#
# file:0.001790773356333375
#
# freepp:0.0008794816676527262
#
# contact:0.0008915382786653936
#
# 10::CLOUD SAVING NOW SUPPORTED Share your progress between multiple devices# and unlock the all-new achievements::0.9113296270370483
#
# cloud:0.5355741381645203
#
# save:0.22688810527324677
#
# support:0.10120175778865814
#
# share:0.016609840095043182
#
# progress:0.00704851234331727
#
# multipl:0.021437380462884903
#
# devic:0.005504500586539507
#
# unlock:0.039849184453487396
#
# new:0.017131095752120018
#
# achiev:0.028755398467183113
#
# 11::Cloud Backup: Never lose your secured files and folders ever again::0.9080134630203247
#
# cloud:0.8198133111000061
#
# backup:0.07129134237766266
#
# never:0.013326771557331085
#
# lose:0.02239331603050232
#
# secur:0.0218760147690773
#
# file:0.02100301720201969
#
# folder:0.0033876351080834866
#
# ever:0.02690867707133293
#
# 12::Support (Free) features:Backup and restore to SD cardBackup and restore from PCHelium (Premium) features:No adsAutomatic Backup schedulesAndroid to Android syncCloud backup and restore * Dropbox * Box * Google Driveb>Note: Some Sony devices have issues with Helium::0.9000588655471802
#
# support:0.3124782145023346
#
# free:0.4591871500015259
#
# featur:0.03314293920993805
#
# backup:0.025429828092455864
#
# restor:0.007312100380659103
#
# sd:0.007095164619386196
#
# restor:0.005927728954702616
#
# premium:0.002747461199760437
#
# featur:0.002191224368289113
#
# backup:0.000653473602142185
#
# android:0.005714531987905502
#
# backup:0.0010562542593106627
#
# restor:0.003967653028666973
#
# dropbox:0.00674674054607749
#
# box:0.004224591888487339
#
# googl:0.002109624445438385
#
# note:0.00340716983191669
#
# soni:0.0025454561691731215
#
# devic:0.006577386055141687
#
# issu:0.037176862359046936
#
# helium:0.07030845433473587
#
# 13::Friends of your HeyTell friends who know your phone number or email address can HeyTell you::0.8905094861984253
#
# friend:0.45463278889656067
#
# heytel:0.1712726205587387
#
# friend:0.060246407985687256
#
# know:0.08053086698055267
#
# phone:0.05360432714223862
#
# number:0.05907541885972023
#
# email:0.04720486328005791
#
# address:0.03836899250745773
#
# heytel:0.035063669085502625
#
# 14::BUSINESS INFO Reverse Lookup# Reviews# Menu# Reservation# Street View# Yelp# Map# # white-pages# yellow-pages SHARE TOOLS Contact Details# Location# Photo::0.8811347484588623
#
# busi:0.14094267785549164
#
# info:0.047295231372117996
#
# revers:0.018927764147520065
#
# lookup:0.1537197083234787
#
# review:0.11711858958005905
#
# menu:0.034009408205747604
#
# reserv:0.06674402207136154
#
# street:0.06830628216266632
#
# view:0.053898885846138
#
# yelp:0.0261384304612875
#
# map:0.025943690910935402
#
# white:0.03374119848012924
#
# page:0.015583643689751625
#
# yellow:0.02772611938416958
#
# page:0.03709040954709053
#
# share:0.01647205278277397
#
# tool:0.04500552639365196
#
# contact:0.020422685891389847
#
# detail:0.022988293319940567
#
# locat:0.00721107330173254
#
# photo:0.02071426622569561
#
# 15::Sync Sync your history# bookmarks# and passwords::0.8730064630508423
#
# sync:0.8707906007766724
#
# sync:0.04596342518925667
#
# histori:0.02581607736647129
#
# bookmark:0.04171149432659149
#
# password:0.015718478709459305
#
# 16::Share on Facebook# Twitter and Google+Enjoy::0.8719798922538757
#
# share:0.7387060523033142
#
# facebook:0.087244413793087
#
# twitter:0.08072422444820404
#
# googl:0.06370078027248383
#
# enjoy:0.029624516144394875
#
# 17::Block all numbers (useful when you are sleeping) Turn blacklist off::0.8706696033477783
#
# block:0.7470842003822327
#
# number:0.11309735476970673
#
# use:0.06454889476299286
#
# sleep:0.030750606209039688
#
# turn:0.031727325171232224
#
# blacklist:0.012791590765118599
#
# 18::Share your progress and workouts with friends on social media::0.8677501082420349
#
# share:0.6721312999725342
#
# progress:0.21124888956546783
#
# workout:0.06470836699008942
#
# friend:0.01700715906918049
#
# social:0.023938922211527824
#
# media:0.010965359397232533
#
# 19::Update your account and device details::0.855880081653595
#
# updat:0.8588640093803406
#
# account:0.021206818521022797
#
# devic:0.02804407849907875
#
# detail:0.09188500791788101
#
# 20::Trace location(city and state) of any mobile and landline telephone numbers 4 Block unwanted Calls & SMS::0.8386104106903076
#
# trace:0.21333611011505127
#
# locat:0.11153613775968552
#
# citi:0.11114607751369476
#
# state:0.08762003481388092
#
# mobil:0.11643455177545547
#
# landlin:0.05602839216589928
#
# telephon:0.02540217526257038
#
# number:0.019252780824899673
#
# block:0.04372211918234825
#
# unwant:0.11002105474472046
#
# call:0.04164550080895424
#
# sm:0.06385504454374313
#
# 21::Do you want to customize natural and elegant photo for Facebook#Twitter#LinkedIn#Snapchat#Pinterest#Instagram or other social sites::0.8365539312362671
#
# want:0.47823435068130493
#
# custom:0.16559231281280518
#
# natur:0.09833862632513046
#
# eleg:0.10915229469537735
#
# photo:0.051357656717300415
#
# facebook:0.02009681984782219
#
# twitter:0.024512413889169693
#
# linkedin:0.014068415388464928
#
# snapchat:0.006764698773622513
#
# pinterest:0.005382831674069166
#
# instagram:0.00961717963218689
#
# social:0.007799773011356592
#
# site:0.009082457982003689
#
# 22::Securely connect your personal finance accounts to get reminders & alerts3::0.8336743712425232
#
# secur:0.3585658073425293
#
# connect:0.25896626710891724
#
# person:0.12122058123350143
#
# financ:0.0729759931564331
#
# account:0.01680586114525795
#
# get:0.08123637735843658
#
# remind:0.0902290791273117
#
# 23::Save or Share Bible verse or plan or devotions easily on Facebook# Twitter# email# text etc::0.8233563303947449
#
# save:0.45828044414520264
#
# share:0.08854072540998459
#
# bibl:0.06419187784194946
#
# vers:0.07794149219989777
#
# plan:0.0768953189253807
#
# devot:0.03403952717781067
#
# easili:0.05494809150695801
#
# facebook:0.019167933613061905
#
# twitter:0.02162698656320572
#
# email:0.06964536011219025
#
# text:0.021141206845641136
#
# etc:0.013580970466136932
#
# 24::Backup and restore from Google Drive::0.8123480081558228
#
# backup:0.6982782483100891
#
# restor:0.23062436282634735
#
# googl:0.05770477280020714
#
# drive:0.013392618857324123
#
# 25::Real-Time Alerts: If the app notices any large purchases or unusual charges in your account# youll be notified immediately via real-time push messages & emails Its easy to get started:1 Download the app 2::0.7821435332298279
#
# real:0.4615662395954132
#
# time:0.10143231600522995
#
# alert:0.027663424611091614
#
# app:0.04906480759382248
#
# notic:0.032555341720581055
#
# larg:0.02591066248714924
#
# purchas:0.007504538632929325
#
# unusu:0.023777104914188385
#
# charg:0.02233186550438404
#
# account:0.007743515074253082
#
# youll:0.007590190973132849
#
# notifi:0.0075538139790296555
#
# immedi:0.005524240899831057
#
# via:0.009458206593990326
#
# real:0.017977943643927574
#
# time:0.016583330929279327
#
# push:0.029265068471431732
#
# messag:0.013753296807408333
#
# email:0.017127538099884987
#
# easi:0.028765328228473663
#
# get:0.03102979250252247
#
# start:0.010498830117285252
#
# download:0.017848316580057144
#
# app:0.027474164962768555
#
# 26::Network Communication (Internet Access) is for retrieving currency exchange rate and synchronizing backup data and/or common wallet::0.7807543873786926
#
# network:0.34567946195602417
#
# commun:0.2555012106895447
#
# internet:0.05817161127924919
#
# access:0.0054855612106621265
#
# retriev:0.0057290662080049515
#
# currenc:0.025248119607567787
#
# exchang:0.01801692694425583
#
# rate:0.026730934157967567
#
# synchron:0.012278007343411446
#
# backup:0.011861242353916168
#
# data:0.033555660396814346
#
# common:0.12716172635555267
#
# wallet:0.07458046823740005
#
# 27::Take photos or record videos in the dark or low light environments and share them with your friends on popular social networks like Whatsapp# Instagram# Viber# Tango# BBM# and more::0.7803062200546265
#
# take:0.2784346044063568
#
# photo:0.15408176183700562
#
# record:0.026580877602100372
#
# video:0.03731124848127365
#
# dark:0.021402038633823395
#
# low:0.05251304432749748
#
# light:0.08696267753839493
#
# environ:0.10832159221172333
#
# share:0.07756931334733963
#
# friend:0.025758154690265656
#
# popular:0.012483014725148678
#
# social:0.021275553852319717
#
# network:0.01840660162270069
#
# like:0.019007069990038872
#
# whatsapp:0.03129587695002556
#
# instagram:0.01047046110033989
#
# viber:0.0066089327447116375
#
# tango:0.0034807054325938225
#
# bbm:0.008036468178033829
#
# 28::Conveniently pay bills with a bank account or credit card::0.7769975662231445
#
# conveni:0.6041275858879089
#
# pay:0.23819589614868164
#
# bill:0.08097710460424423
#
# bank:0.04803253337740898
#
# account:0.012319773435592651
#
# credit:0.009695766493678093
#
# card:0.006651358213275671
#
# 29::Keep up with the state of their account without having to log::0.7745043635368347
#
# keep:0.421869695186615
#
# state:0.24780987203121185
#
# account:0.08113183081150055
#
# without:0.13140662014484406
#
# log:0.11778202652931213
#
# 30::Instant Maps: Using built-in GPS# see nearby homes for sale# houses for rent# apartments for rent or recently sold homes# Android Wear optimized: get nearby home alerts# view property details and photos# or contact the realtor all from your watch::0.7707707285881042
#
# instant:0.0985436737537384
#
# map:0.09197797626256943
#
# use:0.45683082938194275
#
# built:0.05501023307442665
#
# gp:0.0233949925750494
#
# see:0.020809469744563103
#
# nearbi:0.003276115283370018
#
# home:0.005483930930495262
#
# sale:0.00743291387334466
#
# hous:0.007552737835794687
#
# rent:0.010750212706625462
#
# apart:0.01257413998246193
#
# rent:0.005601673386991024
#
# recent:0.005505344830453396
#
# sold:0.006822672672569752
#
# home:0.010708046145737171
#
# android:0.010826755315065384
#
# wear:0.012133141048252583
#
# optim:0.0264383964240551
#
# get:0.01437742542475462
#
# nearbi:0.016160357743501663
#
# home:0.021205300465226173
#
# alert:0.017643028870224953
#
# view:0.011169885285198689
#
# properti:0.01076707523316145
#
# detail:0.006657276302576065
#
# photo:0.01007834356278181
#
# contact:0.006995487492531538
#
# realtor:0.005295450799167156
#
# watch:0.00797707587480545
#
# 31::Instantly sync your library across all your devices::0.7552328109741211
#
# instantli:0.48922136425971985
#
# sync:0.1971716284751892
#
# librari:0.2114259898662567
#
# across:0.061282072216272354
#
# devic:0.0408988818526268
#
# 32::Funds are deposited fastsee money in your bank account in one to two business days::0.7549082636833191
#
# fund:0.5526431202888489
#
# deposit:0.17662882804870605
#
# money:0.04500166326761246
#
# bank:0.0298562441021204
#
# account:0.01595904678106308
#
# one:0.026239626109600067
#
# two:0.06505943089723587
#
# busi:0.03114095702767372
#
# day:0.05747112259268761
#
# 33::Build your Store Shopping List on your computer# phone or tablet; your lists are synced across all your devices::0.7313351631164551
#
# build:0.3914450705051422
#
# store:0.17616653442382812
#
# shop:0.0756576806306839
#
# list:0.03420337289571762
#
# comput:0.030612869188189507
#
# phone:0.04166197404265404
#
# tablet:0.05686517804861069
#
# list:0.04272183030843735
#
# sync:0.039789751172065735
#
# across:0.036290619522333145
#
# devic:0.07458516210317612
#
# 34::< Buzz Communities> Facebook: Twitter: Instagram: Google+ Designer community:::0.7284591794013977
#
# buzz:0.5437230467796326
#
# commun:0.2206656038761139
#
# facebook:0.024031545966863632
#
# twitter:0.016530849039554596
#
# instagram:0.01547741424292326
#
# googl:0.0173494890332222
#
# design:0.08826034516096115
#
# commun:0.07396166771650314
#
# 35::^Money Magazines Best Innovative Banking App * CommBank app Push notifications alert you to important banking or product information# including NetCode Notifications# payments received# changes in your account balance or personal offers::0.6870508790016174
#
# money:0.35282593965530396
#
# magazin:0.11159247905015945
#
# best:0.13449329137802124
#
# innov:0.0808873325586319
#
# bank:0.019777333363890648
#
# app:0.022512178868055344
#
# commbank:0.012193087488412857
#
# app:0.009745821356773376
#
# push:0.013658780604600906
#
# notif:0.011018839664757252
#
# alert:0.02320583537220955
#
# import:0.030694229528307915
#
# bank:0.013168521225452423
#
# product:0.009502734057605267
#
# inform:0.007228564936667681
#
# includ:0.01708279922604561
#
# notif:0.015209798701107502
#
# payment:0.010505756363272667
#
# receiv:0.014101297594606876
#
# chang:0.021200545132160187
#
# account:0.016028786078095436
#
# balanc:0.014506034553050995
#
# person:0.0183646809309721
#
# offer:0.020495334640145302
#
# 36::Square deposits payments into your bank account in one to two business days::0.6845738291740417
#
# squar:0.6907832026481628
#
# deposit:0.1564062535762787
#
# payment:0.030805479735136032
#
# bank:0.021565917879343033
#
# account:0.011879288591444492
#
# one:0.02004762925207615
#
# two:0.019331740215420723
#
# busi:0.013877075165510178
#
# day:0.035303451120853424
#
# 37::Keep in touch with friends across Android# iOS# and the web# and sync chats across all your devices::0.6757702827453613
#
# keep:0.2724422216415405
#
# touch:0.11227333545684814
#
# friend:0.03881433978676796
#
# across:0.014574435539543629
#
# android:0.023767052218317986
#
# io:0.1694248616695404
#
# web:0.14930300414562225
#
# sync:0.04701245203614235
#
# chat:0.049398548901081085
#
# across:0.050211671739816666
#
# devic:0.07277815788984299
#
# 38::the one place to find alerts for your device# account# and any special offers from T-MobileWhat is Device Health Beta::0.6472287774085999
#
# one:0.5769565105438232
#
# place:0.3389188349246979
#
# find:0.019452949985861778
#
# alert:0.01227231789380312
#
# devic:0.013191401027143002
#
# account:0.004827952943742275
#
# special:0.0018417013343423605
#
# offer:0.0022628516890108585
#
# devic:0.004461431875824928
#
# health:0.006359787192195654
#
# beta:0.01945416070520878
#
# 39::Complete Product Info: View detailed information and style notes with multi perspective high-resolution images of selected items Share Your Pick: Share your favorites with friends via Facebook::0.6279091238975525
#
# complet:0.47799429297447205
#
# product:0.14097408950328827
#
# info:0.051442209631204605
#
# view:0.01709495671093464
#
# detail:0.014151660725474358
#
# inform:0.020760178565979004
#
# style:0.008818455040454865
#
# note:0.013232174329459667
#
# multi:0.021020950749516487
#
# perspect:0.025785863399505615
#
# high:0.024678640067577362
#
# resolut:0.02670508250594139
#
# imag:0.05979682505130768
#
# select:0.034722644835710526
#
# item:0.010989895090460777
#
# share:0.01448095217347145
#
# pick:0.01158879417926073
#
# share:0.00790963415056467
#
# favorit:0.0027551392558962107
#
# friend:0.0016900136834010482
#
# via:0.007537388242781162
#
# facebook:0.005870132241398096
#
# 40::Integrate with Amazon AWS / EC2# synchronise connections and automatically group servers based on their class or security groups::0.6240989565849304
#
# integr:0.3664517104625702
#
# amazon:0.12308015674352646
#
# aw:0.18618999421596527
#
# synchronis:0.0756075531244278
#
# connect:0.032460518181324005
#
# automat:0.013558425009250641
#
# group:0.008227240294218063
#
# server:0.05199674144387245
#
# base:0.020697377622127533
#
# class:0.06734534353017807
#
# secur:0.03153877705335617
#
# group:0.022846059873700142
#
# 41::With "MTS Service" easy to check your balance# top up your account# connect options# as well as access to a variety of entertainment services::0.6209405660629272
#
# mt:0.5013245344161987
#
# servic:0.21919721364974976
#
# easi:0.07073605060577393
#
# check:0.02993682771921158
#
# balanc:0.014846731908619404
#
# top:0.0067160301841795444
#
# account:0.008585809729993343
#
# connect:0.009508715942502022
#
# option:0.010949643328785896
#
# well:0.039215125143527985
#
# access:0.009117082692682743
#
# varieti:0.010066535323858261
#
# entertain:0.02583257108926773
#
# servic:0.04396713152527809
#
# 42::Protect your browsing from any malware-infected websites and secure your account logins and financial details when buying things online# checking your bank balance or making a transfer::0.620771050453186
#
# protect:0.15649758279323578
#
# brows:0.1643727719783783
#
# malwar:0.13351310789585114
#
# infect:0.08432895690202713
#
# websit:0.040525469928979874
#
# secur:0.029795553535223007
#
# account:0.012713628821074963
#
# login:0.00993743073195219
#
# financi:0.007878958247601986
#
# detail:0.02680346928536892
#
# buy:0.02063717320561409
#
# thing:0.03667256236076355
#
# onlin:0.03552383556962013
#
# check:0.0794069841504097
#
# bank:0.09449976682662964
#
# balanc:0.028516490012407303
#
# make:0.01876901090145111
#
# transfer:0.019607191905379295
#
# 43::Offered Services:Easy to check your account balance and statement::0.6012097001075745
#
# offer:0.5058967471122742
#
# servic:0.3258921504020691
#
# easi:0.08653656393289566
#
# check:0.04186497628688812
#
# account:0.007035369053483009
#
# balanc:0.013724427670240402
#
# statement:0.019049739465117455
#
# 44::Please contact your telecom operator for details::0.5922073721885681
#
# pleas:0.3471510112285614
#
# contact:0.08183029294013977
#
# telecom:0.01944105513393879
#
# oper:0.172719344496727
#
# detail:0.3788582980632782
#
# 45::On your App icon (for supported devices) or a 1x1 unread widget for any account including Unified Inbox COLOR CODING::0.5609527230262756
#
# app:0.33778122067451477
#
# icon:0.1913943737745285
#
# support:0.14539025723934174
#
# devic:0.12581971287727356
#
# unread:0.039412714540958405
#
# widget:0.06918554753065109
#
# account:0.0043648118153214455
#
# includ:0.004212068859487772
#
# unifi:0.002868710085749626
#
# inbox:0.009575125761330128
#
# color:0.03584843501448631
#
# code:0.03414704650640488
#
# 46::Overview of the coming passes Weather conditions for perfect sightings Radar screen with path indication Current location on a map Detection of Iridium flares Notifications and Alarms Share sightings with whatsapp# twitter# gmail# email etc::0.5570192337036133
#
# overview:0.36928752064704895
#
# come:0.19451546669006348
#
# pass:0.040885381400585175
#
# weather:0.0820082500576973
#
# condit:0.02401518076658249
#
# perfect:0.020069118589162827
#
# sight:0.009565751999616623
#
# radar:0.005052246619015932
#
# screen:0.00541373435407877
#
# path:0.017025165259838104
#
# indic:0.02714635618031025
#
# current:0.013349855318665504
#
# locat:0.008066171780228615
#
# map:0.011165609583258629
#
# detect:0.007591241504997015
#
# iridium:0.015793180093169212
#
# flare:0.01506215613335371
#
# notif:0.007301313802599907
#
# alarm:0.02175649255514145
#
# share:0.020041776821017265
#
# sight:0.02387404628098011
#
# whatsapp:0.014743601903319359
#
# twitter:0.009877489879727364
#
# gmail:0.008463523350656033
#
# email:0.018522925674915314
#
# etc:0.009406301192939281
#
# 47::Add/modify calendar events Allows you to create a calendar event# usually around going to see a movie or special event# and if you choose# share that calendar event with your social networks::0.5485721826553345
#
# add:0.5285772681236267
#
# modifi:0.14536985754966736
#
# calendar:0.03806301951408386
#
# event:0.009064148180186749
#
# allow:0.00411668187007308
#
# creat:0.00871962122619152
#
# calendar:0.00795726664364338
#
# event:0.024896269664168358
#
# usual:0.03865794464945793
#
# around:0.019005922600626945
#
# go:0.04177497699856758
#
# see:0.03564568981528282
#
# movi:0.045442577451467514
#
# special:0.013095595873892307
#
# event:0.003845833707600832
#
# choos:0.00882947538048029
#
# share:0.008447486907243729
#
# calendar:0.006567838601768017
#
# event:0.0042563448660075665
#
# social:0.0040408712811768055
#
# network:0.0036252220161259174
#
# 48::HeyTell is a cross-platform voice messenger & walkie talkie that allows you to instantly talk with friends & family who use Android# iOS# and Windows Phone 7 devices with the press of a single button::0.5424554944038391
#
# heytel:0.36315080523490906
#
# cross:0.12614895403385162
#
# platform:0.04622012376785278
#
# voic:0.013564178720116615
#
# messeng:0.006694648880511522
#
# walki:0.010688142850995064
#
# talki:0.05763885751366615
#
# allow:0.03458331152796745
#
# instantli:0.01582774706184864
#
# talk:0.032423775643110275
#
# friend:0.012035289779305458
#
# famili:0.03010988049209118
#
# use:0.023335246369242668
#
# android:0.032268133014440536
#
# io:0.024669505655765533
#
# window:0.03384794667363167
#
# phone:0.031172672286629677
#
# devic:0.012842349708080292
#
# press:0.021255766972899437
#
# singl:0.03279443085193634
#
# button:0.03872824087738991
#
# 49::see what you were doing and your engine# at a point in time* Turbo boost feature for vehicles that support MAP and MAF sensors (VW & Golf / Audi / Seat etc supported)* Alarms and warnings (for example if your coolant temperature goes over C whilst driving) with voice/speech overlay* Car dock support* Graph data* MPG* Able to share screenshots to Facebook# Twitter# Google+# Email# etc* AIDL API for third party apps# A simple Telnet interface for developers to talk to the adapter# and an OBD scanner::0.5355471968650818
#
# see:0.13848763704299927
#
# engin:0.05917120724916458
#
# point:0.02253492921590805
#
# time:0.01199305895715952
#
# turbo:0.0595538392663002
#
# boost:0.027692761272192
#
# featur:0.01433682069182396
#
# vehicl:0.009402384050190449
#
# support:0.02045500837266445
#
# map:0.013166535645723343
#
# maf:0.012577514164149761
#
# sensor:0.007298025768250227
#
# vw:0.012163248844444752
#
# golf:0.006996740587055683
#
# audi:0.008498133160173893
#
# seat:0.007179968990385532
#
# etc:0.018035126850008965
#
# support:0.04400716722011566
#
# alarm:0.04744093120098114
#
# warn:0.012224615551531315
#
# exampl:0.013425127603113651
#
# coolant:0.011204797774553299
#
# temperatur:0.005066657904535532
#
# goe:0.002504644449800253
#
# c:0.014445607550442219
#
# whilst:0.010562138631939888
#
# drive:0.010927706025540829
#
# voic:0.007430332712829113
#
# speech:0.003658370580524206
#
# overlay:0.004117278382182121
#
# car:0.004636017605662346
#
# dock:0.008820082992315292
#
# support:0.021053371950984
#
# graph:0.025377582758665085
#
# data:0.0059278858825564384
#
# mpg:0.0032763441558927298
#
# abl:0.0026281762402504683
#
# share:0.002072741277515888
#
# screenshot:0.0015984614146873355
#
# facebook:0.006552651058882475
#
# twitter:0.005058391951024532
#
# googl:0.004189844708889723
#
# email:0.013154737651348114
#
# etc:0.027196373790502548
#
# aidl:0.04256243631243706
#
# api:0.014678873121738434
#
# third:0.012300929054617882
#
# parti:0.007675674743950367
#
# app:0.03130907565355301
#
# simpl:0.02120882458984852
#
# telnet:0.017615830525755882
#
# interfac:0.014947539195418358
#
# develop:0.023069538176059723
#
# talk:0.01760002225637436
#
# adapt:0.008106403984129429
#
# obd:0.011561385355889797
#
# scanner:0.009262719191610813
#
# 50::Twitter & Facebook integration: This is major because if you dont tweet or post about your journey# how do people know it actually happened Did it actually happen::0.5225905776023865
#
# twitter:0.3744885325431824
#
# facebook:0.14015933871269226
#
# integr:0.05616426095366478
#
# major:0.05243516340851784
#
# dont:0.05525953695178032
#
# tweet:0.021158777177333832
#
# post:0.02316402457654476
#
# journey:0.020064398646354675
#
# peopl:0.009405380114912987
#
# know:0.051203105598688126
#
# actual:0.060003187507390976
#
# happen:0.03250021114945412
#
# actual:0.0441291369497776
#
# happen:0.05986493453383446
#
# 51::Able to display third party app notification on locker screen (include Google +# Facebook# Twitter# WeChat etc::0.5174697637557983
#
# abl:0.38785186409950256
#
# display:0.20890167355537415
#
# third:0.12594817578792572
#
# parti:0.07911930978298187
#
# app:0.040540579706430435
#
# notif:0.024750392884016037
#
# locker:0.02573319524526596
#
# screen:0.04438258707523346
#
# includ:0.011313253082334995
#
# googl:0.017069311812520027
#
# facebook:0.010223012417554855
#
# twitter:0.012906298041343689
#
# wechat:0.004789971746504307
#
# etc:0.006470511667430401
#
# 52::Sync for reddit (previously reddit sync) is a full-featured app for browsing the popular site reddit on the go::0.5066766142845154
#
# sync:0.3902246654033661
#
# reddit:0.2129012793302536
#
# previous:0.0836191475391388
#
# reddit:0.07025149464607239
#
# sync:0.017790695652365685
#
# full:0.04993182420730591
#
# featur:0.06039060652256012
#
# app:0.037942320108413696
#
# brows:0.015278364531695843
#
# popular:0.014608374796807766
#
# site:0.008989476598799229
#
# reddit:0.022558145225048065
#
# go:0.01551348902285099
#
# 53::Keep in touch:* Official website : Facebook : Twitter : Google+ :::0.5004360675811768
#
# keep:0.20918317139148712
#
# touch:0.15443746745586395
#
# offici:0.22074347734451294
#
# websit:0.17345033586025238
#
# facebook:0.13433511555194855
#
# twitter:0.05960965156555176
#
# googl:0.04824075102806091
#
# 54::AndroidSpin (refers to Modern ICS themes) Available widgets: Agenda & Calendar People Bookmarks Messaging Twitter More tools: Quick Event::0.48672887682914734
#
# androidspin:0.34630224108695984
#
# refer:0.06441948562860489
#
# modern:0.05354296788573265
#
# ic:0.17413777112960815
#
# theme:0.08755019307136536
#
# avail:0.009160219691693783
#
# widget:0.0279112346470356
#
# agenda:0.007613784167915583
#
# calendar:0.016735827550292015
#
# peopl:0.010344362817704678
#
# bookmark:0.03328384831547737
#
# messag:0.05101499333977699
#
# twitter:0.03636632859706879
#
# tool:0.03431621566414833
#
# quick:0.017255548387765884
#
# event:0.030045071616768837
#
# 55::Flash when a new notification arrives in selected app (Whatsapp# Email# Twitter# Alarm/Clock# Messenger# any other app) * For Android or above : [Notification] service::0.4845591187477112
#
# flash:0.6330358386039734
#
# new:0.10700417309999466
#
# notif:0.05054297670722008
#
# arriv:0.04312479868531227
#
# select:0.030690791085362434
#
# app:0.021280979737639427
#
# whatsapp:0.003399009583517909
#
# email:0.018161023035645485
#
# twitter:0.011015868745744228
#
# alarm:0.005635756067931652
#
# clock:0.015811439603567123
#
# messeng:0.005651619751006365
#
# app:0.014389430172741413
#
# android:0.01409836858510971
#
# notif:0.01709245890378952
#
# servic:0.009065615944564342
#
# 56::Save your videos creation to your device or share with friends::0.474507600069046
#
# save:0.6369326710700989
#
# video:0.14619870483875275
#
# creation:0.07737644761800766
#
# devic:0.08048417419195175
#
# share:0.04280474781990051
#
# friend:0.01620326191186905
#
# 57::Chat with your friends from AIM# Facebook and Google chat networks::0.4631037712097168
#
# chat:0.7322530746459961
#
# friend:0.08698800951242447
#
# aim:0.034340471029281616
#
# facebook:0.03331533074378967
#
# googl:0.050840262323617935
#
# chat:0.043687958270311356
#
# network:0.018574880436062813
#
# 58::A: Long tap in the list to bring up popup menuCWMoney is a personal finance manager UI Theme Select Shortcut#Widget for QuickTrack Multiple accounts Multiple currency ::0.44368860125541687
#
# long:0.4751923382282257
#
# tap:0.08832448720932007
#
# list:0.0679599866271019
#
# bring:0.029681816697120667
#
# popup:0.023423632606863976
#
# person:0.006717924494296312
#
# financ:0.003669454250484705
#
# manag:0.017247743904590607
#
# ui:0.025393856689333916
#
# theme:0.03735557943582535
#
# select:0.06960266083478928
#
# shortcut:0.03278777748346329
#
# widget:0.03848293423652649
#
# multipl:0.05837775021791458
#
# account:0.00671859085559845
#
# multipl:0.009920824319124222
#
# currenc:0.009142582304775715
#
# 59::Booster smartly frees up memory space (RAM) and removes viruses and junk cache# so you can play your favorite games faster and smoother# plus more than 70# different apps like Facebook# WeChat# LINE# Whatsapp# Instagram# and Skype::0.43427661061286926
#
# booster:0.2974453568458557
#
# smartli:0.10971862822771072
#
# free:0.024124687537550926
#
# memori:0.05071267485618591
#
# space:0.07236737012863159
#
# ram:0.09016291052103043
#
# remov:0.07058494538068771
#
# virus:0.04627669230103493
#
# junk:0.033688753843307495
#
# cach:0.03350376337766647
#
# play:0.03621871769428253
#
# favorit:0.006713071372359991
#
# game:0.016446862369775772
#
# faster:0.004671341273933649
#
# smoother:0.01948312483727932
#
# plu:0.004667674191296101
#
# differ:0.007444470655173063
#
# app:0.008614285849034786
#
# like:0.01344530563801527
#
# facebook:0.011956592090427876
#
# wechat:0.010966054163873196
#
# line:0.0054631587117910385
#
# whatsapp:0.00997484102845192
#
# instagram:0.00863155908882618
#
# skype:0.006717057432979345
#
# 60::With NAVER Cloud's feature of 'A photo taken on the same day last year'# you can view photos everyday that will remind you of your memory 2::0.43139195442199707
#
# naver:0.504844605922699
#
# cloud:0.026826800778508186
#
# featur:0.07404164969921112
#
# photo:0.02329457364976406
#
# taken:0.013471595011651516
#
# day:0.054476048797369
#
# last:0.04240938276052475
#
# year:0.0331619530916214
#
# view:0.04913384094834328
#
# photo:0.01936297118663788
#
# everyday:0.03556540235877037
#
# remind:0.07627838104963303
#
# memori:0.04713275283575058
#
# 61::All from a single view you can free system memory with a push of a button# control the WIFI# Bluetooth# Auto-Sync and Airplane mode# and get the devices battery level/usage::0.4185488522052765
#
# singl:0.47564685344696045
#
# view:0.2210896760225296
#
# free:0.09893471747636795
#
# system:0.013055448420345783
#
# memori:0.023904090747237206
#
# push:0.008346136659383774
#
# button:0.029817616567015648
#
# control:0.01029238197952509
#
# wifi:0.004884905181825161
#
# bluetooth:0.0021242995280772448
#
# auto:0.004165110643953085
#
# sync:0.0037771177012473345
#
# airplan:0.008573729544878006
#
# mode:0.02915780618786812
#
# get:0.008865300565958023
#
# devic:0.01072571612894535
#
# batteri:0.026864688843488693
#
# level:0.010272554121911526
#
# usag:0.009502081200480461
#
# 62::READ PHONE STATE used to register your device for push notifications with Urban Airship# our push notification delivery partner::0.40528687834739685
#
# read:0.5842841863632202
#
# phone:0.2260623425245285
#
# state:0.0274201687425375
#
# use:0.0370682068169117
#
# regist:0.015545809641480446
#
# devic:0.01713462360203266
#
# push:0.007022860459983349
#
# notif:0.013507070951163769
#
# urban:0.006118844263255596
#
# airship:0.01640351116657257
#
# push:0.010692654177546501
#
# notif:0.016306813806295395
#
# deliveri:0.013231584802269936
#
# partner:0.009201346896588802
#
# 63::PRESS Users no longer have to send a mass email or text message The Next Web "There are several options# but the best one we've found so far that's free and works well is Sync Me " PC Advisor "Sync::0.3965757191181183
#
# press:0.15461291372776031
#
# user:0.0952211245894432
#
# longer:0.05647202581167221
#
# send:0.023949291557073593
#
# mass:0.014683288522064686
#
# email:0.029766613617539406
#
# text:0.04597688093781471
#
# messag:0.05659138783812523
#
# next:0.12685362994670868
#
# web:0.07352511584758759
#
# sever:0.06613847613334656
#
# option:0.014726453460752964
#
# best:0.01744750700891018
#
# one:0.021676521748304367
#
# found:0.03139347583055496
#
# far:0.020337607711553574
#
# free:0.01216631568968296
#
# work:0.021216541528701782
#
# well:0.029307136312127113
#
# sync:0.013418616726994514
#
# pc:0.04141293838620186
#
# advisor:0.0228250864893198
#
# sync:0.010281010530889034
#
# 64::share created square photo directly to Instagram with just one click of a button::0.38958740234375
#
# share:0.45435115694999695
#
# creat:0.16850504279136658
#
# squar:0.11146284639835358
#
# photo:0.08695494383573532
#
# directli:0.03441575542092323
#
# instagram:0.01040868740528822
#
# one:0.049303799867630005
#
# click:0.060488492250442505
#
# button:0.024109400808811188
#
# 65::Share your video to Youtube# Facebook# Instagram# Whatsapp# Line# Wechat# etc Exclusive innovation: Doodle on video Bored of the monotonous fonts Just doodle it It's so simple and intuitive Zoom in and out::0.38066357374191284
#
# share:0.2502695918083191
#
# video:0.17475782334804535
#
# youtub:0.04739407077431679
#
# facebook:0.049524348229169846
#
# instagram:0.018556874245405197
#
# whatsapp:0.02124154008924961
#
# line:0.023988056927919388
#
# wechat:0.007106931414455175
#
# etc:0.01734319142997265
#
# exclus:0.050390370190143585
#
# innov:0.060674868524074554
#
# doodl:0.0435202457010746
#
# video:0.03776157647371292
#
# bore:0.04465586692094803
#
# monoton:0.00932328775525093
#
# font:0.021526606753468513
#
# doodl:0.045823339372873306
#
# simpl:0.04100351780653
#
# intuit:0.017779210582375526
#
# zoom:0.017358645796775818
#
# 66::Unread Gmail inbox or priority inbox conversations::0.3727181553840637
#
# unread:0.6197313666343689
#
# gmail:0.17192450165748596
#
# inbox:0.07298272103071213
#
# prioriti:0.1084602028131485
#
# inbox:0.014046819880604744
#
# convers:0.012854382395744324
#
# 67::------------------------------------------------------------This is a free version# limited to 5 contacts Problems::0.3697815239429474
#
# free:0.28930720686912537
#
# version:0.548761248588562
#
# limit:0.09073502570390701
#
# contact:0.026126211509108543
#
# problem:0.04507031291723251
#
# 68::Moreover# the new smart alerting system lets you know how much credit you have in your account and if you need to top up in order to pay for options::0.3668867349624634
#
# moreov:0.3293841481208801
#
# new:0.1867179423570633
#
# smart:0.0817657858133316
#
# alert:0.06288541108369827
#
# system:0.04119359701871872
#
# let:0.057284895330667496
#
# know:0.0465305931866169
#
# much:0.061715517193078995
#
# credit:0.030132563784718513
#
# account:0.011654473841190338
#
# need:0.023703062906861305
#
# top:0.017875637859106064
#
# order:0.015561461448669434
#
# pay:0.020121995359659195
#
# option:0.01347294170409441
#
# 69::Swiping in message list (actions) and between messages Can save attachments as files Message auto-fit (like in Gmail)::0.35243719816207886
#
# swipe:0.35371243953704834
#
# messag:0.2331639528274536
#
# list:0.1224745512008667
#
# action:0.10583339631557465
#
# messag:0.030198119580745697
#
# save:0.01057059969753027
#
# attach:0.01803719624876976
#
# file:0.013729971833527088
#
# messag:0.009968479163944721
#
# auto:0.03559908643364906
#
# fit:0.03407714515924454
#
# like:0.01897108182311058
#
# gmail:0.01366398110985756
#
# 70::Facebook mode This unique feature speeds up Facebook::0.3523094654083252
#
# facebook:0.45118361711502075
#
# mode:0.2646503448486328
#
# uniqu:0.14513322710990906
#
# featur:0.07735313475131989
#
# speed:0.02646261639893055
#
# facebook:0.0352170430123806
#
# 71::Its state-of-the-art GPS system can keep tabs on registered phones# using satellites to triangulate the exact location of every phone registered to your account::0.34284359216690063
#
# state:0.3774285316467285
#
# art:0.27960896492004395
#
# gp:0.08499876409769058
#
# system:0.06299787759780884
#
# keep:0.025251194834709167
#
# tab:0.016936900094151497
#
# regist:0.009836816228926182
#
# phone:0.0171909648925066
#
# use:0.013818533159792423
#
# satellit:0.01400383934378624
#
# triangul:0.021579623222351074
#
# exact:0.006126685068011284
#
# locat:0.014979162253439426
#
# everi:0.023149700835347176
#
# phone:0.008099465630948544
#
# regist:0.016632430255413055
#
# account:0.0073605808429419994
#
# 72::Unread SMS; Missed Call; Notifier for Gmail and WhatsApp KK Launcher Prime Features: Private folder; Super folder App Lock::0.3325563669204712
#
# unread:0.3403160870075226
#
# sm:0.1402481645345688
#
# miss:0.02174714021384716
#
# call:0.01382725965231657
#
# notifi:0.004015792161226273
#
# gmail:0.008586326614022255
#
# whatsapp:0.013511202298104763
#
# kk:0.0494704470038414
#
# launcher:0.13493916392326355
#
# prime:0.199860617518425
#
# featur:0.029305869713425636
#
# privat:0.006749950349330902
#
# folder:0.004027882125228643
#
# super:0.01003977283835411
#
# folder:0.01340922899544239
#
# app:0.004428423009812832
#
# lock:0.005516672506928444
#
# 73::* For Com2uS Mobile Game Terms of Service# visit For questions or customer support# please contact our Customer Support by visiting::0.3276774287223816
#
# mobil:0.18336151540279388
#
# game:0.20076483488082886
#
# term:0.04138652980327606
#
# servic:0.09437888115644455
#
# visit:0.17367707192897797
#
# question:0.12603366374969482
#
# custom:0.019219715148210526
#
# support:0.03800448775291443
#
# pleas:0.07098421454429626
#
# contact:0.01833544857800007
#
# custom:0.011568497866392136
#
# support:0.014543857425451279
#
# visit:0.007741348817944527
#
# 74::Smart Cycle Alarm + Movement Tracker + Sound Recorder + Sleep Debt Log + Data Analysis + Trend Graphs + Sleep Help + Auto-Wifi/Silence/Airplane modes + Export + Sync to The completely new Sleepbot is finally here::0.32533028721809387
#
# smart:0.47434115409851074
#
# cycl:0.19847659766674042
#
# alarm:0.13402320444583893
#
# movement:0.043433647602796555
#
# tracker:0.008168072439730167
#
# sound:0.0022707900498062372
#
# record:0.002449895953759551
#
# sleep:0.009531470015645027
#
# debt:0.0038726013153791428
#
# log:0.0025723264552652836
#
# data:0.0034117053728550673
#
# analysi:0.010985872708261013
#
# trend:0.009351024404168129
#
# graph:0.0047438424080610275
#
# sleep:0.007852945476770401
#
# help:0.009502004832029343
#
# auto:0.0031882748007774353
#
# wifi:0.0018962136236950755
#
# silenc:0.007174145430326462
#
# airplan:0.015757229179143906
#
# mode:0.012861276976764202
#
# export:0.0066784098744392395
#
# sync:0.0027860295958817005
#
# complet:0.008458749391138554
#
# new:0.003164830384775996
#
# sleepbot:0.00452638603746891
#
# final:0.008521218784153461
#
# 75::Find new live and upcoming events from the accounts you follow daily Watch and Discover Live Events:::0.3183188736438751
#
# find:0.233329638838768
#
# new:0.2697385251522064
#
# live:0.21139109134674072
#
# upcom:0.059646882116794586
#
# event:0.0594484768807888
#
# account:0.015818007290363312
#
# follow:0.03495624661445618
#
# daili:0.006422898266464472
#
# watch:0.00586606515571475
#
# discov:0.02225884050130844
#
# live:0.042286213487386703
#
# event:0.038837090134620667
#
# 76::Instagram is a simple way to capture and share the world's moments::0.3167102038860321
#
# instagram:0.4136839210987091
#
# simpl:0.36629292368888855
#
# way:0.037774089723825455
#
# captur:0.0545235238969326
#
# share:0.03489397093653679
#
# world:0.03241097927093506
#
# moment:0.06042065471410751
#
# 77::CAMERA# VIBRATE: Enables My Account to support credit card scanning::0.31617388129234314
#
# camera:0.5638584494590759
#
# vibrat:0.14357435703277588
#
# enabl:0.11442338675260544
#
# account:0.052601058036088943
#
# support:0.09365551918745041
#
# credit:0.017180433496832848
#
# card:0.006333783734589815
#
# scan:0.008372930809855461
#
# 78::Perfect for managing work# organizing meetings# and planning events Dropbox Integration::0.3141857087612152
#
# perfect:0.5662955641746521
#
# manag:0.05684288591146469
#
# work:0.04814555123448372
#
# organ:0.03306601196527481
#
# meet:0.10258234292268753
#
# plan:0.05142180621623993
#
# event:0.08175752311944962
#
# dropbox:0.028981894254684448
#
# integr:0.03090641461312771
#
# 79::Receive text messages: used for automatically linking your Threema ID to a mobile phone number::0.31033873558044434
#
# receiv:0.47504720091819763
#
# text:0.1757085621356964
#
# messag:0.07746664434671402
#
# use:0.08891280740499496
#
# automat:0.044612299650907516
#
# link:0.05039096251130104
#
# threema:0.024830447509884834
#
# id:0.01606377400457859
#
# mobil:0.015073805116117
#
# phone:0.017525335773825645
#
# number:0.014368101954460144
#
# 80::The easiest and fastest way to create Facebook albums# on the fly::0.30540338158607483
#
# easiest:0.6510326266288757
#
# fastest:0.11304779350757599
#
# way:0.09168969839811325
#
# creat:0.08163750171661377
#
# facebook:0.03393423557281494
#
# album:0.015631698071956635
#
# fli:0.013026378117501736
#
# 81::Schedule automatic backups or manually create backups::0.30243363976478577
#
# schedul:0.35809969902038574
#
# automat:0.3032125234603882
#
# backup:0.1719236671924591
#
# manual:0.048763927072286606
#
# creat:0.08979088813066483
#
# backup:0.028209315612912178
#
# 82::Key features:Download Unlimited MixtapesStream Unlimited MixtapesShare music statuses with your friends via social networksStream selected VideosFind the Latest MixtapesMy Mixtapez RadioHow to use My Mixtapez:My Mixtapez brings you the newest & hottest mixtapes on the go::0.29898640513420105
#
# key:0.4626103639602661
#
# featur:0.11192675679922104
#
# download:0.09986765682697296
#
# unlimit:0.0557730495929718
#
# unlimit:0.03324638679623604
#
# music:0.02187485620379448
#
# status:0.011186772026121616
#
# friend:0.005647298879921436
#
# via:0.009150478057563305
#
# social:0.016720781102776527
#
# select:0.0133128073066473
#
# latest:0.03326740488409996
#
# mixtapez:0.02048611268401146
#
# use:0.0150157380849123
#
# mixtapez:0.009560097008943558
#
# mixtapez:0.011486019939184189
#
# bring:0.01612868905067444
#
# newest:0.016381334513425827
#
# hottest:0.009124227799475193
#
# mixtap:0.011429974809288979
#
# go:0.015803221613168716
#
# 83::With Blackboard Mobile Learn# you can:-Receive push notifications of course activity-Check Grades* -Post to Discussions-Attach files from Dropbox-Read Announcements (instructors can post Announcements)-View Content (instructors can post Content Items)-Create and comment on Blogs and Journalsposts-Take mobile-friendly testsand lots more::0.2964489161968231
#
# blackboard:0.4418506622314453
#
# mobil:0.12933821976184845
#
# learn:0.04341147467494011
#
# receiv:0.016941245645284653
#
# push:0.02006315067410469
#
# notif:0.06257742643356323
#
# cours:0.029451027512550354
#
# activ:0.009503347799181938
#
# check:0.016915282234549522
#
# grade:0.01813347451388836
#
# post:0.017703913152217865
#
# discuss:0.020940100774168968
#
# attach:0.004147740546613932
#
# file:0.002361191436648369
#
# dropbox:0.0029165097512304783
#
# read:0.009923189878463745
#
# announc:0.005570414010435343
#
# instructor:0.005044760648161173
#
# post:0.00215094443410635
#
# announc:0.000634213094599545
#
# view:0.001172850257717073
#
# content:0.012187493033707142
#
# instructor:0.01685773767530918
#
# post:0.01958540268242359
#
# content:0.011500369757413864
#
# item:0.005506314802914858
#
# creat:0.008417637087404728
#
# comment:0.007640108000487089
#
# blog:0.016384728252887726
#
# take:0.0070366752333939075
#
# mobil:0.007344501558691263
#
# friendli:0.006967638153582811
#
# lot:0.01982048526406288
#
# 84::Smart Keep your favorite sites and mobile videos at your fingertips with smart searching# easy-to-use tabs# and desktop-to-mobile Sync features::0.2945234477519989
#
# smart:0.6404394507408142
#
# keep:0.08766479790210724
#
# favorit:0.017961319535970688
#
# site:0.02026897668838501
#
# mobil:0.010744869709014893
#
# video:0.019332807511091232
#
# fingertip:0.019910719245672226
#
# smart:0.012548644095659256
#
# search:0.017436480149626732
#
# easi:0.022336525842547417
#
# use:0.011315185576677322
#
# tab:0.011640826240181923
#
# desktop:0.031939730048179626
#
# mobil:0.013434520922601223
#
# sync:0.025328490883111954
#
# featur:0.037696611136198044
#
# 85::Click for three times to share hundreds of photos with your family# friends# lover Experience the best cloud service 1::0.2943915128707886
#
# click:0.4537898004055023
#
# three:0.19362981617450714
#
# time:0.06314356625080109
#
# share:0.08652256429195404
#
# hundr:0.06066229194402695
#
# photo:0.019126703962683678
#
# famili:0.02366459183394909
#
# friend:0.0052024307660758495
#
# lover:0.04240766540169716
#
# experi:0.011423947289586067
#
# best:0.016047615557909012
#
# cloud:0.015066787600517273
#
# servic:0.009312215261161327
#
# 86::A kind of story maker tool that helps to create own story and share to the world by uploading on Youtube# Vimeo and other social networks::0.29058346152305603
#
# kind:0.49695026874542236
#
# stori:0.25228530168533325
#
# maker:0.07739325612783432
#
# tool:0.03506502881646156
#
# help:0.006643646862357855
#
# creat:0.01766333542764187
#
# stori:0.008623672649264336
#
# share:0.015833884477615356
#
# world:0.023701630532741547
#
# upload:0.028693288564682007
#
# youtub:0.014318248257040977
#
# vimeo:0.005226129200309515
#
# social:0.006413065828382969
#
# network:0.011189279146492481
#
# 87::With Thunderclap Technology# you can sync all your photos and videos on Hi and delete local copies to save your phone space::0.2845536768436432
#
# technolog:0.730780839920044
#
# sync:0.08379398286342621
#
# photo:0.02641783282160759
#
# video:0.008931737393140793
#
# hi:0.02633335255086422
#
# delet:0.0075119975954294205
#
# local:0.03883162513375282
#
# copi:0.021206483244895935
#
# save:0.009669924154877663
#
# phone:0.009067794308066368
#
# space:0.037454307079315186
#
# 88::Contact Us Easily Schedule an appointment at a banking center or call us with any questions::0.2601807117462158
#
# contact:0.05543313920497894
#
# us:0.8108268976211548
#
# easili:0.01588275283575058
#
# schedul:0.007771543227136135
#
# appoint:0.0025321526918560266
#
# bank:0.0009473499958403409
#
# center:0.00023199951101560146
#
# call:0.00017350890266243368
#
# us:0.03844926133751869
#
# question:0.06775140762329102
#
# 89::Exception list (don't block list) (PRO) Text filters by plain text or regular expression# prefix-matches# postfix matches 2::0.2574620842933655
#
# except:0.5851836800575256
#
# list:0.1114802211523056
#
# block:0.06406310945749283
#
# list:0.02864089235663414
#
# pro:0.05544929951429367
#
# text:0.05049110949039459
#
# filter:0.01646377146244049
#
# ...
#
# constantli:0.04564430192112923
#
# 2345::'# or ask Andy to how to spell words Give us a try::0.0004144023987464607
#
# ask:0.1487223356962204
#
# andi:0.6239960789680481
#
# spell:0.07677563279867172
#
# word:0.017866101115942
#
# give:0.011321017518639565
#
# us:0.0874958261847496
#
# tri:0.033823005855083466
#
# 2346::We are grateful for the evaluation and review of the application::0.0004109691653866321
#
# grate:0.3274311125278473
#
# evalu:0.2998313903808594
#
# review:0.13742206990718842
#
# applic:0.23531539738178253
#
# 2347::Please send us feedback or ask questions directly at::0.000400906807044521
#
# pleas:0.0781732127070427
#
# send:0.1016744002699852
#
# us:0.14525389671325684
#
# feedback:0.30850258469581604
#
# ask:0.32594358921051025
#
# question:0.024043498560786247
#
# directli:0.01640886627137661
#
# 2348::From tweezing# to waxing# to shaving::0.0004006975796073675
#
# tweez:0.507259726524353
#
# wax:0.37059882283210754
#
# shave:0.12214145809412003
#
# 2349::For more information on emoji support and other FAQs::0.0003918028378393501
#
# inform:0.41791629791259766
#
# emoji:0.40362513065338135
#
# support:0.13634680211544037
#
# faq:0.04211178421974182
#
# 2350::*System Requirements MB of ram or more is recommended for smooth game-play::0.0003817596298176795
#
# system:0.35565564036369324
#
# requir:0.28836768865585327
#
# mb:0.18069395422935486
#
# ram:0.09061727672815323
#
# recommend:0.038514960557222366
#
# smooth:0.01448697131127119
#
# game:0.01591562107205391
#
# play:0.01574796251952648
#
# 2351::Game Features: Localized to English# French# German# Spanish# Italian# Canadian French and Mexican Spanish::0.00037184616667218506
#
# game:0.3546854257583618
#
# featur:0.22944656014442444
#
# local:0.11321394145488739
#
# english:0.0918584018945694
#
# french:0.07271286845207214
#
# german:0.03648944944143295
#
# spanish:0.021149592474102974
#
# italian:0.03337422385811806
#
# canadian:0.011742240749299526
#
# french:0.010094844736158848
#
# mexican:0.0108104282990098
#
# spanish:0.014422102831304073
#
# 2352::We just love hearing your feedback::0.000367636326700449
#
# love:0.7356206774711609
#
# hear:0.12416206300258636
#
# feedback:0.14021727442741394
#
# 2353::Fans of The Hunger Games will not be disappointed " s GeekDad::0.0003644802200142294
#
# fan:0.36998990178108215
#
# hunger:0.2935267686843872
#
# game:0.20184755325317383
#
# disappoint:0.1346358060836792
#
# 2354::Supported Languages: English# Simplified Chinese# Traditional Chinese# Spanish# Japanese# Korean# Russian# Indonesian# Portuguese Brazil::0.00036295613972470164
#
# support:0.5410377979278564
#
# languag:0.20698003470897675
#
# english:0.10700433701276779
#
# simplifi:0.04224447160959244
#
# chines:0.014283019118010998
#
# tradit:0.012746789492666721
#
# chines:0.010284921154379845
#
# spanish:0.008363383822143078
#
# japanes:0.014039251022040844
#
# korean:0.01068602129817009
#
# russian:0.006892334204167128
#
# indonesian:0.009447596967220306
#
# portugues:0.006516019348055124
#
# brazil:0.00947407353669405
#
# 2355::Please Read If you experience issues with improper display or errors# please close and restart this app::0.000362041755579412
#
# pleas:0.459484338760376
#
# read:0.09680140018463135
#
# experi:0.040622640401124954
#
# issu:0.16150887310504913
#
# improp:0.06678516417741776
#
# display:0.006444938480854034
#
# error:0.007832836359739304
#
# pleas:0.06900765001773834
#
# close:0.04475390538573265
#
# restart:0.007938584312796593
#
# app:0.03881969675421715
#
# 2356::> Wax & style beards with colorful wax strips::0.00036098610144108534
#
# wax:0.5952417254447937
#
# style:0.2057952582836151
#
# beard:0.04680831357836723
#
# color:0.06000380590558052
#
# wax:0.04590480029582977
#
# strip:0.04624606668949127
#
# 2357::Using this app# you can learn English# French# Spanish# German# Italian# Chinese# Japanese# Korean# Russian# Turkish# Portuguese# Arabic & Vietnamese from our multilingual parrot::0.0003602253273129463
#
# use:0.36199691891670227
#
# app:0.28092241287231445
#
# learn:0.05675618350505829
#
# english:0.03403777629137039
#
# french:0.055478665977716446
#
# spanish:0.017477864399552345
#
# german:0.026180479675531387
#
# italian:0.01980150118470192
#
# chines:0.01616324856877327
#
# japanes:0.020175622776150703
#
# korean:0.022346418350934982
#
# russian:0.01553285587579012
#
# turkish:0.012630345299839973
#
# portugues:0.02256747893989086
#
# arab:0.013257797807455063
#
# vietnames:0.008651163429021835
#
# multilingu:0.007861446589231491
#
# parrot:0.008161792531609535
#
# 2358::OSM is available in the following languages: English# German# Danish# Indonesian# Spanish# French# Italian# Hungarian# Dutch# Polish# Portuguese# Romanian# Serbian# Swedish# Turkish# Russian# Arabic# Thai and Japanese::0.0003545581712387502
#
# osm:0.4583711326122284
#
# avail:0.09463585168123245
#
# follow:0.05429892614483833
#
# languag:0.043331459164619446
#
# english:0.019890159368515015
#
# german:0.015760142356157303
#
# danish:0.019739532843232155
#
# indonesian:0.02360028773546219
#
# spanish:0.022266456857323647
#
# french:0.026970477774739265
#
# italian:0.030681774020195007
#
# hungarian:0.03526574745774269
#
# dutch:0.02685982547700405
#
# polish:0.024058911949396133
#
# portugues:0.018143480643630028
#
# romanian:0.020738590508699417
#
# serbian:0.02007998712360859
#
# swedish:0.011666667647659779
#
# turkish:0.006698079872876406
#
# russian:0.005203539039939642
#
# arab:0.007017927244305611
#
# thai:0.007210480980575085
#
# japanes:0.007510509341955185
#
# 2359::Keep update to Android M( Android Marshmallow): -::0.00035048570134676993
#
# keep:0.45865991711616516
#
# updat:0.2649262845516205
#
# android:0.11466818302869797
#
# android:0.09110406786203384
#
# marshmallow:0.07064160704612732
#
# 2360::Learn to speak Spanish# Italian# German# French# English# or one of 19 other languages anytime# anywhere::0.00035019093775190413
#
# learn:0.33938056230545044
#
# speak:0.18064364790916443
#
# spanish:0.07678990811109543
#
# italian:0.06399543583393097
#
# german:0.0614299438893795
#
# french:0.11570705473423004
#
# english:0.06501904129981995
#
# one:0.05103444308042526
#
# languag:0.030537063255906105
#
# anytim:0.008552533574402332
#
# anywher:0.006910412106662989
#
# 2361::And wait for the next game updates::0.00034954390139319
#
# wait:0.5458112955093384
#
# next:0.2511727213859558
#
# game:0.08566374331712723
#
# updat:0.117352195084095
#
# 2362::We appreciate and value your feedback::0.0003396029060240835
#
# appreci:0.7379757165908813
#
# valu:0.050384849309921265
#
# feedback:0.21163935959339142
#
# 2363::Apply icon packs# support ADW icon pack and Launcherpro icon pack::0.0003308705345261842
#
# appli:0.3461149036884308
#
# icon:0.25918278098106384
#
# pack:0.08830209076404572
#
# support:0.07328108698129654
#
# adw:0.05381334200501442
#
# icon:0.05414119362831116
#
# pack:0.05419312044978142
#
# launcherpro:0.027421368286013603
#
# icon:0.02710643596947193
#
# pack:0.016443612053990364
#
# 2364::If you like the software and want to support the development please rate it::0.000322465697536245
#
# like:0.24068498611450195
#
# softwar:0.36838498711586
#
# want:0.17776143550872803
#
# support:0.11582542955875397
#
# develop:0.03226904943585396
#
# pleas:0.04561147466301918
#
# rate:0.019462646916508675
#
# 2365::All the best HD wallpapers and backgrounds Free Yes# that's right::0.00031381446751765907
#
# best:0.35519054532051086
#
# hd:0.2794617712497711
#
# wallpap:0.1959560662508011
#
# background:0.060810986906290054
#
# free:0.03562168776988983
#
# ye:0.04141882807016373
#
# right:0.031540125608444214
#
# 2366::If you like this signal booster 3G 4G# then please click +1 and rate::0.0003035418048966676
#
# like:0.5174685120582581
#
# signal:0.07345400005578995
#
# booster:0.2052270621061325
#
# pleas:0.1533019244670868
#
# click:0.03046167828142643
#
# rate:0.02008678764104843
#
# 2367::Smooth animation; Wallpaper scrolling; 16 transition effect; 5 live wallpaper effect; Color wallpaper8 Launcher Drawer: -::0.0002963928272947669
#
# smooth:0.45437100529670715
#
# anim:0.23762217164039612
#
# wallpap:0.08944825083017349
#
# scroll:0.03995110094547272
#
# transit:0.01706824265420437
#
# effect:0.025387631729245186
#
# live:0.015454049222171307
#
# wallpap:0.014966251328587532
#
# effect:0.008191187866032124
#
# color:0.013819769024848938
#
# launcher:0.041874613612890244
#
# drawer:0.041845712810754776
#
# 2368::Make sure to follow us so you don't miss out on the latest styles Various designs are available::0.0002874078927561641
#
# make:0.27037087082862854
#
# sure:0.179578959941864
#
# follow:0.06544867157936096
#
# us:0.11765921860933304
#
# miss:0.06248201057314873
#
# latest:0.03075450472533703
#
# style:0.215667262673378
#
# variou:0.03331027552485466
#
# design:0.013836956582963467
#
# avail:0.010891338810324669
#
# 2369::IS LANGUAGES Here are a 'few' of the Bibles available:Arabic# Ashninka# Bafut# Bulgarian# Cebuano# Chinese Mandarin# Chinese# Cantonese# Croatian# Czech# Danish# Dutch# English# Ewe# Farsi / Persian# Finnish# French# German# Guaymi# Haitian# Huasteco Veracruz# Indonesian# Italian# Japanese# Javanese# Korean# Latin# Malagasy# Mezquital# Ngiemboon# Portuguese# Romanian# Russian# Somali# Spanish# Swedish# Thai# Ukrainian# Urdu# Vietnamese# many more::0.00028304505394771695
#
# languag:0.2385096400976181
#
# bibl:0.07604162395000458
#
# avail:0.02981582283973694
#
# arab:0.028249751776456833
#
# bulgarian:0.011704816482961178
#
# cebuano:0.009371996857225895
#
# chines:0.009761137887835503
#
# mandarin:0.01035877875983715
#
# chines:0.012375743128359318
#
# cantones:0.012341341003775597
#
# croatian:0.01643015630543232
#
# czech:0.009907443076372147
#
# danish:0.004052551928907633
#
# dutch:0.004988559056073427
#
# english:0.007624721620231867
#
# ewe:0.011910039000213146
#
# farsi:0.019579697400331497
#
# persian:0.014622785151004791
#
# finnish:0.016284460201859474
#
# french:0.02988160029053688
#
# german:0.01809448003768921
#
# haitian:0.02884206548333168
#
# veracruz:0.04264366999268532
#
# indonesian:0.028685078024864197
#
# italian:0.021918367594480515
#
# japanes:0.028185293078422546
#
# javanes:0.023623546585440636
#
# korean:0.02766532450914383
#
# latin:0.02155902422964573
#
# malagasi:0.0304483063519001
#
# portugues:0.02925611473619938
#
# romanian:0.018789926543831825
#
# russian:0.009192469529807568
#
# somali:0.0069886320270597935
#
# spanish:0.005757613107562065
#
# swedish:0.0074126506224274635
#
# thai:0.009012243710458279
#
# ukrainian:0.010507375933229923
#
# urdu:0.017805807292461395
#
# vietnames:0.029117511585354805
#
# mani:0.010681803338229656
#
# 2370::Please provide your feedbacks to and it would definitely help us to further improve our service::0.00025705937878228724
#
# pleas:0.16187803447246552
#
# provid:0.13151763379573822
#
# feedback:0.5838593244552612
#
# would:0.042676474899053574
#
# definit:0.010326703079044819
#
# help:0.003168815979734063
#
# us:0.04278866946697235
#
# improv:0.011103146709501743
#
# servic:0.012681389227509499
#
# 2371::Translations: Italian Thanks to Emmanuel Avetta Portuguese Thanks to Emmanuel Avetta Korean Thanks to Hungaria::0.00022966781398281455
#
# translat:0.4254579544067383
#
# italian:0.124229297041893
#
# thank:0.1707615852355957
#
# emmanuel:0.09609135240316391
#
# portugues:0.04694278538227081
#
# thank:0.058085255324840546
#
# emmanuel:0.04031188040971756
#
# korean:0.021260537207126617
#
# thank:0.016859281808137894
#
# 2372::Please let us know if you find a bug# or you have a complaint# concern# or suggestion to help us improve::0.0002280935295857489
#
# pleas:0.26368024945259094
#
# let:0.3515282869338989
#
# us:0.1268918514251709
#
# know:0.05082426592707634
#
# find:0.02528812550008297
#
# bug:0.035865478217601776
#
# complaint:0.05461931228637695
#
# concern:0.011345830745995045
#
# suggest:0.005829465575516224
#
# help:0.02871779352426529
#
# us:0.017859678715467453
#
# improv:0.027549482882022858
#
# 2373::Please if you enjoy the app give us ;)Thank you::0.0002269399119541049
#
# pleas:0.3177345097064972
#
# enjoy:0.5289911031723022
#
# app:0.057942476123571396
#
# give:0.015028259716928005
#
# us:0.02803954854607582
#
# thank:0.052264049649238586
#
# 2374::Please let us know by going to our forum::0.00021344321430660784
#
# pleas:0.468394935131073
#
# let:0.07984794676303864
#
# us:0.09894643723964691
#
# know:0.2508862018585205
#
# go:0.03211687505245209
#
# forum:0.06980767846107483
#
# 2375::?App and Quran fully translated to: Bahasa Indonesia# Bahasa Melayu# Deutsch# English# Espaol# Franais# Italiano# Nederlands# Portugus# Trke# # # # # #::0.00021333478798624128
#
# app:0.4170577824115753
#
# quran:0.2582128345966339
#
# fulli:0.13334956765174866
#
# translat:0.04359350726008415
#
# bahasa:0.03238963335752487
#
# indonesia:0.019435396417975426
#
# bahasa:0.013077921234071255
#
# melayu:0.013227253220975399
#
# deutsch:0.008764916099607944
#
# english:0.008753683418035507
#
# italiano:0.013413150794804096
#
# nederland:0.01994357816874981
#
# portugu:0.018780605867505074
#
# 2376::Should you have questions# suggestions or tech problems::0.00018407992320135236
#
# question:0.4002373516559601
#
# suggest:0.2922287583351135
#
# tech:0.1593395620584488
#
# problem:0.1481943279504776
#
# 2377::Al'Quran Bahasa Indonesia::0.0001747700007399544
#
# al:0.5521655678749084
#
# quran:0.16862112283706665
#
# bahasa:0.15807321667671204
#
# indonesia:0.12114009261131287
#
# 2378::For HD version please install Body Symbol HD more infomation about this app more about us::0.00017119797121267766
#
# hd:0.6649298071861267
#
# version:0.16624191403388977
#
# pleas:0.0521090105175972
#
# instal:0.026229269802570343
#
# bodi:0.008927194401621819
#
# symbol:0.010589986108243465
#
# hd:0.0058056958951056
#
# infom:0.021716903895139694
#
# app:0.013228503055870533
#
# us:0.03022175095975399
#
# 2379::We can only correspond in English# Japanese# Korean# traditional Chinese# and Indonesian::0.00016843162302393466
#
# correspond:0.5639594793319702
#
# english:0.1888730674982071
#
# japanes:0.1423523724079132
#
# korean:0.05243334174156189
#
# tradit:0.029134629294276237
#
# chines:0.01435160357505083
#
# indonesian:0.008895562030375004
#
# 2380::Show us some love to cheer us up :-) And help us become the worlds best Launcher::0.00014658145664725453
#
# show:0.0837007686495781
#
# us:0.13150811195373535
#
# love:0.028081584721803665
#
# cheer:0.015449034981429577
#
# us:0.3258116841316223
#
# help:0.020005397498607635
#
# us:0.30093467235565186
#
# becom:0.02512376755475998
#
# world:0.008803428150713444
#
# best:0.050867605954408646
#
# launcher:0.009713876061141491
#
# 2381::page at us if you have any problems or suggestions We are happy to help::0.00014407263370230794
#
# page:0.07882554084062576
#
# us:0.2053367793560028
#
# problem:0.2841191291809082
#
# suggest:0.12255726009607315
#
# happi:0.2902052402496338
#
# help:0.018956076353788376
#
# 2382::Please don't forget to leave us a rating::0.00013162953837309033
#
# pleas:0.24918575584888458
#
# forget:0.5678793787956238
#
# leav:0.0932583436369896
#
# us:0.047499172389507294
#
# rate:0.04217742756009102
#
# 2383::Catalan-catalChinese-Croatian-hrvatski jezikCzech-etinaDanish-danskDutch-NederlandsEnglishEstonian-eestiFinnish-suomiFrench-franaisGeorgian-German-DeutschGreek-Hebrew-Hindi-# Hungarian-magyarIndonesian-Bahasa IndonesiaItalian-italianoKannada-KoreanLatvian-latvieu valodaLithuanian-lietuvi kalbaMacedonian Norwegian-NorskPersianPolish-polszczyznaPortuguese-portugusPunjabiRomanian-limba romnRussian-Serbian::0.0001070799698936753
#
# catalan:0.44854652881622314
#
# croatian:0.20636315643787384
#
# hrvatski:0.18901394307613373
#
# german:0.04076612368226051
#
# hebrew:0.023860156536102295
#
# hindi:0.009415742941200733
#
# hungarian:0.01552099734544754
#
# bahasa:0.015641845762729645
#
# norwegian:0.018076056614518166
#
# limba:0.015951989218592644
#
# serbian:0.016843561083078384
#
# 2384::Catalan-catalChinese-Croatian-hrvatski jezikCzech-etinaDanish-danskDutch-NederlandsEnglishEstonian-eestiFinnish-suomiFrench-franaisGeorgian-German-DeutschGreek-Hebrew-Hindi-# Hungarian-magyarIndonesian-Bahasa IndonesiaItalian-italianoKannada-Korean-# Latvian-latvieu valodaLithuanian-lietuvi kalbaMacedonian Norwegian-NorskPersian-Polish-polszczyznaPortuguese-portugusPunjabi-# Romanian-limba romnRussian-Serbian::0.00010684079461498186
#
# catalan:0.4162192940711975
#
# croatian:0.19149035215377808
#
# hrvatski:0.1540614515542984
#
# german:0.07137029618024826
#
# hebrew:0.03561108931899071
#
# hindi:0.03133007884025574
#
# hungarian:0.01663198135793209
#
# bahasa:0.014838303439319134
#
# korean:0.014095271937549114
#
# latvian:0.005126012489199638
#
# norwegian:0.00516214594244957
#
# polish:0.004251750186085701
#
# romanian:0.012830146588385105
#
# limba:0.012552903965115547
#
# serbian:0.014428947120904922
#
# 2385::helps us improve the application rapidlyv: Stability improvements::7.767330680508167e-05
#
# help:0.17088544368743896
#
# us:0.349565327167511
#
# improv:0.07331449538469315
#
# applic:0.06482246518135071
#
# stabil:0.3013385534286499
#
# improv:0.04007377848029137

# %%
with open("attention_pooling_porter_permission_sentences.txt", "w") as target:
    pos_keys = {}
    for idx, entry in enumerate(sorted_positives[::-1]):
        weights = show_attention_weights(model, entry)
        max_index = weights.index(max(weights))
        mit = entry.preprocessed_sentence[max_index] #most_important_token
        pos_keys[mit] = pos_keys[mit]+1 if mit in pos_keys else 1
        pairs = [(t,w)for t,w in zip(entry.preprocessed_sentence,weights)]
        print("{}::{}::{}\n".format(idx+1, entry.sentence, entry.prediction_result))
        #target.write("{}::{}::{}\n".format(idx+1, entry.sentence, entry.prediction_result))
        #target.write("{}\n".format(str(entry.prediction_result)).replace(".", ","))
        for t,w in pairs:
            print("{}:{}".format(t,w))
            #target.write("{}:{}\n".format(t,w))
            target.write("{0}:{1:.2f} ".format(t,w))
        print()
        target.write("\n")
    sorted_lst = sorted(pos_keys.items(), key=lambda kv: kv[1], reverse=True)
    target.write("KEYWORDS\n")
    for key, value in sorted_lst:
        target.write("{}:{}\n".format(key, value))
# Out:
# 1::Buy furniture and home materials on Houzz using Android Pay for a simpler buying experience::0.0021530925296247005
#
# buy:0.5924994349479675
# furnitur:0.14748267829418182
# home:0.0700245350599289
# materi:0.029997332021594048
# houzz:0.03747894987463951
# use:0.015370185486972332
# android:0.04652613401412964
# pay:0.026047926396131516
# simpler:0.012652904726564884
# buy:0.012595782987773418
# experi:0.00932406261563301
#
# 2::But you need to pay for some items especially rare fishes and rare fish food::0.004744844511151314
#
# need:0.4443235993385315
# pay:0.1990099847316742
# item:0.07275120913982391
# especi:0.09546884894371033
# rare:0.06382771581411362
# fish:0.05695497989654541
# rare:0.023307252675294876
# fish:0.024093737825751305
# food:0.020262761041522026
#
# 3::price app Body: Free There is some paid items::0.005237860139459372
#
# price:0.3650326132774353
# app:0.21229758858680725
# bodi:0.18432223796844482
# free:0.1274898201227188
# paid:0.07738626003265381
# item:0.033471446484327316
#
# 4::Multiple options for sharing ZEDGE content with other apps and people::0.017887959256768227
#
# multipl:0.4585115909576416
# option:0.23020175099372864
# share:0.12752342224121094
# zedg:0.12489304691553116
# content:0.03220895677804947
# app:0.017469152808189392
# peopl:0.00919207464903593
#
# 5::Post videos you like on YouTube or Vimeo to a blog+::0.02586871199309826
#
# post:0.7392277717590332
# video:0.12970919907093048
# like:0.06512697041034698
# youtub:0.03665924072265625
# vimeo:0.007479839958250523
# blog:0.021796939894557
#
# 6::BIG TIME GANGSTA is free to play# but you can choose to pay real money for some extra items::0.04532896354794502
#
# big:0.4163057208061218
# time:0.2082720696926117
# gangsta:0.12978605926036835
# free:0.08351535350084305
# play:0.045809317380189896
# choos:0.018674423918128014
# pay:0.019280612468719482
# real:0.021001774817705154
# money:0.01851164549589157
# extra:0.021818000823259354
# item:0.01702503114938736
#
# 7::You will always know the true caller# even if they are not in your address book::0.05791202932596207
#
# alway:0.4177854061126709
# know:0.2101491242647171
# true:0.13688015937805176
# caller:0.04028921574354172
# even:0.05967431887984276
# address:0.04760052263736725
# book:0.08762125670909882
#
# 8::It also allows you to display and operate your Google calendar::0.0632256343960762
#
# also:0.31829091906547546
# allow:0.11481241136789322
# display:0.2782466411590576
# oper:0.14289668202400208
# googl:0.061671607196331024
# calendar:0.08408176898956299
#
# 9::With magicApp you can choose your own phone number to get unlimited calling to the U::0.06765440851449966
#
# magicapp:0.6720179319381714
# choos:0.18003274500370026
# phone:0.061609093099832535
# number:0.032014429569244385
# get:0.024256234988570213
# unlimit:0.011136531829833984
# call:0.004963922780007124
# u:0.013969031162559986
#
# 10::This application will deeply analyze your phonebook and bring it close to perfection::0.1090109795331955
#
# applic:0.5868305563926697
# deepli:0.21652798354625702
# analyz:0.09027256071567535
# phonebook:0.01946185529232025
# bring:0.014490475878119469
# close:0.04345402121543884
# perfect:0.028962522745132446
#
# 11::You can recall a special memory from your photos and share them with your friends and family 1::0.12492982298135757
#
# recal:0.6601684093475342
# special:0.18486899137496948
# memori:0.05200117081403732
# photo:0.027137061581015587
# share:0.01809360831975937
# friend:0.026805410161614418
# famili:0.030925365164875984
#
# 12::?(If you use Gmail or Google Apps# it happens automatically)::0.19776342809200287
#
# use:0.4071520268917084
# gmail:0.17952460050582886
# googl:0.16259725391864777
# app:0.14184321463108063
# happen:0.07193221896886826
# automat:0.03695066645741463
#
# 13::Be the first to try our recent updates# report bugs# and contact developers::0.24261397123336792
#
# first:0.22447338700294495
# tri:0.3042665123939514
# recent:0.23550164699554443
# updat:0.1432793289422989
# report:0.045513708144426346
# bug:0.0204521045088768
# contact:0.013060261495411396
# develop:0.013452991843223572
#
# 14::Signal uses your existing phone number and address book::0.3333396911621094
#
# signal:0.4520450234413147
# use:0.18823546171188354
# exist:0.11716247349977493
# phone:0.08072396367788315
# number:0.04970487579703331
# address:0.03944407030940056
# book:0.07268410176038742
#
# 15::On Google Wallet# you can configure parental controls to avoid unintentional purchases NEED HELP::0.34687766432762146
#
# googl:0.6632529497146606
# wallet:0.09607461839914322
# configur:0.05113965645432472
# parent:0.04270269349217415
# control:0.02978104166686535
# avoid:0.0264311321079731
# unintent:0.045125629752874374
# purchas:0.017409363761544228
# need:0.01902109570801258
# help:0.009061736054718494
#
# 16::Once you run out of bonuses you can get it by watching advertisement in special section Get Free Bonuses# sharing CFC on your Facebook page# inviting friends or buying it at pretty low prices (directly from the application)::0.3687509000301361
#
# run:0.4878270924091339
# bonus:0.08663002401590347
# get:0.04596980661153793
# watch:0.022154031321406364
# advertis:0.018009958788752556
# special:0.013537388294935226
# section:0.01085775438696146
# get:0.008370877243578434
# free:0.015174824744462967
# bonus:0.029361382126808167
# share:0.05044817179441452
# cfc:0.015683207660913467
# facebook:0.015266774222254753
# page:0.030119212344288826
# invit:0.025656919926404953
# friend:0.01360625121742487
# buy:0.020955577492713928
# pretti:0.03261953592300415
# low:0.017837300896644592
# price:0.015703262761235237
# directli:0.00995561946183443
# applic:0.014255068264901638
#
# 17::By using the whitelist and the various modes of blocking# you will have the opportunity to define precisely the circle of people who can get access to you::0.3969394266605377
#
# use:0.2807588577270508
# whitelist:0.17357422411441803
# variou:0.07827509939670563
# mode:0.1579548567533493
# block:0.09572085738182068
# opportun:0.030701884999871254
# defin:0.028960296884179115
# precis:0.0336930975317955
# circl:0.014548306353390217
# peopl:0.014499868266284466
# get:0.07148505002260208
# access:0.019827570766210556
#
# 18::Take notes# highlights# and bookmarks in the app and sync to all your devices::0.4148174524307251
#
# take:0.4855041801929474
# note:0.13823457062244415
# highlight:0.1770213395357132
# bookmark:0.031157590448856354
# app:0.0755559578537941
# sync:0.03333695977926254
# devic:0.059189338237047195
#
# 19::Create strong passwords for all your accounts::0.47612202167510986
#
# creat:0.686966598033905
# strong:0.20511479675769806
# password:0.08824384957551956
# account:0.019674718379974365
#
# 20::Android photo gallery features: Instagram and Facebook photo downloader with beauty camera effects::0.5421309471130371
#
# android:0.611275851726532
# photo:0.09891794621944427
# galleri:0.09255169332027435
# featur:0.04234777018427849
# instagram:0.007532569579780102
# facebook:0.016229135915637016
# photo:0.02137833647429943
# download:0.057105857878923416
# beauti:0.016563335433602333
# camera:0.010465554893016815
# effect:0.025632010772824287
#
# 21::Share Facebook status updates on Tumblr or LinkedIn+::0.556036651134491
#
# share:0.31170737743377686
# facebook:0.09913511574268341
# statu:0.26832160353660583
# updat:0.22745944559574127
# tumblr:0.08636528253555298
# linkedin:0.007011203095316887
#
# 22::Android integration : share pictures from any Android application to set pictures for your contacts Theme support::0.6118242144584656
#
# android:0.46408745646476746
# integr:0.12055039405822754
# share:0.23771560192108154
# pictur:0.07365342229604721
# android:0.024372434243559837
# applic:0.027054429054260254
# set:0.017068203538656235
# pictur:0.010185247287154198
# contact:0.002051105722784996
# theme:0.00925151165574789
# support:0.014010259881615639
#
# 23::Block numbers# if needed::0.6198852062225342
#
# block:0.6973493099212646
# number:0.15863080322742462
# need:0.1440199464559555
#
# 24::Edit photos with this wonderful retro photo editor and share with the world on Facebook#pinterest#instagram and flickr::0.6236863136291504
#
# edit:0.31854259967803955
# photo:0.1275900900363922
# wonder:0.15672820806503296
# retro:0.11940918862819672
# photo:0.1584496647119522
# editor:0.050463270395994186
# share:0.021539855748414993
# world:0.012904767878353596
# facebook:0.015692511573433876
# pinterest:0.01165669597685337
# instagram:0.004582766443490982
# flickr:0.0024403617717325687
#
# 25::With more updates and features on the way# you can: Log on to your account around the world View your account balances and transaction history Move money Exact features depend on the HSBC services available in your country To log on to this app you must be an HSBC Personal Internet Banking customer::0.67244952917099
#
# updat:0.5334973931312561
# featur:0.13938239216804504
# way:0.055839814245700836
# log:0.0072923400439321995
# account:0.00453736400231719
# around:0.005660532973706722
# world:0.011965373530983925
# view:0.004249221179634333
# account:0.00279390555806458
# balanc:0.0049453903920948505
# transact:0.005895278416574001
# histori:0.00918356329202652
# move:0.007305352482944727
# money:0.005716292653232813
# exact:0.00427293311804533
# featur:0.008390882983803749
# depend:0.006229901220649481
# hsbc:0.002155778929591179
# servic:0.0030436853412538767
# avail:0.01997099071741104
# countri:0.015251247212290764
# log:0.0020156532991677523
# app:0.01786244846880436
# must:0.04655787721276283
# hsbc:0.029778234660625458
# person:0.002594825578853488
# internet:0.006962109822779894
# bank:0.01270734891295433
# custom:0.023941749706864357
#
# 26::* It can also synchronize your events in Yahoo::0.6766391396522522
#
# also:0.8071789741516113
# synchron:0.11434232443571091
# event:0.05182719975709915
# yahoo:0.02665148861706257
#
# 27::Supported Apps Missed Calls Unread SMS Calendar Appointments Gmail HTC Mail Samsung Email K-9/Kaiten Mail Battery Level Stock Email Google Hangouts (Android +) WhatsApp (Android +) Google Play (Android +) Google Voice StarbucksNotes Unread SMS provides the number of unread messages# not unread conversations::0.6932337880134583
#
# support:0.2395341396331787
# app:0.05780154466629028
# miss:0.012109855189919472
# call:0.004091699607670307
# unread:0.009716651402413845
# sm:0.018125656992197037
# calendar:0.0050782207399606705
# appoint:0.004121911711990833
# gmail:0.002963928272947669
# htc:0.01087463740259409
# mail:0.027626758441329002
# samsung:0.046568457037210464
# email:0.023005936294794083
# k:0.0437559112906456
# kaiten:0.013893898576498032
# mail:0.019529493525624275
# batteri:0.021314553916454315
# level:0.01335975807160139
# stock:0.01012541726231575
# email:0.017347967252135277
# googl:0.01714102365076542
# hangout:0.016878414899110794
# android:0.04206322878599167
# whatsapp:0.022396579384803772
# android:0.06994897872209549
# googl:0.023332780227065086
# play:0.02277953363955021
# android:0.04577770084142685
# googl:0.02627152018249035
# voic:0.006215110886842012
# unread:0.007418585475534201
# sm:0.002310306066647172
# provid:0.0018740348750725389
# number:0.0018576731672510505
# unread:0.006453417241573334
# messag:0.010178811848163605
# unread:0.021528584882616997
# convers:0.054627399891614914
#
# 28::Share your favorite events on Twitter and Facebook Add any event to your calendarGet Your Tickets from the top Venues: New Amsterdam Theatre# Minskoff Theatre# Radio City Music Hall# Gerswin Theatre ::0.7023288607597351
#
# share:0.33988311886787415
# favorit:0.13159583508968353
# event:0.05787846818566322
# twitter:0.04753069579601288
# facebook:0.04644186422228813
# add:0.03209991380572319
# event:0.024893581867218018
# ticket:0.02332836389541626
# top:0.03460272029042244
# venu:0.013418486341834068
# new:0.02341957949101925
# amsterdam:0.010576154105365276
# theatr:0.009366397745907307
# theatr:0.008703500032424927
# radio:0.07304622232913971
# citi:0.06824642419815063
# music:0.03086022101342678
# hall:0.013637617230415344
# theatr:0.010470868088304996
#
# 29::Link your Disney Movie Rewards account directly to your Fandango VIP account and earn points for seeing Disney movies when you buy tickets with Fandango Thanks for using our app::0.7111606001853943
#
# link:0.35660213232040405
# disney:0.14119237661361694
# movi:0.2569006383419037
# reward:0.026513833552598953
# account:0.0026527331210672855
# directli:0.002649573842063546
# fandango:0.0057007428258657455
# vip:0.020088305696845055
# account:0.0038865553215146065
# earn:0.003011367516592145
# point:0.0055742510594427586
# see:0.008186698891222477
# disney:0.018915221095085144
# movi:0.01271230448037386
# buy:0.008111095055937767
# ticket:0.010933459736406803
# fandango:0.010130571201443672
# thank:0.031232411041855812
# use:0.04667329043149948
# app:0.028332650661468506
#
# 30::We support Facebook Pictures# YouTube Videos# Dropbox files# Photos# PDFs# and much more::0.716515302658081
#
# support:0.8067049384117126
# facebook:0.029053136706352234
# pictur:0.01593782566487789
# youtub:0.003555768635123968
# video:0.003337762551382184
# dropbox:0.0015894640237092972
# file:0.0054948590695858
# photo:0.007406802847981453
# pdf:0.03517678380012512
# much:0.0917426198720932
#
# 31::Type Mail is the best free email app to manage all your accounts from one place::0.7259823083877563
#
# type:0.3624843657016754
# mail:0.21045035123825073
# best:0.13981537520885468
# free:0.04347005486488342
# email:0.06352456659078598
# app:0.0601922981441021
# manag:0.04946755990386009
# account:0.014906820841133595
# one:0.033023521304130554
# place:0.022665109485387802
#
# 32::Share photos to Instagram# Facebook# Twitter# Google+ or anywhere elseFollow @NoCrop_RC on Instagram for news# updates and to see fantastic photos::0.763598620891571
#
# share:0.177780419588089
# photo:0.1805819272994995
# instagram:0.0431353859603405
# facebook:0.057488635182380676
# twitter:0.0714886263012886
# googl:0.03470933809876442
# anywher:0.045945458114147186
# nocrop:0.0393095426261425
# rc:0.051390402019023895
# instagram:0.016322100535035133
# news:0.05764737352728844
# updat:0.13200633227825165
# see:0.059565331786870956
# fantast:0.022357182577252388
# photo:0.010272002778947353
#
# 33::Use Facebook to sign in or register::0.773731529712677
#
# use:0.7380157113075256
# facebook:0.12572354078292847
# sign:0.08978680521249771
# regist:0.046473897993564606
#
# 34::support {at} Stay updated with the latest news: Although CallApp contacts works best as your sole dialer# it may be used alongside most other dialers::0.7955012917518616
#
# support:0.4068487584590912
# stay:0.08285888284444809
# updat:0.05086158961057663
# latest:0.04464392736554146
# news:0.04757086932659149
# although:0.017568903043866158
# callapp:0.010258638300001621
# contact:0.0073996433056890965
# work:0.1253981739282608
# best:0.05587504804134369
# sole:0.02751551754772663
# dialer:0.018940359354019165
# may:0.03354629501700401
# use:0.026108235120773315
# alongsid:0.029422255232930183
# dialer:0.015182923525571823
#
# 35::Log into your account from your mobile phone# tablet or computer and dont miss a single call::0.7983384132385254
#
# log:0.33258339762687683
# account:0.04091457277536392
# mobil:0.05892043933272362
# phone:0.2828027307987213
# tablet:0.14106659591197968
# comput:0.0382038839161396
# dont:0.03216902166604996
# miss:0.024645976722240448
# singl:0.041852813214063644
# call:0.006840442772954702
#
# 36::* Searching function will help you find what you need right away You can find app on your phone# contacts# and even other information at once::0.8008429408073425
#
# search:0.21422119438648224
# function:0.07380291074514389
# help:0.4036238193511963
# find:0.06284531950950623
# need:0.05527811869978905
# right:0.03519406542181969
# away:0.041293565183877945
# find:0.02577109821140766
# app:0.020285628736019135
# phone:0.02091694250702858
# contact:0.02278667688369751
# even:0.015239772386848927
# inform:0.00874091312289238
#
# 37::Everyday banking on your mobile is now as simple as in NetBank# with fast access to your accounts# balances and transfers::0.8054206371307373
#
# everyday:0.26130062341690063
# bank:0.2961462438106537
# mobil:0.14765316247940063
# simpl:0.05354856327176094
# netbank:0.041729602962732315
# fast:0.06962552666664124
# access:0.037439920008182526
# account:0.016743408516049385
# balanc:0.022655528038740158
# transfer:0.053157441318035126
#
# 38::Supports Waypoints# Satellite-Imagery# POI# Favorites# Contacts# etc::0.8375913500785828
#
# support:0.23636628687381744
# waypoint:0.5913597941398621
# satellit:0.07741333544254303
# imageri:0.030365729704499245
# poi:0.03960992768406868
# favorit:0.011682473123073578
# contact:0.0026583592407405376
# etc:0.01054397877305746
#
# 39::Take a photo of your masterpiece and don't forget to share it with your friends on Facebook and Twitter::0.8507883548736572
#
# take:0.5404401421546936
# photo:0.243325337767601
# masterpiec:0.09511080384254456
# forget:0.03135402500629425
# share:0.03993473947048187
# friend:0.026583410799503326
# facebook:0.008713473565876484
# twitter:0.014538010582327843
#
# 40::WhatsApp works with your phone number# just like SMS# and integrates seamlessly with your phones existing address book::0.872268795967102
#
# whatsapp:0.27918246388435364
# work:0.25089457631111145
# phone:0.16518191993236542
# number:0.045906275510787964
# like:0.0586056262254715
# sm:0.026076778769493103
# integr:0.0060780770145356655
# seamlessli:0.017577605322003365
# phone:0.05277935415506363
# exist:0.03149431198835373
# address:0.042054396122694016
# book:0.024168632924556732
#
# 41::Softonic# September FEATURES intuitive navigation with smooth transitions between day# week and month view 48 colors per calendar# per-event colors (if supported by the event's calendar) flexible recurrences year view birthdays from your contacts (or without contacts)::0.908696711063385
#
# softon:0.43002232909202576
# septemb:0.1213713139295578
# featur:0.34873533248901367
# intuit:0.03996977582573891
# navig:0.006492692977190018
# smooth:0.01255839318037033
# transit:0.001852908986620605
# day:0.0008988886256702244
# week:0.00033693460864014924
# month:0.0002831383899319917
# view:0.002307872287929058
# color:0.0031222861725836992
# per:0.0012385040754452348
# calendar:0.0016855006106197834
# per:0.00047376210568472743
# event:0.001428890391252935
# color:0.0024128351360559464
# support:0.001865349244326353
# event:0.0019817575812339783
# calendar:0.0033377951476722956
# flexibl:0.0018213887233287096
# recurr:0.0010052076540887356
# year:0.0025476429145783186
# view:0.0016011323314160109
# birthday:0.0019290122436359525
# contact:0.0017833140445873141
# without:0.003553832182660699
# contact:0.00338231073692441
#
# 42::Turn your LockScreen into a Smart & Beautiful Access your favorite apps# contacts & media::0.9098835587501526
#
# turn:0.13861601054668427
# lockscreen:0.6055684685707092
# smart:0.1879417449235916
# beauti:0.025608452036976814
# access:0.006835618056356907
# favorit:0.008668930269777775
# app:0.013514932245016098
# contact:0.00827943254262209
# media:0.004966382868587971
#
# 43::Add to-do by forwarding an email to Make your to-do list even more useful by uploading files# sound recordings and photos to your tasks from your computer# Dropbox# or Google Drive Print# Export and share your lists & tasks Never forget to call back with Any::0.9129248261451721
#
# add:0.4345201849937439
# forward:0.14479579031467438
# email:0.10343219339847565
# make:0.07291927188634872
# list:0.025405000895261765
# even:0.01608220674097538
# use:0.008527485653758049
# upload:0.003785279579460621
# file:0.004900055471807718
# sound:0.0162295401096344
# record:0.009763556532561779
# photo:0.005580347031354904
# task:0.00756923109292984
# comput:0.009432340040802956
# dropbox:0.0047418540343642235
# googl:0.007422821596264839
# drive:0.009555944241583347
# print:0.0058022611774504185
# export:0.0032597107347100973
# share:0.007230805233120918
# list:0.012624995782971382
# task:0.011709872633218765
# never:0.01822534389793873
# forget:0.02599368803203106
# call:0.021505026146769524
# back:0.008985260501503944
#
# 44::If your contacts arent on Textfree# they might have to pay regular carrier charges for texts and pictures::0.9133908152580261
#
# contact:0.20628678798675537
# arent:0.06664270907640457
# textfre:0.0506819412112236
# might:0.11682785302400589
# pay:0.04151387885212898
# regular:0.018970845267176628
# carrier:0.020367328077554703
# charg:0.0198809914290905
# text:0.027097195386886597
# pictur:0.43173059821128845
#
# 45::Schedule backups to run at a certain time Restore apps from nandroid backups Backup/Restore text messages# bookmarks# accounts# etc::0.923004686832428
#
# schedul:0.5835708379745483
# backup:0.22082410752773285
# run:0.023196931928396225
# certain:0.01964886672794819
# time:0.014264165423810482
# restor:0.007060685195028782
# app:0.004280341323465109
# nandroid:0.003003221470862627
# backup:0.00416063517332077
# backup:0.01385380607098341
# restor:0.008189752697944641
# text:0.025061681866645813
# messag:0.02822737954556942
# bookmark:0.04074730724096298
# account:0.0018778506200760603
# etc:0.0020323721691966057
#
# 46::Contact specific notifications for certain notification types::0.9250058531761169
#
# contact:0.4133501648902893
# specif:0.07057418674230576
# notif:0.0436573289334774
# certain:0.019324569031596184
# notif:0.022342246025800705
# type:0.4307514727115631
#
# 47::Login or register with Facebook and Google+ Record sounds::0.9292296767234802
#
# login:0.5328232645988464
# regist:0.08371519297361374
# facebook:0.03283025696873665
# googl:0.08253611624240875
# record:0.12118009477853775
# sound:0.14691507816314697
#
# 48::Account Protection: Ensures the safety of your personal accounts ::0.9311118125915527
#
# account:0.319125235080719
# protect:0.10362974554300308
# ensur:0.20476870238780975
# safeti:0.243885800242424
# person:0.09137808531522751
# account:0.03721240907907486
#
# 49::VIPs and marking contacts as VIP so that they appear with a crown ---Like Mail Wise::0.9312297701835632
#
# vip:0.28000521659851074
# mark:0.13038182258605957
# contact:0.04346265271306038
# vip:0.033150289207696915
# appear:0.04300014302134514
# crown:0.05134114623069763
# like:0.25255274772644043
# mail:0.08965212106704712
# wise:0.07645381987094879
#
# 50::C+D19456:D19478allApp is the #1 Caller-ID / Dialer / Contacts app & #45 most downloaded app in Google Play::0.9324217438697815
#
# c:0.4686518609523773
# caller:0.03093000128865242
# id:0.02042158506810665
# dialer:0.006919251289218664
# contact:0.009443055838346481
# app:0.16085347533226013
# download:0.15738940238952637
# app:0.07099524885416031
# googl:0.026884304359555244
# play:0.04751181975007057
#
# 51::* Profile / Contacts: To pre-fill your information wherever required so that you type less::0.934080183506012
#
# profil:0.35130468010902405
# contact:0.09119270741939545
# pre:0.07661818712949753
# fill:0.07186442613601685
# inform:0.04353177174925804
# wherev:0.03298409655690193
# requir:0.018243366852402687
# type:0.23697346448898315
# less:0.07728731632232666
#
# 52::Reasons for every permission are available here apw# widget# widgets package# widgets pack# scrollable# scrolling# calendar# agenda widget# quickadd# people widget# contacts widget# bookmarks widget# messaging widget# sms widget# facebook widget# twitter widget# honeycomb# ics# ice cream sandwitch **::0.9432587027549744
#
# reason:0.3340719938278198
# everi:0.20718838274478912
# permiss:0.0715392678976059
# avail:0.03600260242819786
# apw:0.03792984038591385
# widget:0.014516027644276619
# widget:0.027091752737760544
# packag:0.007201808039098978
# widget:0.01691071130335331
# pack:0.008831077255308628
# scrollabl:0.0034959502518177032
# scroll:0.0032127320300787687
# calendar:0.001885300618596375
# agenda:0.0011201431043446064
# widget:0.0008957475074566901
# peopl:0.0008116422104649246
# widget:0.06525856256484985
# contact:0.009474702179431915
# widget:0.015291976742446423
# bookmark:0.00700790248811245
# widget:0.010422566905617714
# messag:0.001966285752132535
# widget:0.0038235222455114126
# sm:0.0026366617530584335
# widget:0.017551405355334282
# facebook:0.004078652709722519
# widget:0.011158118024468422
# twitter:0.002897875849157572
# widget:0.0031795736867934465
# honeycomb:0.010010825470089912
# ic:0.017521165311336517
# ice:0.013772029429674149
# cream:0.015334093011915684
# sandwitch:0.015909096226096153
#
# 53::SMS/EMAIL: you enter the message text# you set the contact information (optionally you can send set it up to go without confirmation)# you set the time (more options to come::0.9433878064155579
#
# sm:0.3731527328491211
# email:0.060373704880476
# enter:0.04972560703754425
# messag:0.015485070645809174
# text:0.019041823223233223
# set:0.020190387964248657
# contact:0.019990764558315277
# inform:0.01163577102124691
# option:0.009381535463035107
# send:0.005444289650768042
# set:0.00799987930804491
# go:0.3032155930995941
# without:0.06210166960954666
# confirm:0.013958904892206192
# set:0.006750071886926889
# time:0.007425638847053051
# option:0.009541163221001625
# come:0.004585461225360632
#
# 54::Preview the Ringtone files and assign to contact::0.9447712898254395
#
# preview:0.8832438588142395
# rington:0.10458272695541382
# file:0.009080379270017147
# assign:0.0019212551414966583
# contact:0.001171762472949922
#
# 55::* If you have imported your contact pictures from Facebook# they might not show in the bubbles::0.9467943906784058
#
# import:0.3142867088317871
# contact:0.06449785828590393
# pictur:0.06663748621940613
# facebook:0.0362909734249115
# might:0.02422144263982773
# show:0.39099323749542236
# bubbl:0.10307234525680542
#
# 56::Automatic Spam Blocking with the Community Blacklist::0.9519259929656982
#
# automat:0.41819003224372864
# spam:0.2944616377353668
# block:0.08739051967859268
# commun:0.1777292788028717
# blacklist:0.022228514775633812
#
# 57::Simply select a contact and choose the 'Mobile Top Up' function::0.9525279402732849
#
# simpli:0.2587171792984009
# select:0.2244662195444107
# contact:0.04698373004794121
# choos:0.020834587514400482
# mobil:0.3211006224155426
# top:0.0853666290640831
# function:0.042530957609415054
#
# 58::Authorize the Contacts/Messagesto show you missed calls# messages and even more notifications on your lock screen::0.9532250165939331
#
# author:0.21013329923152924
# contact:0.0646301731467247
# show:0.03259548172354698
# miss:0.023485304787755013
# call:0.0064308904111385345
# messag:0.007705004885792732
# even:0.014636723324656487
# notif:0.011156795546412468
# lock:0.3180482089519501
# screen:0.3111781179904938
#
# 59::The read contacts permission is required for inviting guests# as without it# we cannot provide auto completion for email or guest names# nor display their profile images in events with invitations::0.9600315690040588
#
# read:0.22306691110134125
# contact:0.04098210856318474
# permiss:0.01664235256612301
# requir:0.02355337142944336
# invit:0.007553372997790575
# guest:0.012126149609684944
# without:0.020374221727252007
# provid:0.023152649402618408
# auto:0.014177379198372364
# complet:0.011152238585054874
# email:0.023012235760688782
# guest:0.02945517562329769
# name:0.021323541179299355
# display:0.014518306590616703
# profil:0.017501350492239
# imag:0.028589216992259026
# event:0.3837353587150574
# invit:0.08908405154943466
#
# 60::GROUP CHAT: Enjoy group chats with your contacts so you can easily stay in touch with your friends or family::0.9600366353988647
#
# group:0.3357993960380554
# chat:0.0927056223154068
# enjoy:0.0798657014966011
# group:0.08815019577741623
# chat:0.025548657402396202
# contact:0.22396320104599
# easili:0.041110385209321976
# stay:0.03233623877167702
# touch:0.05143548175692558
# friend:0.014915356412529945
# famili:0.01416974887251854
#
# 61::TechCrunchFeature List Works with all types of email Gmail# Yahoo Mail# Outlook# iCloud# Google Apps# Microsoft Exchange# Office # AOL and other IMAP accounts::0.960601806640625
#
# list:0.3197192847728729
# work:0.2201676070690155
# type:0.1501394510269165
# email:0.05745570361614227
# gmail:0.02066134102642536
# yahoo:0.007699718698859215
# mail:0.027860162779688835
# outlook:0.018888462334871292
# icloud:0.023071877658367157
# googl:0.011447415687143803
# app:0.037497736513614655
# microsoft:0.03599148243665695
# exchang:0.011288403533399105
# offic:0.016573568806052208
# aol:0.014142008498311043
# imap:0.02221415750682354
# account:0.005181570071727037
#
# 62::Note: this app requests access to your contacts# but solely for the purpose of setting contact-specific ringtones Source code is available at::0.9613399505615234
#
# note:0.36854287981987
# app:0.10764621943235397
# request:0.03600882366299629
# access:0.003393096150830388
# contact:0.005216648802161217
# sole:0.11983121931552887
# purpos:0.022400278598070145
# set:0.012245186604559422
# contact:0.014983558095991611
# specif:0.14216823875904083
# rington:0.030047539621591568
# sourc:0.07094264775514603
# code:0.048263050615787506
# avail:0.01831045374274254
#
# 63::HIGHLIGHTS OF LOCX: Protect in extraordinary ways: Lock the apps you use everyday Real Safety Messages# Email# Facebook and Contacts more easily# safer and even more intelligently::0.9641788005828857
#
# highlight:0.43181219696998596
# locx:0.10062037408351898
# protect:0.02323208749294281
# extraordinari:0.010540440678596497
# way:0.12131920456886292
# lock:0.08245937526226044
# app:0.05055581405758858
# use:0.014444155618548393
# everyday:0.02447427250444889
# real:0.022564442828297615
# safeti:0.033515024930238724
# messag:0.010059360414743423
# email:0.01801988109946251
# facebook:0.009370186366140842
# contact:0.008144364692270756
# easili:0.009002107195556164
# safer:0.011240273714065552
# even:0.011805464513599873
# intellig:0.006820958573371172
#
# 64::Rate + Review movies from the app & share with other Fandango users via Facebook# Twitter and Google+Account Dont miss out on exclusive deals# the hottest trailer releases# breaking news & more::0.9666347503662109
#
# rate:0.36264947056770325
# review:0.2169901430606842
# movi:0.12774819135665894
# app:0.042489565908908844
# share:0.01795535534620285
# fandango:0.012525128200650215
# user:0.013432231731712818
# via:0.00750844506546855
# facebook:0.01487345714122057
# twitter:0.012777266092598438
# googl:0.0037496730219572783
# account:0.005472101271152496
# dont:0.021030880510807037
# miss:0.013755274005234241
# exclus:0.024746639654040337
# deal:0.01266735140234232
# hottest:0.0035394346341490746
# trailer:0.00932860653847456
# releas:0.018942901864647865
# break:0.029098615050315857
# news:0.02871917188167572
#
# 65::Set as ringtone for android / contact ringtone / alarm sound / sms sound::0.9682077169418335
#
# set:0.4661623239517212
# rington:0.039620541036129
# android:0.04531415179371834
# contact:0.0062636868096888065
# rington:0.0033887354657053947
# alarm:0.18886645138263702
# sound:0.1976614147424698
# sm:0.024615785107016563
# sound:0.028106948360800743
#
# 66::Easily backup and restore apps# sms# mms# call log# calendar# bookmarks# dictionary and contact found on your Android phone::0.9697413444519043
#
# easili:0.12607771158218384
# backup:0.05651137977838516
# restor:0.07768700271844864
# app:0.5735116004943848
# sm:0.11678411066532135
# mm:0.006255934946238995
# call:0.0019787224009633064
# log:0.0016008832026273012
# calendar:0.0066820490173995495
# bookmark:0.006895846221596003
# dictionari:0.003859863616526127
# contact:0.009649272076785564
# found:0.005684415344148874
# android:0.0028429788071662188
# phone:0.003978285472840071
#
# 67::Jorte Cloud (Free) =Sync Jorte Calendar# entries# and Tasks to Jorte Cloud::0.9772694110870361
#
# jort:0.5910636782646179
# cloud:0.12935474514961243
# free:0.05086071044206619
# sync:0.012660014443099499
# jort:0.005860141944140196
# calendar:0.0336841382086277
# entri:0.013883786275982857
# task:0.035595595836639404
# jort:0.08600521087646484
# cloud:0.041031789034605026
#
# 68::CREATE your own QR CODES encoding: > EMAIL ADDRESSES > PHONE NUMBERS > CONTACTS INFORMATIONS > CALENDAR EVENTS > GEOGRAPHIC INFORMATION > SIMPLE TEXT > BOOKMARKS::0.9780828952789307
#
# creat:0.10449447482824326
# qr:0.038863856345415115
# code:0.028934871777892113
# encod:0.03360608220100403
# email:0.05405079200863838
# address:0.01565055549144745
# phone:0.008770107291638851
# number:0.009698514826595783
# contact:0.25494876503944397
# inform:0.15522511303424835
# calendar:0.06157172471284866
# event:0.08543410152196884
# geograph:0.06026625260710716
# inform:0.025788605213165283
# simpl:0.0261911079287529
# text:0.011384973302483559
# bookmark:0.025120094418525696
#
# 69::Premium gives you: Sync across all your devices Secure cloud backup for your account Access to your passwords on our website Priority user supportLearn more about Premium at Visit::0.9800983667373657
#
# premium:0.5642709136009216
# give:0.235359326004982
# sync:0.06513768434524536
# across:0.02602461539208889
# devic:0.019584709778428078
# secur:0.010769300162792206
# cloud:0.004601391032338142
# backup:0.007479372434318066
# account:0.0002590601216070354
# access:0.0026372296269983053
# password:0.0033105886541306973
# websit:0.0029918747022747993
# prioriti:0.0074308100156486034
# user:0.005166009068489075
# premium:0.012375249527394772
# visit:0.032601967453956604
#
# 70::MANAGE_ACCOUNTS# AUTHENTICATE_ACCOUNTS# USE_CREDENTIALS add reddit accounts to system ::0.9804642796516418
#
# manag:0.7798824310302734
# account:0.08432945609092712
# authent:0.05173482745885849
# account:0.0059613436460494995
# use:0.015266941860318184
# credenti:0.006010626442730427
# add:0.018381889909505844
# reddit:0.014654189348220825
# account:0.010839788243174553
# system:0.012938659638166428
#
# 71::Browse PhoneBook Contacts sorted by Location (at Country/State/City level)::0.9826309084892273
#
# brows:0.4965600073337555
# phonebook:0.1056615486741066
# contact:0.05794782564043999
# sort:0.03897000104188919
# locat:0.013634415343403816
# countri:0.010456849820911884
# state:0.16996242105960846
# citi:0.0676010251045227
# level:0.039205946028232574
#
# 72::Free Services: Once you and your contact are both on FreePP# all your calls# texts# and multimedia messages will be free::0.9840098023414612
#
# free:0.43487176299095154
# servic:0.05601850897073746
# contact:0.012342697940766811
# freepp:0.005647442769259214
# call:0.005018197000026703
# text:0.01029050163924694
# multimedia:0.25670957565307617
# messag:0.11274249851703644
# free:0.10635880380868912
#
# 73::just select a picture from your gallery to add a unique wallpaper to your main contacts# sms and call log screens# or to a specific contact::0.9843026399612427
#
# select:0.6403482556343079
# pictur:0.19937974214553833
# galleri:0.02667474001646042
# add:0.00380892027169466
# uniqu:0.003719083033502102
# wallpap:0.0015406463062390685
# main:0.06595642864704132
# contact:0.031067218631505966
# sm:0.018004734069108963
# call:0.005823873449116945
# log:0.0011321650817990303
# screen:0.0008691379334777594
# specif:0.0010252547217532992
# contact:0.0006498507573269308
#
# 74::association of favorite contacts into groups for quick dial::0.9848912358283997
#
# associ:0.37295809388160706
# favorit:0.03805982694029808
# contact:0.025386951863765717
# group:0.4488195776939392
# quick:0.05771126598119736
# dial:0.057064250111579895
#
# 75::Powerful call blocker and blacklist (text SMS blacklist too)::0.985126793384552
#
# power:0.6993850469589233
# call:0.02412561886012554
# blocker:0.007346868049353361
# blacklist:0.040811944752931595
# text:0.10480600595474243
# sm:0.07173226028680801
# blacklist:0.051792290061712265
#
# 76::Private Contacts: Create a list of confidential contacts# send secret-group SMS to your secret contacts right within Folder Locks secure interface::0.9855707883834839
#
# privat:0.16089092195034027
# contact:0.06389909237623215
# creat:0.03060934692621231
# list:0.005618808325380087
# confidenti:0.0035227001644670963
# contact:0.004990586545318365
# send:0.129756897687912
# secret:0.07324328273534775
# group:0.007442617788910866
# sm:0.00821081455796957
# secret:0.01638912409543991
# contact:0.008236384950578213
# right:0.10465829074382782
# within:0.03719270974397659
# folder:0.014446771703660488
# lock:0.01829274743795395
# secur:0.2024904042482376
# interfac:0.11010856181383133
#
# 77::With Simpler you can easily merge all your duplicate contacts and quickly find the contacts your need Simpler Contacts is your new contacts app that makes your address book light# smart and user friendly::0.9865809679031372
#
# simpler:0.0843810886144638
# easili:0.03277385234832764
# merg:0.010923861525952816
# duplic:0.006692927796393633
# contact:0.001804941799491644
# quickli:0.0014596700202673674
# find:0.003484488697722554
# contact:0.005117496941238642
# need:0.07634136080741882
# simpler:0.03190162777900696
# contact:0.10467033088207245
# new:0.042018335312604904
# contact:0.014146170578897
# app:0.20234178006649017
# make:0.09409446269273758
# address:0.0157818291336298
# book:0.17541790008544922
# light:0.06594004482030869
# smart:0.015189309604465961
# user:0.007874046452343464
# friendli:0.007644460070878267
#
# 78::Find & merge contacts with similar names::0.9868212342262268
#
# find:0.2303752303123474
# merg:0.092943474650383
# contact:0.5405706167221069
# similar:0.07264215499162674
# name:0.06346853077411652
#
# 79::what a nice surprise all the contacts# sms # logs were restored thanks"::0.9876726269721985
#
# nice:0.7575202584266663
# surpris:0.05161250755190849
# contact:0.006768421735614538
# sm:0.0015782200498506427
# log:0.04524294659495354
# restor:0.04195132479071617
# thank:0.09532633423805237
#
# 80::Know whos calling you even if you dont have the number as a contact - Personal Blacklist::0.9876742959022522
#
# know:0.4336031377315521
# who:0.06336095929145813
# call:0.2261466383934021
# even:0.0602920725941658
# dont:0.1528652459383011
# number:0.031104885041713715
# contact:0.01279952097684145
# person:0.011018154211342335
# blacklist:0.00880932342261076
#
# 81::READ_CONTACTS The game reads your contacts only to allow you to invite your friends to play getLine1Number::0.9885104298591614
#
# read:0.3268420696258545
# contact:0.046474725008010864
# game:0.028981845825910568
# read:0.020939402282238007
# contact:0.21274323761463165
# allow:0.05486500263214111
# invit:0.05563405156135559
# friend:0.1757497489452362
# play:0.0777699425816536
#
# 82::Wipe contacts# text messages# photos# browser history# calendar# format SD card# and restore mobile device to factory  settings::0.9910326600074768
#
# wipe:0.28471264243125916
# contact:0.10429678112268448
# text:0.028452342376112938
# messag:0.020505456253886223
# photo:0.008648516610264778
# browser:0.021862799301743507
# histori:0.005724804010242224
# calendar:0.00616903230547905
# format:0.0035492137540131807
# sd:0.0039134579710662365
# card:0.0038222160656005144
# restor:0.004509647376835346
# mobil:0.006184984929859638
# devic:0.005865786224603653
# factori:0.34933802485466003
# set:0.14244426786899567
#
# 83::There are four block modes of call blocker: Blacklist All except the whitelist All except contacts All numbersBlock method selection: Hang up MuteOther capabilities: Whitelist::0.9936112761497498
#
# four:0.40959542989730835
# block:0.056735582649707794
# mode:0.0638447031378746
# call:0.00835623499006033
# blocker:0.004116349387913942
# blacklist:0.0463520847260952
# except:0.033733759075403214
# whitelist:0.056544650346040726
# except:0.02857067808508873
# contact:0.07525350898504257
# method:0.07107992470264435
# select:0.08831236511468887
# hang:0.021472789347171783
# capabl:0.016596391797065735
# whitelist:0.019435500726103783
#
# 84::Your Contacts : We need access to your contacts# so that you can invite your friends to join you after you've booked your tickets Your information will kept confidential::0.9936577677726746
#
# contact:0.20083008706569672
# need:0.15429827570915222
# access:0.03403690084815025
# contact:0.012068584561347961
# invit:0.005466805770993233
# friend:0.011922941543161869
# join:0.013565456494688988
# book:0.012036089785397053
# ticket:0.21892572939395905
# inform:0.07551032304763794
# kept:0.04147714376449585
# confidenti:0.21986162662506104
#
# 85::Group memberships and contact lists are managed on your device only# and never stored on our servers::0.9938225746154785
#
# group:0.32729053497314453
# membership:0.06266295164823532
# contact:0.03409551829099655
# list:0.009713116101920605
# manag:0.0113609554246068
# devic:0.009179878048598766
# never:0.2044442594051361
# store:0.2099783569574356
# server:0.13127440214157104
#
# 86::FEATURES+ Caller ID+ Calls & SMS spam block+ Contacts# SMS and Call log backup+ Over 80 customizable themes and infinite wallpapers + Speed dial screen with one touch to call+ Fast dialer search+ Smart contacts sort+ Grid / List contacts view+ Smart cards integrated in your contacts (Gmail# Events# etc::0.9965936541557312
#
# featur:0.16013988852500916
# caller:0.01275213435292244
# id:0.0025775230024009943
# call:0.0368795320391655
# sm:0.01553089078515768
# spam:0.007103662006556988
# block:0.008602278307080269
# contact:0.0031092832796275616
# sm:0.07319308072328568
# call:0.013753728941082954
# log:0.007773987017571926
# backup:0.005396836902946234
# customiz:0.1280333399772644
# theme:0.141238734126091
# infinit:0.028459584340453148
# wallpap:0.09357430785894394
# speed:0.023060817271471024
# dial:0.008907303214073181
# screen:0.01285284012556076
# one:0.011853338219225407
# touch:0.005188661627471447
# call:0.004476148635149002
# fast:0.0039016727823764086
# dialer:0.0032545675057917833
# search:0.0053716558031737804
# smart:0.009926892817020416
# contact:0.0054785944521427155
# sort:0.0006797882379032671
# grid:0.0009315310744568706
# list:0.002067632507532835
# contact:0.0007050891290418804
# view:0.05599626898765564
# smart:0.025148259475827217
# card:0.028180068358778954
# integr:0.003365099895745516
# contact:0.006422233767807484
# gmail:0.009543691761791706
# event:0.013171537779271603
# etc:0.02139744535088539
#
# 87::Quickly export your backups to Dropbox# Google Drive# Email SMART DIALER Beautiful dialer to call and add new contacts T9 Dialer::0.9974875450134277
#
# quickli:0.19718517363071442
# export:0.41669824719429016
# backup:0.17550501227378845
# dropbox:0.017771117389202118
# googl:0.016632890328764915
# drive:0.04131999984383583
# email:0.04190445318818092
# smart:0.05789108946919441
# dialer:0.012561087496578693
# beauti:0.0111228721216321
# dialer:0.0035769252572208643
# call:0.0027006485033780336
# add:0.001962056150659919
# new:0.0008250211249105632
# contact:0.0004900050698779523
# dialer:0.0018532578833401203

# %%
all_data = []
all_data.extend(data.train_entries)
all_data.extend(data.test_entries)
statements = [entry.sentence for entry in all_data if entry.permissions["READ_CONTACTS"]==0]
permissions = [entry.sentence for entry in all_data if entry.permissions["READ_CONTACTS"]==1]
with open("statement_sentences.txt", "w") as target:
    for line in statements:
        target.write("{}\n".format(line))
with open("permission_sentences.txt", "w") as target:
    for line in permissions:
        target.write("{}\n".format(line))

# %%
len(permissions)
# Out:
# 944

# %%
print(neg_keys)
# Out:
# {'cloud': 3, 'block': 2, 'droid': 1, 'app': 2, 'use': 2, 'hit': 1, 'new': 1, 'contact': 1, 'send': 1, 'free': 1, 'friend': 1, 'lookup': 1, 'sync': 2, 'share': 2, 'updat': 1, 'trace': 1, 'want': 1, 'secur': 1, 'save': 1, 'backup': 1, 'real': 1, 'network': 1, 'take': 1, 'conveni': 1, 'keep': 2, 'instantli': 1, 'fund': 1, 'build': 1, 'buzz': 1, 'money': 1, 'squar': 1, 'one': 1, 'complet': 1, 'integr': 1, 'mt': 1, 'brows': 1, 'offer': 1, 'detail': 1, 'overview': 1, 'add': 1, 'heytel': 1, 'see': 1, 'twitter': 1, 'abl': 1, 'offici': 1}

# %%
print(pos_keys)
# Out:
# {'export': 1, 'featur': 1, 'group': 3, 'confidenti': 1, 'four': 1, 'factori': 1, 'read': 1, 'know': 1, 'nice': 1, 'contact': 2, 'app': 2, 'secur': 1, 'power': 1, 'select': 1, 'free': 1, 'brows': 1, 'manag': 1, 'premium': 1, 'jort': 1, 'set': 1, 'rate': 1, 'highlight': 1, 'note': 1, 'list': 1, 'event': 1, 'lock': 1, 'mobil': 1, 'automat': 1, 'show': 1, 'preview': 1, 'sm': 1, 'reason': 1, 'profil': 1, 'c': 1, 'vip': 1, 'account': 1, 'login': 1, 'type': 2, 'schedul': 1, 'pictur': 1, 'add': 1, 'lockscreen': 1, 'softon': 1, 'whatsapp': 1, 'take': 2, 'waypoint': 1, 'bank': 1, 'help': 1, 'log': 1, 'support': 3, 'use': 3, 'photo': 1, 'link': 1, 'share': 2, 'also': 2, 'updat': 1, 'edit': 1, 'block': 1, 'android': 2, 'creat': 1, 'run': 1, 'googl': 1, 'signal': 1, 'tri': 1, 'recal': 1, 'applic': 1, 'magicapp': 1, 'alway': 1, 'big': 1, 'post': 1, 'multipl': 1, 'price': 1, 'need': 1, 'buy': 1}

# %%
"""test_entries = data.test_entries
data.test_entries = data.train_entries
roc_auc, pr_auc = test_all(args, model, data)

ls = []
ls.extend(data.test_entries)
ls.extend(test_entries)
false = sum([1 for entry in ls if entry.prediction_result  < 0.25 and entry.permissions["READ_CONTACTS"] == 1 ])
tagged = sum([1 for entry in ls if entry.permissions["READ_CONTACTS"] == 1])
print(false, tagged, (false/tagged))
false = sum([1 for entry in ls if entry.prediction_result  < 0.25 and entry.permissions["READ_CONTACTS"] == 1 ])
tagged = sum([1 for entry in ls if entry.permissions["READ_CONTACTS"] == 1])
print(false, tagged, (false/tagged))
for entry in ls:
    print(idx+1, entry.sentence, entry.prediction_result)
    print()
false_positives = [entry for entry in sorted_negatives if entry.prediction_result >= 0.5]
for entry in false_positives:
    print(entry.prediction_result)"""
