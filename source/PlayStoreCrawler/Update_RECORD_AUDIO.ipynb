# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import requests
import numpy as np

# %%
def get_app_category(app_id):
    base_url = 'http://localhost:3000/api/apps/'
    response = requests.get(base_url+app_id)
    if response.status_code == 200:
        gid = response.json()["genreId"].upper()
        return gid
    else:
        print(app_id, " category cannot be found")
        return "NOT_FOUND"

# %%
def update_sheets(sheetname):
    df = pd.read_excel('RECORD_AUDIO.xlsx', sheet_name=sheetname)
    data = []
    for index, row in df.iterrows():
        data.append([row["Count"], row["Sentences"], row["Manually Marked"], row["uses-permission"], row["permission"]])
    updated_data = []
    app_order = 1
    description_tag = None
    for row in data:
        row[1] = str(row[1])
        if row[1].startswith("##"):
            if app_order != 1:
                description_row = [np.nan, "Description Tag", description_tag, np.nan, np.nan]
                updated_data.append(description_row)
            row[0] = "##{}".format(app_order)
            app_order += 1
            app_id = row[1].split("##")[1].strip()
            category = get_app_category(app_id)
            app_category = "CATEGORY/" + category
            category_row = [np.nan, app_category , np.nan, np.nan, np.nan]
            description_tag = row[2]
            row[2] = np.nan
            updated_data.append(row)
            updated_data.append(category_row)
        else:
            updated_data.append(row)
    return updated_data

# %%
from collections import defaultdict
def category_counts(sheetname):
    df = pd.read_excel('RECORD_AUDIO.xlsx', sheet_name=sheetname)
    data = []
    for index, row in df.iterrows():
        data.append([row["Count"], row["Sentences"], row["Manually Marked"], row["uses-permission"], row["permission"]])
    categories = defaultdict(int)
    for row in data:
        row[1] = str(row[1])
        if row[1].startswith("##"):
            app_id = row[1].split("##")[1].strip()
            category = get_app_category(app_id)
            categories[category] += 1
    return categories

# %%
def application_list(sheetname, outfile):
    df = pd.read_excel('RECORD_AUDIO.xlsx', sheet_name=sheetname)
    data = set()
   
    for index, row in df.iterrows():
        if row["Sentences"].startswith("##"):
            app_id = row["Sentences"].split("##")[1]
            data.add(app_id)
    return data

# %%
def write_to_excel(updated_data, output_file):
    def background_apply(value):
        if value.startswith("##") or value.startswith("Description Tag"):
            font_weight = 'bold'
        else:
            font_weight = 'normal'
        return 'font-weight: %s' % font_weight
    
    updated_df = pd.DataFrame(updated_data, columns = ["Count", "Sentences", "Manually Marked", "uses-permission", "permission"])
    styled = updated_df.style.applymap(background_apply, subset=['Sentences'])
    styled.to_excel(output_file, engine='openpyxl')

# %%
def run(sheet_name):
    updated_data = update_sheets(sheet_name)
    write_to_excel(updated_data, "{}.xlsx".format(sheet_name))

# %%
categories = category_counts("SEVIL")
# Out:
# com.duapps.recorder  category cannot be found

# %%
application_list("SEVIL", "record_audio_tagged_list.txt")
# Out:
# {'advanced3nd.ofamerican.english',
#  'ae.uae.ott.hiu',
#  'air.com.nhncorp.jrapp',
#  'air.com.rosettastone.mobile.CoursePlayer',
#  'alphastudio.adrama',
#  'au.gov.wa.pta.transperth',
#  'beauty.camera.photo.editor',
#  'bts.dancing.line.tap.dash.music.zigzag',
#  'call.free.international.phone.call',
#  'chat.rocket.android',
#  'city.russ.alltrackerfamily',
#  'co.adultfnder.android',
#  'co.clover.clover',
#  'co.dilmil.android',
#  'co.happybits.marcopolo',
#  'co.triller.droid',
#  'co.yellw.yellowapp',
#  'co.zodiacmatch.freedating',
#  'codematics.universal.tv.remote.control',
#  'com.DreamonStudios.BouncyBasketball',
#  'com.ElfizMedia.DubStepMusicMakerRM',
#  'com.KABloomInteractive.EV3',
#  'com.MixerStudio.SuperHearingSecretVoicesRecorderFREE',
#  'com.Slack',
#  'com.SouthernPacificOceanFisher.VoiceToText_memo',
#  'com.a4tune',
#  'com.ac.kannada.textbyvoice.speechtotext.voice.typingkeyboard',
#  'com.airbnb.android',
#  'com.alexvas.dvr',
#  'com.alibaba.aliexpresshd',
#  'com.alibaba.intl.android.apps.poseidon',
#  'com.amazon.windowshop',
#  'com.amolatina',
#  'com.android.chrome',
#  'com.androidworks.videocalling',
#  'com.andrwq.recorder',
#  'com.anghami',
#  'com.anhlt.karaokelite',
#  'com.ants360.yicamera.international',
#  'com.apn.mobile.browser.cherry',
#  'com.apn.mobile.browser.infosonics',
#  'com.appsfuturo.magianegra',
#  'com.arcsoft.perfect365',
#  'com.aspiro.tidal',
#  'com.atistudios.italk.nl',
#  'com.atpc',
#  'com.audio.ringtone.trim',
#  'com.audioRec',
#  'com.audionowdigital.player.channels24',
#  'com.audionowdigital.player.dwamharic',
#  'com.audiosmaxs.audiorecorder',
#  'com.aurora.music',
#  'com.autocab.driverapp',
#  'com.autodesk.homestyler',
#  'com.awabe.koreanwriting',
#  'com.awabe.learningchinese',
#  'com.awox.smart.control',
#  'com.axlebolt.standoff2',
#  'com.babbel.mobile.android.en',
#  'com.badoo.mobile',
#  'com.baidu.browser.inter',
#  'com.bamnetworks.mobile.android.gameday.atbat',
#  'com.bandlab.bandlab',
#  'com.barstoolsports.onebite',
#  'com.baviux.voicechanger',
#  'com.bbm',
#  'com.bddroid.android.hindi',
#  'com.beat.light',
#  'com.beatronik.djstudiodemo',
#  'com.benqu.wuta',
#  'com.bigheadtechies.diary',
#  'com.bkool.simulator',
#  'com.blackboard.android.bbstudent',
#  'com.blendr.mobile',
#  'com.blinkhd',
#  'com.blogspot.byterevapps.lollipopscreenrecorder',
#  'com.bork.dsp.datuna',
#  'com.bravolang.chinese',
#  'com.briniclemobile.wibeetalk',
#  'com.brisk.jpay',
#  'com.bs.editor.screenrecorder.mp4',
#  'com.calea.echo',
#  'com.camera.mix.camera',
#  'com.camerafourkpro.cameraultrahd',
#  'com.camerasideas.trimmer',
#  'com.capturerecorder.receditor.screenrecorder',
#  'com.cardflight.swipesimple',
#  'com.cateater.stopmotionstudio',
#  'com.cerdillac.filmmaker',
#  'com.cherinbo.callrecorder',
#  'com.chuchutv.android',
#  'com.cisco.im',
#  'com.cisco.webex.meetings',
#  'com.citrix.worxedit.xenmobile',
#  'com.citymobil',
#  'com.classdojo.android',
#  'com.cleanmaster.security',
#  'com.clogica.mp3cutter',
#  'com.cloudmosa.puffinFree',
#  'com.clusterdev.hindikeyboard',
#  'com.clusterdev.malayalamkeyboard',
#  'com.clusterdev.tamilkeyboard',
#  'com.coffeemeetsbagel',
#  'com.coolncoolapps.secretsoundrecorderhd.free',
#  'com.cosmicmobile.app.lighter',
#  'com.crazylabs.monster.high',
#  'com.creativemusicapps.mixpads.launchpad.free',
#  'com.creativemusicapps.mixpads2.free',
#  'com.ctm',
#  'com.cudu.conversationenglish',
#  'com.cvs.launchers.cvs',
#  'com.cyberlink.powerdirector.DRA140225_01',
#  'com.cyberlink.youcammakeup',
#  'com.cyberlink.youperfect',
#  'com.dailyselfie.newlook.studio',
#  'com.danale.video',
#  'com.darkcube.binnm',
#  'com.designkeyboard.keyboard',
#  'com.developitnowadays.frenchtoenglish',
#  'com.dhgate.buyermob',
#  'com.discord',
#  'com.disney.docmcstuffinsbaby_goo',
#  'com.diveomedia.little.stories.bedtime.books.kids',
#  'com.dlink.mydlink',
#  'com.dmp.android.joule',
#  'com.doctorondemand.android.patient',
#  'com.dogusdigital.puhutv',
#  'com.dongby.android.mmshow.inter',
#  'com.drivergenius.screenrecorder',
#  'com.dts.freefireth',
#  'com.duapps.recorder',
#  'com.duolingo',
#  'com.duowan.supervideo',
#  'com.dvdb.bergnotes',
#  'com.easytouch.assistivetouch',
#  'com.ecosia.android',
#  'com.editvideos.videomaker.videoshowmusic',
#  'com.ef.evc2015',
#  'com.eflasoft.porengfree',
#  'com.efun.encktx',
#  'com.emoji.keyboard.touchpal',
#  'com.enchantedcloud.photovault',
#  'com.englearner.frenchtoenglishspeaking',
#  'com.englearner.listenandleanspanishtoenglish',
#  'com.enlightment.voicerecorder',
#  'com.equalizer.volume.music.bass.booster.tool',
#  'com.esim.numero',
#  'com.esri.survey123',
#  'com.estmob.android.sendanywhere',
#  'com.evernote',
#  'com.evilduck.musiciankit',
#  'com.exatools.sensors',
#  'com.extreamsd.aemobiledemo',
#  'com.eyesthegame.eyes',
#  'com.eyougame.mysh.en',
#  'com.eytg.ssjj',
#  'com.ezscreenrecorder',
#  'com.facebook.Socal',
#  'com.facebook.lite',
#  'com.facebook.mlite',
#  'com.facebook.pages.app',
#  'com.facemoji.lite.indian',
#  'com.facemoji.lite.xiaomi.gp',
#  'com.fakecallgame',
#  'com.fameelee.app',
#  'com.familyandco.framilywall',
#  'com.famousbluemedia.yokee',
#  'com.fd.accessplusecs.aqua',
#  'com.feit.smart',
#  'com.ffgamestudio.fast12306',
#  'com.fiistudio.fiinote',
#  'com.finestandroid.tunner',
#  'com.flexbyte.groovemixer',
#  'com.foscam.foscam',
#  'com.fotoable.fotobeauty',
#  'com.fourchars.lmpfree',
#  'com.fragileheart.recorder',
#  'com.fragileheart.screenrecorder',
#  'com.free.apps.ikaraoke',
#  'com.freeconferencecall.fccmeetingclient',
#  'com.frenzycoders.microphoneblockerantispyware',
#  'com.freshgames.escapethetitanic',
#  'com.frojo.moy5',
#  'com.frojo.moy6',
#  'com.frojo.pug',
#  'com.fsf.tapestrymobile',
#  'com.funcamerastudio.videoeditor',
#  'com.futurebits.instamessage.free',
#  'com.galasports.football',
#  'com.gameleap.luna.na',
#  'com.gameloft.android.ANMP.GloftINHM',
#  'com.games24x7.ultimaterummy.playstore',
#  'com.gamestar.perfectpiano',
#  'com.gamestar.pianoperfect',
#  'com.gdz_ru',
#  'com.genesisblue01.verfutbolonlineguia',
#  'com.gi.talkinggarfield',
#  'com.gi.talkinggummybear',
#  'com.gismart.guitar.tuner',
#  'com.glidetalk.glideapp',
#  'com.glip.mobile',
#  'com.glu.nickiminaj',
#  'com.gogii.textplus',
#  'com.gokids.bphone1',
#  'com.google.android.apps.chromecast.app',
#  'com.google.android.apps.meetings',
#  'com.google.android.apps.tachyon',
#  'com.google.android.apps.translate',
#  'com.google.android.youtube',
#  'com.google.toontastic',
#  'com.gotomeeting',
#  'com.grabtaxi.passenger',
#  'com.grandstream.wave',
#  'com.grindrapp.android',
#  'com.gujarati.keyboard.for.android',
#  'com.har.androidapp',
#  'com.hawk.android.browser',
#  'com.hecorat.screenrecorder.free',
#  'com.hellochinese',
#  'com.hellofresh.androidapp',
#  'com.herman.ringtone',
#  'com.herogame.gplay.hopelessland',
#  'com.herzick.houseparty',
#  'com.hiqrecorder.free',
#  'com.hirevue.candidate.generic',
#  'com.hoctiengtrung.giaotiep',
#  'com.homeguard',
#  'com.homesnap',
#  'com.hotornot.app',
#  'com.hsv.freeadblockerbrowser',
#  'com.hudl.hudroid',
#  'com.huya.nimo',
#  'com.iart.camera.photo',
#  'com.idea.screenshot',
#  'com.igg.castleclash',
#  'com.iherb',
#  'com.imo.android.imoimbeta',
#  'com.inglesdivino.addmusictovoice',
#  'com.inputmethod.gurmukhi',
#  'com.internet.radio.fm.podcast',
#  'com.intuit.quickbooks',
#  'com.iosclip.moviemaker.movieapple.videostar.imovie',
#  'com.isharing.isharing',
#  'com.issteks.perfectkamera',
#  'com.ivuu',
#  'com.jazarimusic.voloco',
#  'com.jb.emoji.gokeyboard',
#  'com.jb.go.musicplayer.mp3player',
#  'com.jcp',
#  'com.jiubang.go.music',
#  'com.jnj.mocospace.android',
#  'com.joytunes.simplypiano',
#  'com.jrinnovation.proguitartuner',
#  'com.jsplash.tuner',
#  'com.juphoon.justalk',
#  'com.kakao.cheez',
#  'com.kakao.talk',
#  'com.kamagames.blackjack',
#  'com.kimcy929.secretvideorecorder',
#  'com.kimmysuperstarcat.virtualpet',
#  'com.kiwibrowser.browser',
#  'com.kkday.member',
#  'com.knudge.me',
#  'com.komspek.battleme',
#  'com.ktcccp.videofacetime',
#  'com.kty.gameday',
#  'com.laugh.doghome',
#  'com.learnchinese.learnchinesecommunication',
#  'com.learnfrench.learnfrenchlanguageoffline',
#  'com.learninga_z.onyourown',
#  'com.learningappjapanese',
#  'com.learnwithhomer.webapp',
#  'com.lemon.faceu.oversea',
#  'com.lescapadou.cursivefree',
#  'com.lifx.lifx',
#  'com.lilithgame.hgame.gp',
#  'com.lilithgame.roc.gp',
#  'com.linecorp.b612.android',
#  'com.linecorp.foodcam.android',
#  'com.lingumi.lingumiplay',
#  'com.linpusime_tc.android.linpus_tckbd',
#  'com.lioncomdev.trichat',
#  'com.logitech.harmonyhub',
#  'com.longtech.lastwars.gp',
#  'com.loudtalks',
#  'com.macrovideo.v380pro',
#  'com.magicv.airbrush',
#  'com.magom.ear.spy.pro',
#  'com.makewonder.pathandroid',
#  'com.matteljv.uno',
#  'com.mayoclinic.patient',
#  'com.mdd.dating',
#  'com.media.bestrecorder.audiorecorder',
#  'com.media.voicerecorder.ultimate',
#  'com.meihillman.ringtonemaker',
#  'com.meitu.makeup',
#  'com.meitu.meiyancamera',
#  'com.melodis.midomiMusicIdentifier.freemium',
#  'com.memrise.android.memrisecompanion',
#  'com.merkuryinnovations.geeni',
#  'com.mewe',
#  'com.microsoft.emmx',
#  'com.microsoft.office.lync15',
#  'com.microsoft.office.onenote',
#  'com.microsoft.teams',
#  'com.microsoft.xboxone.smartglass',
#  'com.microsoft.xboxone.smartglass.beta',
#  'com.miga.myschool',
#  'com.mining.app.mipca',
#  'com.mireo.ada',
#  'com.mixvibes.crossdjfree',
#  'com.mixvibes.remixlive',
#  'com.mm.android.direct.g_CMOB_XU',
#  'com.mo1st.simpleguitartuner',
#  'com.mobile.android.eris',
#  'com.mobile.legends',
#  'com.mobilemotion.dubsmash',
#  'com.mobobi.twienglishbible',
#  'com.motion.voice.recorder',
#  'com.movavi.mobile.movaviclips',
#  'com.movisoft.photostory',
#  'com.movisoftnew.videoeditor',
#  'com.mtelnet.watson.thailand',
#  'com.multipletranslate',
#  'com.musicplayer.equalizer.volumebooster',
#  'com.musicplayer.player.mp3player.white',
#  'com.musicroquis.hum_on',
#  'com.musixmatch.android.lyrify',
#  'com.mutyapps.oldiesradio.musica60s70s80s90s',
#  'com.mutyapps.peliculasgratisonline',
#  'com.mycatemma.virtualpet',
#  'com.myntra.android',
#  'com.mywickr.wickr2',
#  'com.myyearbook.m',
#  'com.narvii.amino.x233332503',
#  'com.navigation.offlinemaps.gps',
#  'com.neenbo',
#  'com.nest.android',
#  'com.netease.g78na.gb',
#  'com.netease.idv.googleplay',
#  'com.netflix.mediaclient',
#  'com.newTelDialer',
#  'com.nexstreaming.app.kinemasterfree',
#  'com.nike.plusgps',
#  'com.niklabs.pp',
#  'com.nll.acr',
#  'com.nll.asr',
#  'com.nll.screenrecorder',
#  'com.nobluffdating.com.app',
#  'com.noticiasusa.news',
#  'com.noxgroup.app.browser',
#  'com.odia.keyboard.for.android',
#  'com.odiosingle.calls',
#  'com.ojhero.translate',
#  'com.onix.live',
#  'com.onoapps.cal4u',
#  'com.opalastudios.pads',
#  'com.opera.browser',
#  'com.opera.browser.beta',
#  'com.outfit7.mytalkingangelafree',
#  'com.outfit7.mytalkingtom2',
#  'com.outfit7.talkingtom',
#  'com.outfit7.talkingtom2free',
#  'com.ovelin.guitartuna',
#  'com.pakdata.easyurdu',
#  'com.panasonic.avc.cng.imageapp',
#  'com.parla.android',
#  'com.peel.app',
#  'com.peliculas.gratis.tfilmss',
#  'com.perfectcorp.ycf',
#  'com.photoeditor.videopiccollage',
#  'com.photographylifestyle.super4dresults',
#  'com.photogrid.lite',
#  'com.picsart.animate',
#  'com.picstudio.photoeditorplus',
#  'com.planetromeo.android.app',
#  'com.playgendary.kickthebuddy',
#  'com.playstation.knowledge',
#  'com.playstation.mobilemessenger',
#  'com.pnc.ecommerce.mobile',
#  'com.pof.android',
#  'com.prankbuzz.wifihacker',
#  'com.primeleasing.citybee',
#  'com.progimax.candle.free',
#  'com.progimax.lighter.free',
#  'com.psychos.nvcamphotoandvideo',
#  'com.quvideo.xiaoying',
#  'com.raytechnoto.glab.voicerecorder',
#  'com.real.RealPlayerCloud',
#  'com.reallyvision.realvisor0',
#  'com.reallyvision.realvisors1',
#  'com.reallyvision.realvisors5',
#  'com.redboxsoft.voicerecorder',
#  'com.reflectionsinfos.arncity',
#  'com.remind101',
#  'com.revesoft.mobiledialer.dialglobe_communication.mabrook_plazma',
#  'com.revesoft.mobiledialer.playstar_1547104989026_20167',
#  'com.revesoft.mobiledialer.vibeplus_49601',
#  'com.ringcentral.android',
#  'com.runtastic.android',
#  'com.rvappstudios.flashlight',
#  'com.samsung.smartviewad',
#  'com.sayhi.android.sayhitranslate',
#  'com.scdgroup.englishpronunciation',
#  'com.schedule.telmate.telmatescheduleandroid',
#  'com.scoompa.slideshow',
#  'com.scorp.who',
#  'com.screenrecorder.recordingvideo.supervideoeditor',
#  'com.sdu.didi.psnger',
#  'com.sec.android.app.sbrowser.beta',
#  'com.sec.android.easyMover',
#  'com.securus.videoclient',
#  'com.series.TSeriess.gratis',
#  'com.sertanta.slideshowmaker.movie.movieslideshowmaker',
#  'com.sevegame.voicerecorder',
#  'com.sgrsoft.streetgamer',
#  'com.shazam.android',
#  'com.shenyaocn.android.usbcamera',
#  'com.sidefeed.TCViewer',
#  'com.signal.android',
#  'com.simejikeyboard',
#  'com.singlecellsoftware.caustic',
#  'com.sinyee.babybus.speaking',
#  'com.sinyee.babybus.travelsafety',
#  'com.skout.android',
#  'com.skycode.atrance.enfr.free',
#  'com.skypaw.decibel',
#  'com.slader.slader',
#  'com.smartmobitools.voicerecorder',
#  'com.smile.android.app',
#  'com.smule.singandroid',
#  'com.snapchat.android',
#  'com.snowcorp.soda.android',
#  'com.sofeh.android.musicstudio3',
#  'com.somfy.tahoma',
#  'com.sonyliv',
#  'com.soundcloud.android',
#  'com.soundlim.panotuner',
#  'com.speechtexter.speechtexter',
#  'com.sqr5.android.player_jb',
#  'com.squareup.beta',
#  'com.squarevalley.i8birdies',
#  'com.ss.android.article.topbuzzlite.en',
#  'com.stringtunerplus.guitartuner2019',
#  'com.studiosol.cifraclub',
#  'com.sudyapp',
#  'com.supereffect.voicechanger',
#  'com.superevilmegacorp.game',
#  'com.sygic.aura',
#  'com.sygic.speedcamapp',
#  'com.synctuition.synctuition',
#  'com.tabletmessenger',
#  'com.taggedapp',
#  'com.tap4fun.seagame.gplay',
#  'com.taxsee.driver',
#  'com.teladoc.members',
#  'com.telmate.TelmateGettingout',
#  'com.telos.app.im',
#  'com.tendinsights.tend',
#  'com.teq.guitarjam',
#  'com.textfun.text.free.call',
#  'com.textmeinc.freetone',
#  'com.textmeinc.textme',
#  'com.textmeinc.textme3',
#  'com.thelallantop',
#  'com.theotino.chinadaily',
#  'com.thisclicks.wiw',
#  'com.tianxingjian.screenshot',
#  'com.tickpickllc.ceobrien.tickpick',
#  'com.tinybeans',
#  'com.titan.cd.gb',
#  'com.todoist',
#  'com.toktumi.line2',
#  'com.tpaay.bigpay',
#  'com.tpvision.philipstvapp',
#  'com.transat.airtransat',
#  'com.tuenti.messenger',
#  'com.tumblr',
#  'com.twis.punjabiradio',
#  'com.typany.ime',
#  'com.uaemoi.smartservices',
#  'com.ubisoft.uplay',
#  'com.uc.vmate',
#  'com.ucool.heroesarena',
#  'com.ukuleletuner',
#  'com.unearby.sayhi',
#  'com.universal.voice.translator',
#  'com.vaultmicro.camerafi.live',
#  'com.vaultmicro.camerafi2',
#  'com.vava.free.music.equalizer.color.theme',
#  'com.vblast.flipaclip',
#  'com.venticake.retrica',
#  'com.verizon.messaging.vzmsgs',
#  'com.vialsoft.radarbot_free',
#  'com.vialsoft.radars_uk_free',
#  'com.video.capturevideo',
#  'com.video.master',
#  'com.videoeditor.videomaker.photos.music.pictures',
#  'com.videomaker.editor.slideshow.songs.record.album',
#  'com.videoslideshow.photomovie.videomaker',
#  'com.vidku.app.flipgrid',
#  'com.vinapp.fuji.cam',
#  'com.virtecha.umniah',
#  'com.visne.baglamatuner',
#  'com.vivashow.share.video.chat',
#  'com.vkontakte.android',
#  'com.vnlentertainment.mmoproject',
#  'com.voice.gps.driving.directions.gps.navigation.maps.location',
#  'com.voice.gps.navigation.map.location.route',
#  'com.vtm.audiorecord',
#  'com.vtm.voicechanger',
#  'com.vuongtx.mp3editor',
#  'com.waplog.social',
#  'com.warden.cam',
#  'com.wb.goog.hothands',
#  'com.wengo.crystalball',
#  'com.wenor.uia.checking',
#  'com.wescan.alo',
#  'com.whatsapp',
#  'com.wildec.dating.meet4u',
#  'com.wildec.fastmeet',
#  'com.wildec.meet24',
#  'com.wix.android',
#  'com.wondershare.filmorago',
#  'com.wowwee.rev',
#  'com.writing.learn.arabic',
#  'com.writing.learn.japanese',
#  'com.wsi.wallstreetenglish.nse',
#  'com.ximalaya.ting.himalaya',
#  'com.yandex.browser',
#  'com.yandex.yango',
#  'com.yelp.android',
#  'com.yiyou.game.trickyfour',
#  'com.yiyou.game.trickythree',
#  'com.yocto.wenote',
#  'com.youdao.translator',
#  'com.yousician.yousician',
#  'com.yy.biu',
#  'com.zalivka.animation2',
#  'com.zayan.ui2',
#  'com.zenjoy.slideshow',
#  'com.zenjoy.videoeditor.funimate',
#  'com.zentertain.videoeditor',
#  'com.zhiliaoapp.musically',
#  'com.zinkia.pocoyo.talkingpocoyo2',
#  'com.zoho.chat',
#  'com.zoho.creator.a',
#  'com.zoiper.android.app',
#  'com.zplay.willhero',
#  'com.zyepro.mobilescopes',
#  'cool.monkey.android',
#  'cz.master.babyheartbeats',
#  'datee.mobi',
#  'de.appfiction.yocutiegoogle',
#  'dictionary.english.freeapptck',
#  'dictionary.ofamerican.english',
#  'dje073.android.modernrecforge',
#  'eop.everyone.piano.usb.keyboard',
#  'es.ingenia.emt',
#  'finarea.MobileVoip',
#  'finarea.VoipBuster',
#  'fm.anchor.android',
#  'fm.castbox.audiobook.radio.podcast',
#  'fr.anuman.HomeDesign3D',
#  'free.call.international.phone.calling',
#  'gr.pixelab.sketch',
#  'im.vector.alpha',
#  'in.mohalla.sharechat',
#  'in.mtap.iincube.safetrax.commuter',
#  'info.thana.dictionarychinese',
#  'io.gartic.Gartic',
#  'io.gonative.android.rzkyq',
#  'io.knowledge.triviaspar',
#  'io.sbaud.wavstudio',
#  'ir.resaneh1.iptv',
#  'it.rabb.rabbitandroid',
#  'jp.co.nikko_data.japantaxi',
#  'jp.co.rarity.tvweb',
#  'jp.co.roland.bosstuner',
#  'jp.naver.line.android',
#  'jp.naver.linecamera.android',
#  'kaydev.recordaudio.voiceapp',
#  'kr.sira.sound',
#  'krk.anime.animekeyboard',
#  'liedetector.tpg.com.liedetector',
#  'lior.hai.soundanalyzertest',
#  'live.hala',
#  'madiva.com.talkenglishconversation',
#  'me.dingtone.app.im',
#  'me.elvn',
#  'me.jlabs.loudalarmclock',
#  'me.nextplus.smsfreetext.phonecalls',
#  'me.pou.app',
#  'mega.privacy.android.app',
#  'messenger.messenger.videocall.messenger',
#  'mingle.android.mingle',
#  'mingle.android.mingle2',
#  'mp3songs.mp3player.mp3cutter.ringtonemaker',
#  'music.equalizer.bass.volume.booster',
#  'net.bloomz',
#  'net.cybrook.trackview',
#  'net.daum.android.map',
#  'net.idt.um.android.bossrevapp',
#  'net.languagecourse.vt.de',
#  'net.languagecourse.vt.en',
#  'net.languagecourse.vt.fi',
#  'net.learnmatch.app',
#  'net.lovoo.android',
#  'net.musopia.fourchordsjustin',
#  'net.musopia.kalatuner',
#  'net.osmand',
#  'net.sourceforge.opencamera',
#  'nl.hnogames.domoticz',
#  'org.adblockplus.browser',
#  'org.blubblub.app.speechblubs',
#  'org.familysearch.mobile.memories',
#  'org.intoorbit.spectrum',
#  'org.lds.ldssa',
#  'org.liveanimations.hippomagic',
#  'org.me.mobiexpensifyg',
#  'org.tasks',
#  'org.telegram.BifToGram',
#  'org.telegram.plus',
#  'org.videolan.vlc',
#  'org.whiteglow.keepmynotes',
#  'photoeditor.filter.camera',
#  'photoeditor.photo.video.pic.collage',
#  'pl.netigen.simplebanjotuner',
#  'pl.netigen.simpleviolintuner',
#  'real.guitar.learn.chords.tuner.play.songs.tiles.pocket.rhythm.game',
#  'recording.phone.call.auto.recorder',
#  'ru.aeroflot',
#  'ru.alarmtrade.pandora',
#  'ru.appache.findphonebywhistle',
#  'ru.aterlux.guitartuner',
#  'ru.bestappsandbestgames.realdjsimulator',
#  'ru.chocoapp.app',
#  'ru.loveplanet.app',
#  'ru.mamba.client',
#  'ru.ok.android',
#  'ru.s7.android',
#  'ru.yandex.searchplugin',
#  'ru.yandex.taxi',
#  'ru.yandex.taximeter',
#  'screen.recorder',
#  'screenrecorder.recorder.editor',
#  'se.posten.riktigavykort',
#  'seesaw.shadowpuppet.co.classroom',
#  'selfcoder.mstudio.mp3editor',
#  'sg.bigo.gaming',
#  'sg.bigo.live',
#  'software.simplicial.nebulous',
#  'sweet.selfie.lite',
#  'tv.cchan.harajuku',
#  'tv.jamlive',
#  'tv.peel.app',
#  'tv.peel.smartremote',
#  'tv.twitch.android.app',
#  'tw.chaozhuyin',
#  'ua.mybible',
#  'us.hiphopbeatmaker.xxxtentacion',
#  'us.only4prank.clapfinder',
#  'us.universalapps.virtua.lighter.cigarette',
#  'vStudio.Android.Camera360',
#  'video.editor.videoeditor.videomaker',
#  'video.like',
#  'videoeditor.videomaker.videoeditorforyoutube',
#  'videoslideshow.photoedit.videocutter',
#  'voice.recorder.soundrecorder',
#  'vr.audio.voicerecorder',
#  'xyz.klinker.messenger'}

# %%
import operator
sorted_categories = sorted(categories.items(), key=operator.itemgetter(1), reverse=True)

total = 0
for line in sorted_categories:
    total += line[1]
    print(line[0], line[1])
print("Total : ", total)
# Out:
# MUSIC_AND_AUDIO 77
# COMMUNICATION 68
# EDUCATION 57
# VIDEO_PLAYERS 51
# PHOTOGRAPHY 43
# TOOLS 41
# SOCIAL 41
# ENTERTAINMENT 36
# PRODUCTIVITY 28
# DATING 25
# BUSINESS 18
# TRAVEL_AND_LOCAL 16
# MAPS_AND_NAVIGATION 15
# LIFESTYLE 14
# GAME_CASUAL 14
# GAME_ACTION 11
# NEWS_AND_MAGAZINES 10
# HOUSE_AND_HOME 9
# PERSONALIZATION 8
# SHOPPING 8
# GAME_ROLE_PLAYING 7
# FINANCE 6
# GAME_STRATEGY 6
# GAME_TRIVIA 6
# HEALTH_AND_FITNESS 5
# PARENTING 5
# BOOKS_AND_REFERENCE 5
# GAME_MUSIC 4
# SPORTS 4
# GAME_EDUCATIONAL 4
# MEDICAL 4
# LIBRARIES_AND_DEMO 3
# GAME_CARD 3
# FOOD_AND_DRINK 2
# GAME_SIMULATION 2
# GAME_SPORTS 2
# GAME_ADVENTURE 2
# EVENTS 2
# ART_AND_DESIGN 2
# AUTO_AND_VEHICLES 1
# GAME_RACING 1
# GAME_PUZZLE 1
# NOT_FOUND 1
# BEAUTY 1
# COMICS 1
# GAME_ARCADE 1
# Total :  671

# %%
new_categories = sorted_categories[len(sorted_categories)//2:]
for cat in new_categories:
    print('"{}",'.format(cat[0]), end =" ")
# Out:
# "GAME_TRIVIA", "HEALTH_AND_FITNESS", "PARENTING", "BOOKS_AND_REFERENCE", "GAME_MUSIC", "SPORTS", "GAME_EDUCATIONAL", "MEDICAL", "LIBRARIES_AND_DEMO", "GAME_CARD", "FOOD_AND_DRINK", "GAME_SIMULATION", "GAME_SPORTS", "GAME_ADVENTURE", "EVENTS", "ART_AND_DESIGN", "AUTO_AND_VEHICLES", "GAME_RACING", "GAME_PUZZLE", "NOT_FOUND", "BEAUTY", "COMICS", "GAME_ARCADE",
