# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time
import csv
import random
from time import sleep

# %%
def application_list(filename):
    df = pd.read_excel(filename)
    data = set()
    for _, row in df.iterrows():
        if row["Sentences"].startswith("##"):
            app_id = row["Sentences"].split("##")[1]
            data.add(app_id)
    return data

# %%
permission_type = "RECORD_AUDIO"
downloded_file = "SEVIL.xlsx"
categories = {"categories":[{"cat_key":"OVERALL","name":"Overall"},{"cat_key":"APPLICATION","name":"All apps"},{"cat_key":"GAME","name":"All games"},{"cat_key":"ART_AND_DESIGN","name":"Art & Design"},{"cat_key":"AUTO_AND_VEHICLES","name":"Auto & Vehicles"},{"cat_key":"BEAUTY","name":"Beauty"},{"cat_key":"BOOKS_AND_REFERENCE","name":"Books & Reference"},{"cat_key":"BUSINESS","name":"Business"},{"cat_key":"COMICS","name":"Comics"},{"cat_key":"COMMUNICATION","name":"Communication"},{"cat_key":"DATING","name":"Dating"},{"cat_key":"EDUCATION","name":"Education"},{"cat_key":"ENTERTAINMENT","name":"Entertainment"},{"cat_key":"EVENTS","name":"Events"},{"cat_key":"FINANCE","name":"Finance"},{"cat_key":"FOOD_AND_DRINK","name":"Food & Drink"},{"cat_key":"HEALTH_AND_FITNESS","name":"Health & Fitness"},{"cat_key":"HOUSE_AND_HOME","name":"House & Home"},{"cat_key":"LIFESTYLE","name":"Lifestyle"},{"cat_key":"MAPS_AND_NAVIGATION","name":"Maps & Navigation"},{"cat_key":"MEDICAL","name":"Medical"},{"cat_key":"MUSIC_AND_AUDIO","name":"Music & Audio"},{"cat_key":"NEWS_AND_MAGAZINES","name":"News & Magazines"},{"cat_key":"PARENTING","name":"Parenting"},{"cat_key":"PERSONALIZATION","name":"Personalization"},{"cat_key":"PHOTOGRAPHY","name":"Photography"},{"cat_key":"PRODUCTIVITY","name":"Productivity"},{"cat_key":"SHOPPING","name":"Shopping"},{"cat_key":"SOCIAL","name":"Social"},{"cat_key":"SPORTS","name":"Sports"},{"cat_key":"TOOLS","name":"Tools"},{"cat_key":"TRAVEL_AND_LOCAL","name":"Travel & Local"},{"cat_key":"VIDEO_PLAYERS","name":"Video Players & Editors"},{"cat_key":"WEATHER","name":"Weather"},{"cat_key":"LIBRARIES_AND_DEMO","name":"Libraries & Demo"},{"cat_key":"GAME_ARCADE","name":"Arcade"},{"cat_key":"GAME_PUZZLE","name":"Puzzle"},{"cat_key":"GAME_CARD","name":"Cards"},{"cat_key":"GAME_CASUAL","name":"Casual"},{"cat_key":"GAME_RACING","name":"Racing"},{"cat_key":"GAME_SPORTS","name":"Sport Games"},{"cat_key":"GAME_ACTION","name":"Action"},{"cat_key":"GAME_ADVENTURE","name":"Adventure"},{"cat_key":"GAME_BOARD","name":"Board"},{"cat_key":"GAME_CASINO","name":"Casino"},{"cat_key":"GAME_EDUCATIONAL","name":"Educational"},{"cat_key":"GAME_MUSIC","name":"Music Games"},{"cat_key":"GAME_ROLE_PLAYING","name":"Role Playing"},{"cat_key":"GAME_SIMULATION","name":"Simulation"},{"cat_key":"GAME_STRATEGY","name":"Strategy"},{"cat_key":"GAME_TRIVIA","name":"Trivia"},{"cat_key":"GAME_WORD","name":"Word Games"},{"cat_key":"ANDROID_WEAR","name":"Android Wear"},{"cat_key":"FAMILY","name":"Family All Ages"},{"cat_key":"FAMILY_UNDER_5","name":"Family Ages 5 & Under"},{"cat_key":"FAMILY_6_TO_8","name":"Family Ages 6-8"},{"cat_key":"FAMILY_9_AND_UP","name":"Family Ages 9 & Up"},{"cat_key":"FAMILY_ACTION","name":"Family Action"},{"cat_key":"FAMILY_BRAINGAMES","name":"Family Brain Games"},{"cat_key":"FAMILY_CREATE","name":"Family Create"},{"cat_key":"FAMILY_EDUCATION","name":"Family Education"},{"cat_key":"FAMILY_MUSICVIDEO","name":"Family Music & Video"},{"cat_key":"FAMILY_PRETEND","name":"Family Pretend Play"}]}
if permission_type == "RECORD_AUDIO":
    category_keys = ["GAME_TRIVIA", "HEALTH_AND_FITNESS", "PARENTING", "BOOKS_AND_REFERENCE", "GAME_MUSIC", "SPORTS", "GAME_EDUCATIONAL", "MEDICAL", "LIBRARIES_AND_DEMO", "GAME_CARD", "FOOD_AND_DRINK", "GAME_SIMULATION", "GAME_SPORTS", "GAME_ADVENTURE", "EVENTS", "ART_AND_DESIGN", "AUTO_AND_VEHICLES", "GAME_RACING", "GAME_PUZZLE", "NOT_FOUND", "BEAUTY", "COMICS", "GAME_ARCADE"]
else:
    category_keys = [cat["cat_key"] for cat in categories["categories"]]

permission_phrase = "record audio" if permission_type == "RECORD_AUDIO" else "read your contacts"
downloaded_apps_check = True if permission_type == "RECORD_AUDIO" else False

# %%
def get_top_free_applications(categories):
    def per_category_top_free(category):
        waiting_urls = set()
        url = 'http://localhost:3000/api/apps/?collection=topselling_free&category={}&lang=en'.format(category)
        #top free applications
        response = requests.get(url)
        if response.status_code == 200:
            for app in response.json()["results"]:
                waiting_urls.add(app["url"])
        else:
            print("Request Error")
        return waiting_urls
    all_top_free_apps = set()
    for category in categories:
        all_top_free_apps.update(per_category_top_free(category))
    return all_top_free_apps

# %%
def get_app_category(app_id):
    base_url = 'http://localhost:3000/api/apps/'
    response = requests.get(base_url+app_id)
    if response.status_code == 200:
        gid = response.json()["genreId"].upper()
        return gid
    else:
        print(app_id, " category cannot be found")
        return "NOT_FOUND"

# %%
def is_permission_exist(url):
    response = requests.get(url+"/permissions")
    if response.status_code == 200:
        json = response.json()
        for line in json["results"]:
            if permission_content in line["permission"]:
                return True
        return False
    else:
        print("Permission link is failed")

# %%
def get_similar_ids(app_id):
    sleep(0.1)
    page = requests.get("https://play.google.com/store/apps/details?id={}".format(app_id))
    soup = BeautifulSoup(page.content, 'html.parser')
    href = soup.find(class_='LkLjZd ScJHi U8Ww7d xjAeve nMZKrb id-track-click ')
    if href != None:
        href = href["href"]
        sleep(0.2)
        page = requests.get(href)
        soup = BeautifulSoup(page.content, 'html.parser')
        similars = []
        for link in soup.find_all(class_="JC71ub"):
            similars.append(link['href'].split("=")[1])
        return similars
    else:
        return []

# %%
permission_type = permission_type
check_downloaded_apps = downloaded_apps_check
permission_content = permission_phrase
if check_downloaded_apps:
    dowloaded_list = application_list(downloded_file)

# %%
top_free_apps = get_top_free_applications(category_keys)
# Out:
# Request Error

# %%
init_apps = top_free_apps
waiting_urls = list(init_apps)
random.shuffle(waiting_urls)
waiting_urls_unique_check = set([url for url in waiting_urls])
app_ids = set()


counter = 0
while (len(app_ids) + len(waiting_urls)) < 100000:
    try:
        if counter % 10 == 0:
            print("Total number of apps", len(app_ids) + len(waiting_urls))
            print("Collected app ids", len(app_ids))
        try:
            url = waiting_urls.pop()
            waiting_urls_unique_check.remove(url)
        except Exception:
            print("All linked applications are traversed")
            break

        #add apk id if it is free, popular, and has longer description than 500 characters
        response = requests.get(url)
        print(url, end=" ")
        if response.status_code == 200:
            print("SUCCESS")
            json = response.json()
            if json["minInstalls"] > 10000 and json["priceText"] == "Free" and len(json["description"]) > 500:
                application_id = url.split('/')[-1]
                if application_id not in app_ids:
                    if is_permission_exist(url):
                        print("PERMISSION EXIST")
                        app_ids.add(application_id)
                        cat = get_app_category(application_id)
                        with open("{}/{}.txt".format(permission_type, cat), "a") as target:
                            if application_id not in dowloaded_list:
                                target.write(application_id + "\n")
                                print("DOWNLOADED NOW")
                            else:
                                print("PREVIOUSLY DOWNLOADED")                   
        else:
            print("FAIL")

        #add similar app urls
        for sim_id in get_similar_ids(url.split("/")[-1]):
            sim_id = "http://localhost:3000/api/apps/" + sim_id
            if sim_id not in waiting_urls_unique_check:
                waiting_urls_unique_check.add(sim_id)
                waiting_urls.append(sim_id)
        random.shuffle(waiting_urls)
        counter += 1
    except Exception:
        print("Number of waiting_urls ", len(waiting_urls))
        pass
print("-----------------------------------------------------------------------------------------------------------")
print("TRAVERSING COMPLETED")
for url in waiting_urls:
    print(url, end=" ")
    response = requests.get(url)
    if response.status_code == 200:
        print("SUCCESS")
        json = response.json()
        if json["minInstalls"] > 10000 and json["priceText"] == "Free" and len(json["description"]) > 500:
            application_id = url.split('/')[-1]
            if application_id not in app_ids:
                if is_permission_exist(url):
                    print("PERMISSION EXIST")
                    app_ids.add(application_id )
                    cat = get_app_category(application_id)
                    with open("{}/{}.txt".format(permission_type, cat), "a") as target:
                        if application_id not in dowloaded_list:
                            target.write(application_id + "\n")
    else:
        print("FAIL")
# Out:
# Total number of apps 1320
# Collected app ids 0
# http://localhost:3000/api/apps/com.medicalutilitytools.bloodpressure.diary.bp.info.chart.log SUCCESS
# http://localhost:3000/api/apps/com.mayoclinic.patient SUCCESS
# PERMISSION EXIST
# PREVIOUSLY DOWNLOADED
# http://localhost:3000/api/apps/com.sirma.mobile.bible.android SUCCESS
# http://localhost:3000/api/apps/org.blueletterbible.blb SUCCESS
# http://localhost:3000/api/apps/com.mindbodyonline.connect SUCCESS
# http://localhost:3000/api/apps/com.freakingfreegames.miami.beach.car.driver SUCCESS
# http://localhost:3000/api/apps/com.szyk.myheart SUCCESS
# http://localhost:3000/api/apps/com.postmates.android SUCCESS
# http://localhost:3000/api/apps/com.vblast.flipaclip SUCCESS
# PERMISSION EXIST
# PREVIOUSLY DOWNLOADED
# http://localhost:3000/api/apps/com.rtsoft.growtopia SUCCESS
# Total number of apps 1627
# Collected app ids 2
# http://localhost:3000/api/apps/com.episodeinteractive.android.catalog SUCCESS
# http://localhost:3000/api/apps/mobi.mangatoon.comics.aphone SUCCESS
# http://localhost:3000/api/apps/app.playandwinapp.com SUCCESS
# http://localhost:3000/api/apps/com.health.lab.drink.water.tracker SUCCESS
# http://localhost:3000/api/apps/com.mlb.HomeRunDerby SUCCESS
# http://localhost:3000/api/apps/br.com.tapps.donotdisturb SUCCESS
# http://localhost:3000/api/apps/com.tutotoons.app.kikififipethotel.free SUCCESS
# http://localhost:3000/api/apps/com.tiramisu.driftmax2 SUCCESS
# http://localhost:3000/api/apps/com.atomic.moguls.hockey2018 SUCCESS
# http://localhost:3000/api/apps/com.viagogo.consumer.viagogo.playstore SUCCESS
# Total number of apps 1922
# Collected app ids 2
# http://localhost:3000/api/apps/com.ticketswap.ticketswap SUCCESS
# http://localhost:3000/api/apps/com.science.yarnapp SUCCESS
# http://localhost:3000/api/apps/niv.biblereader.olivetree SUCCESS
# http://localhost:3000/api/apps/com.pixelberrystudios.hwuandroid SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.instacart.client.publix SUCCESS
# http://localhost:3000/api/apps/id.drakor.plus SUCCESS
# http://localhost:3000/api/apps/com.gamesbypost.spadescardclassic SUCCESS
# http://localhost:3000/api/apps/net.dotpicko.dotpict SUCCESS
# http://localhost:3000/api/apps/com.miniclip.eightballpool SUCCESS
# http://localhost:3000/api/apps/com.ajaxcleaner.app SUCCESS
# Total number of apps 2244
# Collected app ids 3
# http://localhost:3000/api/apps/newking.james.version.BIBLE SUCCESS
# http://localhost:3000/api/apps/com.kai.kaiticketing SUCCESS
# http://localhost:3000/api/apps/com.joyjourney.PianoWhiteLittle SUCCESS
# http://localhost:3000/api/apps/com.getsomeheadspace.android SUCCESS
# http://localhost:3000/api/apps/com.hotheadgames.google.free.bigwinfootball2 SUCCESS
# http://localhost:3000/api/apps/ps.battle.royale SUCCESS
# http://localhost:3000/api/apps/com.enflick.android.TextNow SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/in.sweatco.app SUCCESS
# http://localhost:3000/api/apps/com.pzizz.android SUCCESS
# http://localhost:3000/api/apps/com.gifs.flowers SUCCESS
# Total number of apps 2541
# Collected app ids 4
# http://localhost:3000/api/apps/com.gametime.gametime SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev180329.app542783 SUCCESS
# http://localhost:3000/api/apps/com.facebook.katana SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.bimiboo.playandlearn SUCCESS
# http://localhost:3000/api/apps/com.flashseats.v2 SUCCESS
# http://localhost:3000/api/apps/com.hdmi.app SUCCESS
# http://localhost:3000/api/apps/com.crowdstar.covetfashion SUCCESS
# http://localhost:3000/api/apps/com.foodlion.mobile SUCCESS
# http://localhost:3000/api/apps/com.mashaapps.Happy.Birthday.songs.NamePhotooncake SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.aldrinarciga.creepypastareader SUCCESS
# Total number of apps 2860
# Collected app ids 6
# http://localhost:3000/api/apps/com.pixelberrystudios.hwuandroid SUCCESS
# http://localhost:3000/api/apps/com.ea.game.pogogames SUCCESS
# http://localhost:3000/api/apps/com.figames.adultcoloring SUCCESS
# http://localhost:3000/api/apps/com.fitbit.FitbitMobile SUCCESS
# http://localhost:3000/api/apps/com.app.magicmoneyguest SUCCESS
# http://localhost:3000/api/apps/cc.moov.five SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.maxstream SUCCESS
# http://localhost:3000/api/apps/co.ritual.app SUCCESS
# http://localhost:3000/api/apps/com.bilkon.easypiano SUCCESS
# http://localhost:3000/api/apps/com.dreamsky.DiabloLOL SUCCESS
# Total number of apps 3120
# Collected app ids 7
# http://localhost:3000/api/apps/com.narvii.amino.x51 SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/anime.face.changer.cartoon.photo_editor SUCCESS
# http://localhost:3000/api/apps/com.tinytouchtales.cardthief SUCCESS
# http://localhost:3000/api/apps/com.pearmobile.apps.holybible SUCCESS
# http://localhost:3000/api/apps/melstudio.mpresssure SUCCESS
# http://localhost:3000/api/apps/com.crowdcompass.appRlu4oSX2JZ SUCCESS
# http://localhost:3000/api/apps/kjv.audio.bible SUCCESS
# http://localhost:3000/api/apps/com.StefMorojna.SpaceflightSimulator SUCCESS
# http://localhost:3000/api/apps/net.wouldyouratherapp.wouldyourather SUCCESS
# http://localhost:3000/api/apps/com.animedrawing.husin SUCCESS
# Total number of apps 3398
# Collected app ids 8
# http://localhost:3000/api/apps/com.tacobell.ordering SUCCESS
# http://localhost:3000/api/apps/com.geishatokyo.trafficrun SUCCESS
# http://localhost:3000/api/apps/com.all.social.allnetworks SUCCESS
# http://localhost:3000/api/apps/com.yiyou.game.newtricky SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.superking.parchisi.star SUCCESS
# http://localhost:3000/api/apps/com.netpulse.mobile.morefitness SUCCESS
# http://localhost:3000/api/apps/kjv.offline.holy.bible.king.james SUCCESS
# http://localhost:3000/api/apps/com.mizo.moto.bike.racing SUCCESS
# http://localhost:3000/api/apps/com.netflix.mediaclient SUCCESS
# PERMISSION EXIST
# PREVIOUSLY DOWNLOADED
# http://localhost:3000/api/apps/f2game.bubbleshooter.pandapop SUCCESS
# Total number of apps 3616
# Collected app ids 10
# http://localhost:3000/api/apps/com.ascent.affirmations.myaffirmations SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.mykronoz.zefit4 SUCCESS
# http://localhost:3000/api/apps/com.piupiuapps.hairstyles SUCCESS
# http://localhost:3000/api/apps/com.madfingergames.monzo SUCCESS
# http://localhost:3000/api/apps/com.combyne.app SUCCESS
# http://localhost:3000/api/apps/memory.verses.com.knowyourmemoryverses.biblegames SUCCESS
# http://localhost:3000/api/apps/com.canva.editor SUCCESS
# http://localhost:3000/api/apps/com.dreame.reader SUCCESS
# http://localhost:3000/api/apps/com.gameinsight.gplay.mmanor SUCCESS
# http://localhost:3000/api/apps/com.ginortcar.postres.faciles.y.rapidos SUCCESS
# Total number of apps 3929
# Collected app ids 11
# http://localhost:3000/api/apps/com.NdesoDEV.SemuaChannelTVIndonesiaOnlineHD SUCCESS
# http://localhost:3000/api/apps/com.norizabob.coinprincessvip SUCCESS
# http://localhost:3000/api/apps/com.benoit.outman.fortniteshopoftheday SUCCESS
# http://localhost:3000/api/apps/com.BattleRoyale.Wallpapers SUCCESS
# http://localhost:3000/api/apps/com.budgestudios.MissHollywood2 SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/king.james.bible.kjv.daily.study SUCCESS
# http://localhost:3000/api/apps/com.squad.snool.droproulette.fortnite SUCCESS
# http://localhost:3000/api/apps/com.rosegold.wallpapers SUCCESS
# http://localhost:3000/api/apps/org.catrobat.paintroid SUCCESS
# http://localhost:3000/api/apps/eu.mvns.games SUCCESS
# Total number of apps 4115
# Collected app ids 12
# http://localhost:3000/api/apps/com.popboxapp.newmovieboxapp SUCCESS
# http://localhost:3000/api/apps/com.edmtrain.edmtracks SUCCESS
# http://localhost:3000/api/apps/com.playdigious.evoland2 SUCCESS
# http://localhost:3000/api/apps/com.miniclip.archery SUCCESS
# http://localhost:3000/api/apps/com.sleekbit.dormi SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.specialyg.ippro3 SUCCESS
# http://localhost:3000/api/apps/com.microsoft.microsoftsolitairecollection SUCCESS
# http://localhost:3000/api/apps/com.creativemobile.DragRacing SUCCESS
# http://localhost:3000/api/apps/com.gdcompany.metalmadness SUCCESS
# http://localhost:3000/api/apps/com.gamehouse.slingo SUCCESS
# Total number of apps 4396
# Collected app ids 13
# http://localhost:3000/api/apps/com.candywriter.bitlife SUCCESS
# http://localhost:3000/api/apps/air.com.lunime.gachalife SUCCESS
# http://localhost:3000/api/apps/com.bubble.puzzle SUCCESS
# http://localhost:3000/api/apps/com.gameinsight.solitaire SUCCESS
# http://localhost:3000/api/apps/biblia.LETRA.gigante SUCCESS
# http://localhost:3000/api/apps/com.piupiuapps.hairstylesgirls SUCCESS
# http://localhost:3000/api/apps/com.inov8.fonepayconsumer SUCCESS
# http://localhost:3000/api/apps/biblereader.olivetree SUCCESS
# http://localhost:3000/api/apps/com.motivateco.hubway SUCCESS
# http://localhost:3000/api/apps/com.fs.birthdayphotoframe.photo.editor SUCCESS
# Total number of apps 4641
# Collected app ids 13
# http://localhost:3000/api/apps/spin.bubble SUCCESS
# http://localhost:3000/api/apps/com.bitmango.go.blockhexapuzzle SUCCESS
# http://localhost:3000/api/apps/com.mcdonalds.app SUCCESS
# http://localhost:3000/api/apps/com.razmobi.monstertrucks2 SUCCESS
# http://localhost:3000/api/apps/com.askari SUCCESS
# http://localhost:3000/api/apps/kjv.Bible SUCCESS
# http://localhost:3000/api/apps/paolo4c.amazfit.watchfaces SUCCESS
# http://localhost:3000/api/apps/com.bestgame.theimpossiblequiznew SUCCESS
# http://localhost:3000/api/apps/com.gameloft.android.ANMP.GloftDMHM SUCCESS
# http://localhost:3000/api/apps/com.nexttechgamesstudio.fashion.poly.art.color.by.number.pixel.art SUCCESS
# Total number of apps 4830
# Collected app ids 13
# http://localhost:3000/api/apps/com.kwiktrip SUCCESS
# http://localhost:3000/api/apps/edu.northwestern.cbits.intellicare.thoughtchallenger SUCCESS
# http://localhost:3000/api/apps/com.mr.birthdaycakephotoframes SUCCESS
# http://localhost:3000/api/apps/br.com.tapps.mymonsterhouse SUCCESS
# http://localhost:3000/api/apps/cn.qz.lolita.avatarfactory SUCCESS
# http://localhost:3000/api/apps/a2z.Mobile.Event4633 SUCCESS
# http://localhost:3000/api/apps/emoji.background.photo.editor SUCCESS
# http://localhost:3000/api/apps/com.badcrane.rgbexpress SUCCESS
# http://localhost:3000/api/apps/com.lolsurprise.pixelart.free SUCCESS
# http://localhost:3000/api/apps/com.FDGEntertainment.redball4.gp SUCCESS
# Total number of apps 5051
# Collected app ids 13
# http://localhost:3000/api/apps/air.com.pearsoned.poptropica SUCCESS
# http://localhost:3000/api/apps/apps.syst.com.devbib SUCCESS
# http://localhost:3000/api/apps/com.webzen.shotonlinegolf.google SUCCESS
# http://localhost:3000/api/apps/com.hoteltarvr SUCCESS
# http://localhost:3000/api/apps/dh3games.doeshelikeme SUCCESS
# http://localhost:3000/api/apps/com.kidspaint.kaushalmehra.drawingfun SUCCESS
# http://localhost:3000/api/apps/digifit.android.virtuagym.pro.xercise4less SUCCESS
# http://localhost:3000/api/apps/com.honkmobile SUCCESS
# http://localhost:3000/api/apps/com.isysway.free.alquran SUCCESS
# http://localhost:3000/api/apps/com.finja.simsim SUCCESS
# Total number of apps 5311
# Collected app ids 13
# http://localhost:3000/api/apps/com.veitch.themelodymaster.pmf SUCCESS
# http://localhost:3000/api/apps/com.vc.voco SUCCESS
# http://localhost:3000/api/apps/com.gv.solitairedreamforestcards SUCCESS
# http://localhost:3000/api/apps/air.com.turner.boomerangmakeandrace SUCCESS
# http://localhost:3000/api/apps/com.zephyo.LivePortraitMakerM SUCCESS
# http://localhost:3000/api/apps/com.tfgco.games.coloring.free.paint.by.number SUCCESS
# http://localhost:3000/api/apps/com.zhystudio.FamousLoveRomanceNovels SUCCESS
# http://localhost:3000/api/apps/com.enigmastudio.gangstercitysimulator SUCCESS
# http://localhost:3000/api/apps/com.locker.kids SUCCESS
# http://localhost:3000/api/apps/uk.co.aifactory.spades SUCCESS
# Total number of apps 5524
# Collected app ids 13
# http://localhost:3000/api/apps/com.sesameworkshop.alphabetkitchen.play SUCCESS
# http://localhost:3000/api/apps/com.destotechgames.bike.stunts.tracks SUCCESS
# http://localhost:3000/api/apps/com.percent.mybest SUCCESS
# http://localhost:3000/api/apps/com.vizorapps.klondike SUCCESS
# http://localhost:3000/api/apps/com.monois.android.eduapp27 SUCCESS
# http://localhost:3000/api/apps/org.codechimp.qrwear SUCCESS
# http://localhost:3000/api/apps/bubbles.bounce SUCCESS
# http://localhost:3000/api/apps/com.sesame.go SUCCESS
# http://localhost:3000/api/apps/com.jaicode.moviesjune2k18 SUCCESS
# http://localhost:3000/api/apps/com.withbuddies.diceellen SUCCESS
# Total number of apps 5717
# Collected app ids 13
# http://localhost:3000/api/apps/jp.co.cybird.appli.android.sgk.en SUCCESS
# http://localhost:3000/api/apps/com.freefuncard.solitaire.challenge SUCCESS
# http://localhost:3000/api/apps/com.ellisapps.itrackbitesplus SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/id.drakor.plus SUCCESS
# http://localhost:3000/api/apps/com.us.wouldyourather.trivia.adults SUCCESS
# http://localhost:3000/api/apps/com.textmeinc.freetone SUCCESS
# PERMISSION EXIST
# PREVIOUSLY DOWNLOADED
# http://localhost:3000/api/apps/com.nexttechgamesstudio.valentine.glitter.color.by.number.sandbox.coloring.adult.coloring.book SUCCESS
# http://localhost:3000/api/apps/com.samsung.android.geargplugin SUCCESS
# http://localhost:3000/api/apps/com.bytelogics.bolt SUCCESS
# http://localhost:3000/api/apps/br.com.zeroeum.bibliamulher SUCCESS
# Total number of apps 5906
# Collected app ids 15
# http://localhost:3000/api/apps/com.hyperbeard.alchademy SUCCESS
# http://localhost:3000/api/apps/com.dolphingames.fearless.jetski.racing SUCCESS
# http://localhost:3000/api/apps/com.ada.app SUCCESS
# http://localhost:3000/api/apps/com.interactivespecializedsoftware.bloodpressurediary SUCCESS
# http://localhost:3000/api/apps/io.a24go.android.dev SUCCESS
# http://localhost:3000/api/apps/com.ayogamez.sketchcartoon SUCCESS
# http://localhost:3000/api/apps/com.cardgame.spider.fishdom SUCCESS
# http://localhost:3000/api/apps/best.live_wallpapers.name_on_birthday_cake SUCCESS
# http://localhost:3000/api/apps/com.zynga.FarmVille2CountryEscape SUCCESS
# http://localhost:3000/api/apps/com.fourth.ichoose SUCCESS
# Total number of apps 6116
# Collected app ids 15
# http://localhost:3000/api/apps/com.pitashi.audiojoy.angieatkinson SUCCESS
# http://localhost:3000/api/apps/com.royale.challenge.dances.battle SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.partyqs SUCCESS
# http://localhost:3000/api/apps/com.relance.happycouple SUCCESS
# http://localhost:3000/api/apps/tv.picpac SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.skintracker.skins.battleroyale.app SUCCESS
# http://localhost:3000/api/apps/com.sinyee.babybus.tailor SUCCESS
# http://localhost:3000/api/apps/com.nexttechgamesstudio.butterfly.paint.by.number.sandbox.coloring.adult.coloring.book SUCCESS
# http://localhost:3000/api/apps/com.teenstylesoutfits.wall SUCCESS
# http://localhost:3000/api/apps/com.sobergrid SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# Total number of apps 6372
# Collected app ids 18
# http://localhost:3000/api/apps/com.g5e.twinmoonspg.android SUCCESS
# http://localhost:3000/api/apps/com.facebook.katana SUCCESS
# http://localhost:3000/api/apps/com.simppro.quran.offline SUCCESS
# http://localhost:3000/api/apps/com.watchback.android SUCCESS
# http://localhost:3000/api/apps/com.punchh.fazolis SUCCESS
# http://localhost:3000/api/apps/com.best.photo.app.weddinghairstyle SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev337735.app650875 SUCCESS
# http://localhost:3000/api/apps/com.ea.gp.nbamobile SUCCESS
# http://localhost:3000/api/apps/com.medicalgroupsoft.medical.directorymedtermsmultilang.free SUCCESS
# http://localhost:3000/api/apps/bibleverses.bibleverse.bible.biblia.verse.devotion SUCCESS
# Total number of apps 6590
# Collected app ids 18
# http://localhost:3000/api/apps/com.banesco.banescomovilpa.tcmbpa.android SUCCESS
# http://localhost:3000/api/apps/com.publix.main SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.zq.realm SUCCESS
# http://localhost:3000/api/apps/com.escapefun.the100roomiv SUCCESS
# http://localhost:3000/api/apps/com.huami.watch.hmwatchmanager SUCCESS
# http://localhost:3000/api/apps/com.aa.extreme.city.gt.car.stunts SUCCESS
# http://localhost:3000/api/apps/uk.co.aifactory.heartsfree SUCCESS
# http://localhost:3000/api/apps/com.sevelina.sweetvampire SUCCESS
# http://localhost:3000/api/apps/com.freakingfreegames.horse.taxi.city.offroad.transport.simulator SUCCESS
# http://localhost:3000/api/apps/com.dokdoapps.mybabypiano SUCCESS
# Total number of apps 6804
# Collected app ids 19
# http://localhost:3000/api/apps/com.userfeel.app SUCCESS
# http://localhost:3000/api/apps/com.drivetime.MobileOnline SUCCESS
# http://localhost:3000/api/apps/com.x3m.tx4 SUCCESS
# http://localhost:3000/api/apps/com.offfgames.android.free.baseballbattle SUCCESS
# http://localhost:3000/api/apps/com.Best.Ringtones SUCCESS
# http://localhost:3000/api/apps/com.robot.water.slide SUCCESS
# http://localhost:3000/api/apps/air.com.pixelfederation.seaport.explore.collect.trade SUCCESS
# http://localhost:3000/api/apps/com.gameloft.android.ANMP.GloftGF2F SUCCESS
# http://localhost:3000/api/apps/com.playflock.indicatfb SUCCESS
# http://localhost:3000/api/apps/io.birdchain.app SUCCESS
# Total number of apps 7036
# Collected app ids 19
# http://localhost:3000/api/apps/com.babycam SUCCESS
# http://localhost:3000/api/apps/com.yhi.virtual.wild.horse.family.survival.simulator.game SUCCESS
# http://localhost:3000/api/apps/com.gameloft.android.ANMP.GloftDOHM SUCCESS
# http://localhost:3000/api/apps/game.puzzle.woodypuzzle SUCCESS
# http://localhost:3000/api/apps/com.Questions.boyfriend.yr SUCCESS
# http://localhost:3000/api/apps/com.dalcomsoft.ssb SUCCESS
# http://localhost:3000/api/apps/com.real_piano_learning_keyboard_2019 SUCCESS
# http://localhost:3000/api/apps/a2z.Mobile.Event5570 SUCCESS
# http://localhost:3000/api/apps/com.tencent.mm SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.lemontart.demolition.derby.car.racing.stunts SUCCESS
# Total number of apps 7239
# Collected app ids 20
# http://localhost:3000/api/apps/com.streamhelper.streamhelper SUCCESS
# http://localhost:3000/api/apps/com.Endvoid.SculptPlus SUCCESS
# http://localhost:3000/api/apps/com.cnn.indonesia SUCCESS
# http://localhost:3000/api/apps/com.icemobile.brightstamps.alfamart SUCCESS
# http://localhost:3000/api/apps/com.ahmed53.quraan_abdulbasit_tartil SUCCESS
# http://localhost:3000/api/apps/com.ionicframework.fyle595781 SUCCESS
# http://localhost:3000/api/apps/net.andromo.dev540689.app520732 SUCCESS
# http://localhost:3000/api/apps/zonek.design.paintbynumbers SUCCESS
# http://localhost:3000/api/apps/com.hungry.crocodile.simulator SUCCESS
# http://localhost:3000/api/apps/com.kidgame.supermarket SUCCESS
# Total number of apps 7418
# Collected app ids 20
# http://localhost:3000/api/apps/com.QSSUMSTUDIO.FeeDog SUCCESS
# http://localhost:3000/api/apps/com.bubadu.duddu SUCCESS
# http://localhost:3000/api/apps/com.aparna.girlandboy.jokes SUCCESS
# http://localhost:3000/api/apps/com.tvhdmedia.livesatu SUCCESS
# http://localhost:3000/api/apps/com.carl.bible SUCCESS
# http://localhost:3000/api/apps/com.sky.breakers.allaroundme SUCCESS
# http://localhost:3000/api/apps/com.neivaflima.bibliaparamulheres SUCCESS
# http://localhost:3000/api/apps/com.jasongiddings.tvonlineindonesia SUCCESS
# http://localhost:3000/api/apps/com.PlasticBottles.yashan SUCCESS
# http://localhost:3000/api/apps/com.mangasan.app SUCCESS
# Total number of apps 7547
# Collected app ids 20
# http://localhost:3000/api/apps/com.noticiasfortnite.stickers SUCCESS
# http://localhost:3000/api/apps/pop.bubble.pandora SUCCESS
# http://localhost:3000/api/apps/air.com.inclusive.fingerpaint SUCCESS
# http://localhost:3000/api/apps/com.tesseractmobile.solitairefreepack SUCCESS
# http://localhost:3000/api/apps/com.cocoplay.diy.fashion SUCCESS
# http://localhost:3000/api/apps/bookaz.storiesbook.novelstories1 SUCCESS
# http://localhost:3000/api/apps/app.magic.cleaner.boost SUCCESS
# http://localhost:3000/api/apps/pop.bubble.top SUCCESS
# http://localhost:3000/api/apps/com.gametime.gametime SUCCESS
# http://localhost:3000/api/apps/com.kumandgo.rewards SUCCESS
# Total number of apps 7666
# Collected app ids 20
# http://localhost:3000/api/apps/hu.lilarepa.nycbikemapoffline SUCCESS
# http://localhost:3000/api/apps/com.TAV.Mooring SUCCESS
# http://localhost:3000/api/apps/com.narvii.amino.manager SUCCESS
# http://localhost:3000/api/apps/com.moniapps.recetasmexicanastradicionalesfacilesygratis SUCCESS
# http://localhost:3000/api/apps/com.seword.app SUCCESS
# http://localhost:3000/api/apps/com.glu.nickiminaj SUCCESS
# PERMISSION EXIST
# PREVIOUSLY DOWNLOADED
# http://localhost:3000/api/apps/br.com.aleluiah_apps.bibliasagrada.viva SUCCESS
# http://localhost:3000/api/apps/com.orangenose.speedycar2 SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/dk.tactile.cookiecats SUCCESS
# http://localhost:3000/api/apps/uk.org.alcoholconcern.dryjanuary SUCCESS
# Total number of apps 7868
# Collected app ids 22
# http://localhost:3000/api/apps/my.smartech.mp3quran SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.lolsgg.lmmr SUCCESS
# http://localhost:3000/api/apps/com.foranj.monsterfarm SUCCESS
# http://localhost:3000/api/apps/com.jetstartgames.chess SUCCESS
# http://localhost:3000/api/apps/com.riatech.souprecipes SUCCESS
# http://localhost:3000/api/apps/and.onemt.boe.tr SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/org.stanfordhealthcare.myhealth SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.contextlogic.wish SUCCESS
# http://localhost:3000/api/apps/com.bandainamcoent.TKGRB SUCCESS
# http://localhost:3000/api/apps/com.motionvolt.flipdiving SUCCESS
# Total number of apps 8146
# Collected app ids 25
# http://localhost:3000/api/apps/com.askari SUCCESS
# http://localhost:3000/api/apps/com.facebook.pages.app SUCCESS
# PERMISSION EXIST
# PREVIOUSLY DOWNLOADED
# http://localhost:3000/api/apps/com.avanza.ambitwiz SUCCESS
# http://localhost:3000/api/apps/com.high.blood.pressure.hypertension.diet.tips SUCCESS
# http://localhost:3000/api/apps/com.rivingchoolestaracingkids SUCCESS
# http://localhost:3000/api/apps/hiddencamdetector.futureapps.com.hiddencamdetectoradsfree SUCCESS
# http://localhost:3000/api/apps/br.com.tapps.hackinghero SUCCESS
# http://localhost:3000/api/apps/com.punchh.schlotzskys SUCCESS
# http://localhost:3000/api/apps/masterfiveappsstudiosbr.abibliadamulherportuguesbr SUCCESS
# http://localhost:3000/api/apps/com.pepiplay.pepihome SUCCESS
# Total number of apps 8287
# Collected app ids 26
# http://localhost:3000/api/apps/com.bpva.womensaree.photosuit.girls.fancysuit.maker SUCCESS
# http://localhost:3000/api/apps/com.urbandroid.sleep SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/tecyou.com.khawterqassd SUCCESS
# http://localhost:3000/api/apps/com.langtao.neyeprotwo SUCCESS
# http://localhost:3000/api/apps/com.minimango.games.carcitytv2 SUCCESS
# http://localhost:3000/api/apps/com.samsung.android.gearoplugin SUCCESS
# http://localhost:3000/api/apps/com.ea.gp.simsmobile SUCCESS
# http://localhost:3000/api/apps/net.andromo.dev540689.app521846 SUCCESS
# http://localhost:3000/api/apps/com.bbumgames.spadesroyale SUCCESS
# http://localhost:3000/api/apps/fitness.loseweight.absworkout.women SUCCESS
# Total number of apps 8459
# Collected app ids 27
# http://localhost:3000/api/apps/com.funnyplaygames.realuspolice SUCCESS
# http://localhost:3000/api/apps/de.motain.iliga SUCCESS
# http://localhost:3000/api/apps/vn.tivi.xemtv SUCCESS
# http://localhost:3000/api/apps/com.etsy.android SUCCESS
# http://localhost:3000/api/apps/com.appomart.teeth SUCCESS
# http://localhost:3000/api/apps/digifit.android.virtuagym.pro.xercise4less SUCCESS
# http://localhost:3000/api/apps/com.pikpok.hrc.play SUCCESS
# http://localhost:3000/api/apps/com.honeydue.honeydue SUCCESS
# http://localhost:3000/api/apps/de.eventim.mobile.app.Android SUCCESS
# http://localhost:3000/api/apps/com.berdikaribook SUCCESS
# Total number of apps 8707
# Collected app ids 27
# http://localhost:3000/api/apps/com.scores365 SUCCESS
# http://localhost:3000/api/apps/com.aleluyapps.bibliadamulher SUCCESS
# http://localhost:3000/api/apps/com.moviebase SUCCESS
# http://localhost:3000/api/apps/com.gmspartnersltd.earthmiles SUCCESS
# http://localhost:3000/api/apps/com.droidlinkedcodenw.duo SUCCESS
# http://localhost:3000/api/apps/com.zitga.ninja.stickman.legends SUCCESS
# http://localhost:3000/api/apps/com.brandbassadoras.brandbassador SUCCESS
# http://localhost:3000/api/apps/the.easy.to.read.bible SUCCESS
# http://localhost:3000/api/apps/com.tesseractmobile.solitairemulti SUCCESS
# http://localhost:3000/api/apps/com.Zonmob.ShadowofDeath.FightingGames SUCCESS
# Total number of apps 8870
# Collected app ids 27
# http://localhost:3000/api/apps/com.printandpixel.lolhistory SUCCESS
# http://localhost:3000/api/apps/com.wb.goog.fantasticbeastsho SUCCESS
# http://localhost:3000/api/apps/com.astro.astro SUCCESS
# http://localhost:3000/api/apps/io.methinks.android SUCCESS
# http://localhost:3000/api/apps/com.nighp.babytracker_android SUCCESS
# http://localhost:3000/api/apps/com.unplugged SUCCESS
# http://localhost:3000/api/apps/com.sdk.blood_pressure SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.king.diamonddiariessaga SUCCESS
# http://localhost:3000/api/apps/com.cv.sawan.tvmalaysia SUCCESS
# http://localhost:3000/api/apps/com.tjt.wificam.maginon.ac800w SUCCESS
# Total number of apps 9056
# Collected app ids 28
# http://localhost:3000/api/apps/com.hulu.plus SUCCESS
# http://localhost:3000/api/apps/mobi.koni.appstofiretv SUCCESS
# http://localhost:3000/api/apps/com.asda.android SUCCESS
# http://localhost:3000/api/apps/se.isakpersson.dashyknight SUCCESS
# http://localhost:3000/api/apps/bubbles.peak SUCCESS
# http://localhost:3000/api/apps/kr.co.rinasoft.howuse SUCCESS
# http://localhost:3000/api/apps/best.photo.app.pinkhair SUCCESS
# http://localhost:3000/api/apps/com.deliverycom SUCCESS
# http://localhost:3000/api/apps/jp.danball.powdergameviewer SUCCESS
# http://localhost:3000/api/apps/com.square_enix.android_google.ffxvpe SUCCESS
# Total number of apps 9223
# Collected app ids 28
# http://localhost:3000/api/apps/com.luizserenainc.giyimstiller SUCCESS
# http://localhost:3000/api/apps/com.pinkjava.creepypasta SUCCESS
# http://localhost:3000/api/apps/vaildfoxs.webs SUCCESS
# http://localhost:3000/api/apps/com.twinbody.android SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/cas.happy.birthday.photo.frames SUCCESS
# http://localhost:3000/api/apps/com.codeknitters.silentdepth SUCCESS
# http://localhost:3000/api/apps/com.simppro.quran.khatm SUCCESS
# http://localhost:3000/api/apps/air.ru.crazypanda.wpcm SUCCESS
# http://localhost:3000/api/apps/com.ninetyfour.degrees.app SUCCESS
# http://localhost:3000/api/apps/com.nimblebit.pockettrains SUCCESS
# Total number of apps 9439
# Collected app ids 29
# http://localhost:3000/api/apps/com.leafgreen.heartbreak SUCCESS
# http://localhost:3000/api/apps/com.sdgcode.drinkwater SUCCESS
# http://localhost:3000/api/apps/com.pikasapps.whitehorse.wallpapers SUCCESS
# http://localhost:3000/api/apps/com.weheartit SUCCESS
# http://localhost:3000/api/apps/com.sports.schedules.scores.baseball.mlb SUCCESS
# http://localhost:3000/api/apps/com.randomsaladgames.heartsdeluxe SUCCESS
# http://localhost:3000/api/apps/com.cctv.keye SUCCESS
# http://localhost:3000/api/apps/com.jugosadelgazar.jugosparabajardepeso SUCCESS
# http://localhost:3000/api/apps/com.gc.multi.transforming.jet.robots.war SUCCESS
# http://localhost:3000/api/apps/com.fanduel.android.self SUCCESS
# Permission link is failed
# Total number of apps 9654
# Collected app ids 29
# http://localhost:3000/api/apps/it.midapp.moma.explora SUCCESS
# http://localhost:3000/api/apps/com.pixign.premium.coloring.book SUCCESS
# http://localhost:3000/api/apps/com.todaytix.TodayTix SUCCESS
# http://localhost:3000/api/apps/topringtones.newringtones.sonneries SUCCESS
# http://localhost:3000/api/apps/is.abide SUCCESS
# http://localhost:3000/api/apps/io.com.app.NTN24 SUCCESS
# http://localhost:3000/api/apps/com.physics.sim.game.savecats SUCCESS
# http://localhost:3000/api/apps/com.hyilmaz.rummy.gin SUCCESS
# http://localhost:3000/api/apps/com.actcompanion SUCCESS
# http://localhost:3000/api/apps/com.workmarket.android.native SUCCESS
# Total number of apps 9856
# Collected app ids 29
# http://localhost:3000/api/apps/com.sirius SUCCESS
# http://localhost:3000/api/apps/com.simyasolutions.tod SUCCESS
# http://localhost:3000/api/apps/com.mobiteka.navigator SUCCESS
# http://localhost:3000/api/apps/com.interactivespecializedsoftware.bloodpressurediary SUCCESS
# http://localhost:3000/api/apps/biblia.sagrada.gratis.audio SUCCESS
# http://localhost:3000/api/apps/com.zakg.scaryteacher.hellgame SUCCESS
# http://localhost:3000/api/apps/a2z.Mobile.Event4903 SUCCESS
# http://localhost:3000/api/apps/com.insomniac.mothership SUCCESS
# http://localhost:3000/api/apps/pastudio.ccbubble.pandafruit SUCCESS
# http://localhost:3000/api/apps/com.maverik.rewards SUCCESS
# Total number of apps 9975
# Collected app ids 29
# http://localhost:3000/api/apps/com.castle_biblia_mulher.castle_biblia_mulher SUCCESS
# http://localhost:3000/api/apps/io.friendly.twitter SUCCESS
# http://localhost:3000/api/apps/pe.cinepapaya.cinemark SUCCESS
# http://localhost:3000/api/apps/com.ifuncreator.tanimewall SUCCESS
# http://localhost:3000/api/apps/com.gty.macarthurstudybible SUCCESS
# http://localhost:3000/api/apps/de.twokit.castbrowser SUCCESS
# http://localhost:3000/api/apps/com.changemystyle.gentlewakeup SUCCESS
# http://localhost:3000/api/apps/com.messages.deeplovemessages SUCCESS
# http://localhost:3000/api/apps/com.cardfree.android.redlobster SUCCESS
# http://localhost:3000/api/apps/com.crazyapps.marriagesavingtips SUCCESS
# Total number of apps 10166
# Collected app ids 29
# http://localhost:3000/api/apps/photo.editor.polarr SUCCESS
# http://localhost:3000/api/apps/com.generamobile.logomania SUCCESS
# http://localhost:3000/api/apps/bammo.lyft.taxi SUCCESS
# http://localhost:3000/api/apps/com.desygner.wattpadcovers SUCCESS
# http://localhost:3000/api/apps/sms.msg.message.love.valentine.saint.saintvalentine SUCCESS
# http://localhost:3000/api/apps/com.miniclip.bowmasters SUCCESS
# http://localhost:3000/api/apps/org.pbskids.catinthehatbuildsthat SUCCESS
# http://localhost:3000/api/apps/com.streamelements.firestream SUCCESS
# http://localhost:3000/api/apps/com.kiwilimon2 SUCCESS
# http://localhost:3000/api/apps/com.funnyring.ringtone_free.for_android SUCCESS
# Total number of apps 10325
# Collected app ids 29
# http://localhost:3000/api/apps/com.generagames.ninjadash.samuraironin.jumprpg SUCCESS
# http://localhost:3000/api/apps/com.belajarapp.lagu90an SUCCESS
# http://localhost:3000/api/apps/com.starcommand.scgame SUCCESS
# http://localhost:3000/api/apps/com.olo.ihop SUCCESS
# http://localhost:3000/api/apps/com.BestPhotoEditor.BabyStory SUCCESS
# http://localhost:3000/api/apps/com.adobe.lrmobile SUCCESS
# http://localhost:3000/api/apps/air.com.armorgames.infectonator SUCCESS
# http://localhost:3000/api/apps/quran.tilawatequran.ahmedalajmi SUCCESS
# http://localhost:3000/api/apps/com.candy.world.crush.jam.free SUCCESS
# http://localhost:3000/api/apps/com.iitcoinc.faceposts SUCCESS
# Total number of apps 10558
# Collected app ids 29
# http://localhost:3000/api/apps/com.djinnworks.ssp SUCCESS
# http://localhost:3000/api/apps/com.crazylabs.dance.school SUCCESS
# http://localhost:3000/api/apps/com.soulgame.soda.gp SUCCESS
# http://localhost:3000/api/apps/com.cheekuapps.smart.car.wash.service.extreme.city.car.stunts SUCCESS
# http://localhost:3000/api/apps/com.com2us.kungfupet.normal2.freefull.google.global.android.common SUCCESS
# http://localhost:3000/api/apps/com.ankama.kingcrusher SUCCESS
# http://localhost:3000/api/apps/com.horner.ronald.cessationnation SUCCESS
# http://localhost:3000/api/apps/com.MASTGames.StarChindy01 SUCCESS
# http://localhost:3000/api/apps/fitapp.fittofit SUCCESS
# http://localhost:3000/api/apps/com.punchh.capriottis SUCCESS
# Total number of apps 10693
# Collected app ids 29
# http://localhost:3000/api/apps/plex.activador SUCCESS
# http://localhost:3000/api/apps/com.belajarapp.laguterbaik SUCCESS
# http://localhost:3000/api/apps/com.internetdesignzone.poems SUCCESS
# http://localhost:3000/api/apps/pk.pakistanprizebond.m.pakistanprizebond SUCCESS
# http://localhost:3000/api/apps/com.gigago.monster.city.hero SUCCESS
# http://localhost:3000/api/apps/com.drugscom.app SUCCESS
# http://localhost:3000/api/apps/tukangsayur.co SUCCESS
# http://localhost:3000/api/apps/com.wsy.google.wansuiye.en SUCCESS
# http://localhost:3000/api/apps/com.nghe.nhacsong SUCCESS
# http://localhost:3000/api/apps/com.TWCableTV SUCCESS
# Total number of apps 10930
# Collected app ids 29
# http://localhost:3000/api/apps/com.Infinity.swan SUCCESS
# http://localhost:3000/api/apps/com.dazn SUCCESS
# http://localhost:3000/api/apps/com.kemasdimas.wristcamera SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.overstock SUCCESS
# http://localhost:3000/api/apps/com.zillow.android.rentals SUCCESS
# http://localhost:3000/api/apps/com.g5e.twinmoonspg.android SUCCESS
# http://localhost:3000/api/apps/com.gamestar.pianoperfect SUCCESS
# PERMISSION EXIST
# PREVIOUSLY DOWNLOADED
# http://localhost:3000/api/apps/com.cbssports.fantasy.franchisefootball2015 SUCCESS
# http://localhost:3000/api/apps/com.cookie.crush.maina.jam.candy.free SUCCESS
# http://localhost:3000/api/apps/org.nanobit.hollywood SUCCESS
# Total number of apps 11113
# Collected app ids 31
# http://localhost:3000/api/apps/com.andronicus.ledclock SUCCESS
# http://localhost:3000/api/apps/com.case7Games.extremecarstunts SUCCESS
# http://localhost:3000/api/apps/com.radiosonline.fmradiovietnam SUCCESS
# http://localhost:3000/api/apps/com.mindifi.deepsleephypnosis SUCCESS
# http://localhost:3000/api/apps/com.eastbay.eastbay SUCCESS
# http://localhost:3000/api/apps/com.rk.lovebirdsphotoframes SUCCESS
# http://localhost:3000/api/apps/com.girlywallpapers.girlypictures.girls.funny.cute.beautiful.pink.glitter.background.images.beautiful.hd.free SUCCESS
# http://localhost:3000/api/apps/com.ttlike.makien.android SUCCESS
# http://localhost:3000/api/apps/com.otherguys.lindab SUCCESS
# http://localhost:3000/api/apps/com.gluak.f24 SUCCESS
# Total number of apps 11312
# Collected app ids 31
# http://localhost:3000/api/apps/mobi.firedepartment SUCCESS
# http://localhost:3000/api/apps/tv.benandholly.party SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.dopewallpapers.trillwallpaper.hypebeast.streetwear.sick.cool.hype.backgrounds.hd SUCCESS
# http://localhost:3000/api/apps/adriandp.m365dashboard SUCCESS
# http://localhost:3000/api/apps/com.Sumdog.App3D SUCCESS
# http://localhost:3000/api/apps/home.mediashow.tvgratis SUCCESS
# http://localhost:3000/api/apps/com.tribefluence SUCCESS
# http://localhost:3000/api/apps/com.raddixcore.xyzplayer SUCCESS
# http://localhost:3000/api/apps/com.sky.breakers.fbiopenup SUCCESS
# http://localhost:3000/api/apps/com.angelworks.cutequotes SUCCESS
# Total number of apps 11541
# Collected app ids 32
# http://localhost:3000/api/apps/com.kaigan.simulacra SUCCESS
# http://localhost:3000/api/apps/com.legendroaapps.africacouplefashion SUCCESS
# http://localhost:3000/api/apps/net.joyplustech.android_mermaid13 SUCCESS
# http://localhost:3000/api/apps/com.bhima.logoart SUCCESS
# http://localhost:3000/api/apps/com.gismart.piano.games.music.keyboard SUCCESS
# http://localhost:3000/api/apps/com.clickdelivery.android.domiciliosbogota SUCCESS
# http://localhost:3000/api/apps/com.rsg.lord SUCCESS
# http://localhost:3000/api/apps/com.king.candycrush4 SUCCESS
# http://localhost:3000/api/apps/co.kernelnetworks.casejournals SUCCESS
# http://localhost:3000/api/apps/com.kmart.android SUCCESS
# Total number of apps 11710
# Collected app ids 32
# http://localhost:3000/api/apps/com.New.Ringtones2018 SUCCESS
# http://localhost:3000/api/apps/com.appmind.radios.ve SUCCESS
# http://localhost:3000/api/apps/forest.fairy.live.wallpaper SUCCESS
# http://localhost:3000/api/apps/net.sinproject.android.tweecha.lite SUCCESS
# http://localhost:3000/api/apps/com.iboattech.avatar.cute SUCCESS
# http://localhost:3000/api/apps/com.blackcircleapps.tropicalbingo SUCCESS
# http://localhost:3000/api/apps/com.cosmo.sweetcandyfrenzy.free SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev375438.app351313 SUCCESS
# http://localhost:3000/api/apps/com.leafgreen.sassy SUCCESS
# http://localhost:3000/api/apps/com.hourglass.figure.bodyworkout SUCCESS
# Total number of apps 11890
# Collected app ids 32
# http://localhost:3000/api/apps/com.kalypsomedia.crowntakers SUCCESS
# http://localhost:3000/api/apps/com.bluesky.veryfunny.ringtone SUCCESS
# http://localhost:3000/api/apps/ru.mobiledimension.kbr SUCCESS
# http://localhost:3000/api/apps/com.wsl.noom SUCCESS
# http://localhost:3000/api/apps/com.coco2games.whisper SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/mobi.abcmouse.mrt.google SUCCESS
# http://localhost:3000/api/apps/com.bytesequencing.spades_ads SUCCESS
# http://localhost:3000/api/apps/com.narvii.amino.x22 SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.funnyplaygames.motocrosssimulator SUCCESS
# http://localhost:3000/api/apps/a2z.Mobile.Event4706 SUCCESS
# Total number of apps 12068
# Collected app ids 34
# http://localhost:3000/api/apps/pop.bubble.mega SUCCESS
# http://localhost:3000/api/apps/com.brdances.emotesbr SUCCESS
# http://localhost:3000/api/apps/com.womenwedding.photosuit SUCCESS
# http://localhost:3000/api/apps/com.mobirate.rovercraft.gplay SUCCESS
# http://localhost:3000/api/apps/com.ibyteapps.sobertoday SUCCESS
# http://localhost:3000/api/apps/com.jdgames.p16snew.googleplay SUCCESS
# http://localhost:3000/api/apps/com.nordcurrent.canteenhd SUCCESS
# http://localhost:3000/api/apps/id.co.bri.brimo SUCCESS
# http://localhost:3000/api/apps/com.omarecalde.recetasparaninos SUCCESS
# http://localhost:3000/api/apps/co.bird.android SUCCESS
# Total number of apps 12183
# Collected app ids 34
# http://localhost:3000/api/apps/com.ubisoft.dragonfire SUCCESS
# http://localhost:3000/api/apps/com.takashi.loveletters SUCCESS
# http://localhost:3000/api/apps/com.wordsmobile.RealBikeRacing SUCCESS
# http://localhost:3000/api/apps/br.com.rodrigokolb.realbass SUCCESS
# http://localhost:3000/api/apps/de.cyberdream.firenotifications.google SUCCESS
# http://localhost:3000/api/apps/com.sunmax.ktp SUCCESS
# http://localhost:3000/api/apps/homeworkout.homeworkouts.noequipment SUCCESS
# http://localhost:3000/api/apps/com.stencyl.rowdywrestling SUCCESS
# http://localhost:3000/api/apps/com.my.awa SUCCESS
# http://localhost:3000/api/apps/com.trucorp.trumonitor SUCCESS
# Total number of apps 12315
# Collected app ids 34
# http://localhost:3000/api/apps/com.electrowolff.war SUCCESS
# http://localhost:3000/api/apps/com.as.sadwords SUCCESS
# http://localhost:3000/api/apps/com.africanshweshwedresses.lonodev SUCCESS
# http://localhost:3000/api/apps/br.com.balaozinhos SUCCESS
# http://localhost:3000/api/apps/com.pitashi.audiojoy.empoweredhypnosisaddiction SUCCESS
# http://localhost:3000/api/apps/com.iboattech.lolita SUCCESS
# http://localhost:3000/api/apps/com.xzdailygame.GardenBlossom SUCCESS
# http://localhost:3000/api/apps/com.sometimeswefly.littlealchemy SUCCESS
# http://localhost:3000/api/apps/com.faceboo.statusonline SUCCESS
# http://localhost:3000/api/apps/com.appmind.radios.vn SUCCESS
# Total number of apps 12475
# Collected app ids 34
# http://localhost:3000/api/apps/com.hidden.cam_detector.mic_detector SUCCESS
# http://localhost:3000/api/apps/com.Winter.Fashion.Trends SUCCESS
# http://localhost:3000/api/apps/ro.mb.mastery SUCCESS
# http://localhost:3000/api/apps/com.ccswe.SmokingLog SUCCESS
# http://localhost:3000/api/apps/bg.mobio.angeltarotlove SUCCESS
# http://localhost:3000/api/apps/com.ozrunways.marvin SUCCESS
# http://localhost:3000/api/apps/com.next.babyphotoframes SUCCESS
# http://localhost:3000/api/apps/com.m3uloader.player SUCCESS
# http://localhost:3000/api/apps/com.mr.goodmorningphotoframes SUCCESS
# http://localhost:3000/api/apps/me.scan.android.client SUCCESS
# Total number of apps 12762
# Collected app ids 34
# http://localhost:3000/api/apps/com.saan.nclexpnexamprep SUCCESS
# http://localhost:3000/api/apps/com.Love.Story.Games.Romance.Choice SUCCESS
# http://localhost:3000/api/apps/cc.chenhe.weargallery SUCCESS
# http://localhost:3000/api/apps/com.ninetailgames.roguehearts.paid SUCCESS
# http://localhost:3000/api/apps/com.leafgreen.unhappy SUCCESS
# http://localhost:3000/api/apps/com.klab.bleach SUCCESS
# http://localhost:3000/api/apps/com.ajnsnewmedia.kitchenstories SUCCESS
# http://localhost:3000/api/apps/ar.com.megaingenieria.emobi.locator SUCCESS
# http://localhost:3000/api/apps/com.yanka.mc SUCCESS
# http://localhost:3000/api/apps/com.maximus.enrollment.healthyla SUCCESS
# Total number of apps 12979
# Collected app ids 34
# http://localhost:3000/api/apps/com.subletapp.sublet SUCCESS
# http://localhost:3000/api/apps/com.merriamwebster SUCCESS
# http://localhost:3000/api/apps/com.wb.goog.ellentube SUCCESS
# http://localhost:3000/api/apps/com.pixel.gun3d SUCCESS
# http://localhost:3000/api/apps/com.wpl.advance.car.driving.school.parking.games SUCCESS
# http://localhost:3000/api/apps/de.markt.android.classifieds.df SUCCESS
# http://localhost:3000/api/apps/com.wpl.ultimate.car.racing.game SUCCESS
# http://localhost:3000/api/apps/com.hover1bike.hover1 SUCCESS
# http://localhost:3000/api/apps/com.ndappsgames.dancefitness SUCCESS
# http://localhost:3000/api/apps/com.science.wishboneapp SUCCESS
# Total number of apps 13176
# Collected app ids 34
# http://localhost:3000/api/apps/com.vaporwave.aesthetic SUCCESS
# http://localhost:3000/api/apps/air.MermaidDollmakerENHANCED SUCCESS
# http://localhost:3000/api/apps/me.xceed.party SUCCESS
# http://localhost:3000/api/apps/com.miniclip.basketballstars SUCCESS
# http://localhost:3000/api/apps/com.gc.teammanager SUCCESS
# http://localhost:3000/api/apps/com.cyberlink.photodirector SUCCESS
# http://localhost:3000/api/apps/com.smarttool.patternphoto SUCCESS
# http://localhost:3000/api/apps/a2z.Mobile.Event5596 SUCCESS
# http://localhost:3000/api/apps/com.ultimateapps.nclexpn SUCCESS
# http://localhost:3000/api/apps/com.pikasapps.blackcats.wallpapers SUCCESS
# Total number of apps 13348
# Collected app ids 34
# http://localhost:3000/api/apps/id.mucho SUCCESS
# http://localhost:3000/api/apps/com.rstgames.durak SUCCESS
# http://localhost:3000/api/apps/ar.com.basejuegos.simplealarm SUCCESS
# http://localhost:3000/api/apps/com.LoopGames.Blast SUCCESS
# http://localhost:3000/api/apps/com.springloaded.thelastvikings SUCCESS
# http://localhost:3000/api/apps/com.dvloper.granny SUCCESS
# http://localhost:3000/api/apps/com.camera.beautycam SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.cylonblast.homemadebeautyguidesfacialcare SUCCESS
# http://localhost:3000/api/apps/com.cobra.srpagopos SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.bg.kungfu.karate.fighting.tiger.martialarts.punchkick.ninja SUCCESS
# Total number of apps 13512
# Collected app ids 36
# http://localhost:3000/api/apps/com.ketchapp.jellyjump SUCCESS
# http://localhost:3000/api/apps/com.cardgame.solitaire SUCCESS
# http://localhost:3000/api/apps/wiktoria.goroch.bible_kjv.AOUSSDQLXBLBGHWY SUCCESS
# http://localhost:3000/api/apps/pk.gov.pitb.sis SUCCESS
# http://localhost:3000/api/apps/onxmaps.hunt SUCCESS
# http://localhost:3000/api/apps/net.fieldagent SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/air.ru.mail.games.backgammonlong SUCCESS
# http://localhost:3000/api/apps/com.aap.cmcpnjb_cmplntrck.cmcmil_cmpln.cmcwpdaal_cmplinpr.cmpnjbtrck_cmplnhistry SUCCESS
# http://localhost:3000/api/apps/com.lyrebirdstudio.nocrop SUCCESS
# http://localhost:3000/api/apps/com.samsung.android.galaxycontinuity SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# Total number of apps 13695
# Collected app ids 38
# http://localhost:3000/api/apps/com.timeplay SUCCESS
# http://localhost:3000/api/apps/com.inditex.ecommerce.bershka SUCCESS
# http://localhost:3000/api/apps/com.getmarketingtutorials.occultlibrary SUCCESS
# http://localhost:3000/api/apps/com.genius.vampire2 SUCCESS
# http://localhost:3000/api/apps/com.otherguys.zoe SUCCESS
# http://localhost:3000/api/apps/biblia.feminina.diaria SUCCESS
# http://localhost:3000/api/apps/hsl.p2pipcam SUCCESS
# http://localhost:3000/api/apps/time.bubble SUCCESS
# http://localhost:3000/api/apps/com.herogame.gplay.evolutionchess SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.piki.reference.book.babycare SUCCESS
# Total number of apps 13816
# Collected app ids 39
# http://localhost:3000/api/apps/offline.bible.free SUCCESS
# http://localhost:3000/api/apps/com.romerock.apps.utilities.fstats SUCCESS
# http://localhost:3000/api/apps/com.radiolight.indonesie SUCCESS
# http://localhost:3000/api/apps/com.grootersproductions.challenge SUCCESS
# http://localhost:3000/api/apps/com.caracoltv.lakalle SUCCESS
# http://localhost:3000/api/apps/kr.co.smartstudy.babysharkcoloring_android_googlemarket SUCCESS
# http://localhost:3000/api/apps/br.biblia SUCCESS
# http://localhost:3000/api/apps/com.enter_the_gunbook SUCCESS
# http://localhost:3000/api/apps/com.taka.losebellyfat SUCCESS
# http://localhost:3000/api/apps/com.leodesol.games.puzzlecollection SUCCESS
# Total number of apps 13967
# Collected app ids 39
# http://localhost:3000/api/apps/com.xcandroider.bookslibrary SUCCESS
# http://localhost:3000/api/apps/org.khanacademy.android SUCCESS
# http://localhost:3000/api/apps/com.xnview.XnSketch SUCCESS
# http://localhost:3000/api/apps/com.roc_connect.ozom.app SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.pokemon.pokemontcg SUCCESS
# http://localhost:3000/api/apps/br.com.tapps.bostondonuttruck SUCCESS
# http://localhost:3000/api/apps/melstudio.myogafat SUCCESS
# http://localhost:3000/api/apps/com.New.Ringtones2018 SUCCESS
# http://localhost:3000/api/apps/com.flashcardinc.teas2 SUCCESS
# http://localhost:3000/api/apps/com.bcp.bank.bcp SUCCESS
# Total number of apps 14142
# Collected app ids 40
# http://localhost:3000/api/apps/com.kncv.sitrust SUCCESS
# http://localhost:3000/api/apps/be.antwerpen.velo SUCCESS
# http://localhost:3000/api/apps/com.boombit.solitaire.adventure.journey SUCCESS
# http://localhost:3000/api/apps/admobileapps.lovechinesesong SUCCESS
# http://localhost:3000/api/apps/com.mobileaddicts.rattle SUCCESS
# http://localhost:3000/api/apps/siddguru99.prizebond.prizebond_tracker_scanner SUCCESS
# http://localhost:3000/api/apps/com.cocoplay.promqueen SUCCESS
# http://localhost:3000/api/apps/com.zillow.android.streeteasy SUCCESS
# http://localhost:3000/api/apps/com.mobirate.parkingmania3d SUCCESS
# http://localhost:3000/api/apps/com.blindflugstudios.firststrike.free SUCCESS
# Total number of apps 14272
# Collected app ids 40
# http://localhost:3000/api/apps/com.lumeos SUCCESS
# http://localhost:3000/api/apps/com.netease.lztgglobal SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/a2z.Mobile.Event4413 SUCCESS
# http://localhost:3000/api/apps/com.vgminds.mrbell2 SUCCESS
# http://localhost:3000/api/apps/com.aktuna.gear.facebook SUCCESS
# http://localhost:3000/api/apps/com.time.to.quit.smoke SUCCESS
# http://localhost:3000/api/apps/bible.commentary SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev623845.app700415 SUCCESS
# http://localhost:3000/api/apps/net.peakgames.bidwhist SUCCESS
# http://localhost:3000/api/apps/com.ketchapp.dunkshot SUCCESS
# Total number of apps 14441
# Collected app ids 41
# http://localhost:3000/api/apps/com.hungry.crocodile.simulator SUCCESS
# http://localhost:3000/api/apps/com.wastickerappfortnite.stickertest SUCCESS
# http://localhost:3000/api/apps/com.uthink.ring SUCCESS
# http://localhost:3000/api/apps/com.atsdev.babyphotomontage SUCCESS
# http://localhost:3000/api/apps/com.paybyphone SUCCESS
# http://localhost:3000/api/apps/com.sololearn.python SUCCESS
# http://localhost:3000/api/apps/app.weightfit.android SUCCESS
# http://localhost:3000/api/apps/tv.twitch.android.app SUCCESS
# PERMISSION EXIST
# PREVIOUSLY DOWNLOADED
# http://localhost:3000/api/apps/com.sparkwave.mindease SUCCESS
# http://localhost:3000/api/apps/net.beatapper.disablesecret SUCCESS
# Total number of apps 14552
# Collected app ids 42
# http://localhost:3000/api/apps/com.sma.smartalarm SUCCESS
# http://localhost:3000/api/apps/com.mobisystems.ubreader_west SUCCESS
# http://localhost:3000/api/apps/ch.mobility.mobidroid.main SUCCESS
# http://localhost:3000/api/apps/com.nexttechgamesstudio.flowers.poly.art.color.by.number.pixel.art SUCCESS
# http://localhost:3000/api/apps/com.getheal.patient SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# ...
# http://localhost:3000/api/apps/com.creativeimageapps.RosasParaCumples SUCCESS
# http://localhost:3000/api/apps/com.surfcityapps.attractlove SUCCESS
# http://localhost:3000/api/apps/com.dask.Blurphotobackground SUCCESS
# http://localhost:3000/api/apps/com.englearner.tamiltohindispeaking SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.appsolutely.aps SUCCESS
# http://localhost:3000/api/apps/com.tamera.hwsnea.tamera SUCCESS
# http://localhost:3000/api/apps/com.stolencar.FindStolenCar SUCCESS
# http://localhost:3000/api/apps/com.kitabwala.mamoolatesubhashaam SUCCESS
# http://localhost:3000/api/apps/com.dts.freefireth SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.phoneRingtones.Redmi SUCCESS
# http://localhost:3000/api/apps/com.vanuatu.aiqfome SUCCESS
# http://localhost:3000/api/apps/com.prodyapps.crecimiento.espiritual.cristiano SUCCESS
# http://localhost:3000/api/apps/com.holy_bible_audio_mp3.holy_bible_audio_mp3 SUCCESS
# http://localhost:3000/api/apps/com.naver.shopping.biztalk SUCCESS
# http://localhost:3000/api/apps/com.mightytext.tablet SUCCESS
# http://localhost:3000/api/apps/lt.barbora SUCCESS
# http://localhost:3000/api/apps/com.motivacion2018.imagenesdefloresyrosasnaturalesenhdgratis SUCCESS
# http://localhost:3000/api/apps/com.sec.android.app.popupcalculator SUCCESS
# http://localhost:3000/api/apps/com.doceapps_alcorao_audio_swahili.doceapps_alcorao_audio_swahili SUCCESS
# http://localhost:3000/api/apps/pixelab.camart.cartoon SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.niros.isteppedinshit SUCCESS
# http://localhost:3000/api/apps/com.expresscheckout.customer SUCCESS
# http://localhost:3000/api/apps/com.publix.publixsecure SUCCESS
# http://localhost:3000/api/apps/br.lgfelicio SUCCESS
# http://localhost:3000/api/apps/com.matometab.jwest SUCCESS
# http://localhost:3000/api/apps/com.makeshop.powerapp.tecnifibre SUCCESS
# http://localhost:3000/api/apps/com.icicibank.istudiovoice SUCCESS
# http://localhost:3000/api/apps/com.dawateislami.hajiabdulhabib SUCCESS
# http://localhost:3000/api/apps/com.wikitech.mehndidesigns SUCCESS
# http://localhost:3000/api/apps/com.shinycore.picsayfree SUCCESS
# http://localhost:3000/api/apps/maratische.android.phonesmscodes SUCCESS
# http://localhost:3000/api/apps/com.communities.neighborhood SUCCESS
# http://localhost:3000/api/apps/com.codfidea.nocropinstapic SUCCESS
# http://localhost:3000/api/apps/com.mojotouch.fotaq SUCCESS
# http://localhost:3000/api/apps/com.flyingfox.x_sakura_free SUCCESS
# http://localhost:3000/api/apps/com.deemples.v2 SUCCESS
# http://localhost:3000/api/apps/com.prepladder.medicalprep SUCCESS
# http://localhost:3000/api/apps/com.tutotoons.app.sweetbabygirlcleanup6.free SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.purplediamonds SUCCESS
# http://localhost:3000/api/apps/inc.com.youbo.invocationsquotidiennes.free SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.cupid.pretty.girl SUCCESS
# http://localhost:3000/api/apps/com.hypermania.crush.soft.things SUCCESS
# http://localhost:3000/api/apps/com.ttsolution.chigoogle SUCCESS
# http://localhost:3000/api/apps/org.yufid.hisnulmuslim SUCCESS
# http://localhost:3000/api/apps/com.tourbillon.freeappsnow SUCCESS
# http://localhost:3000/api/apps/com.radiofmapp.radioireland SUCCESS
# http://localhost:3000/api/apps/com.maltaapps.khwabkitabeer SUCCESS
# http://localhost:3000/api/apps/com.hongoapps.quotesfakefriends SUCCESS
# http://localhost:3000/api/apps/com.livos.companionplants SUCCESS
# http://localhost:3000/api/apps/com.affinityblue.tunable SUCCESS
# http://localhost:3000/api/apps/sk.peterjurkovic.dril SUCCESS
# http://localhost:3000/api/apps/com.ekonom.taxi SUCCESS
# http://localhost:3000/api/apps/com.cactus.umarhayomru SUCCESS
# http://localhost:3000/api/apps/com.Whitebreastedwaterhen.sound SUCCESS
# http://localhost:3000/api/apps/com.mndevelop.biblestory SUCCESS
# http://localhost:3000/api/apps/br.com.mobiletkbrazil.minhasdespesasplus SUCCESS
# http://localhost:3000/api/apps/com.messenger.sms.theme.green.flower SUCCESS
# http://localhost:3000/api/apps/com.korean.idolsticker.wastickerapps.free SUCCESS
# http://localhost:3000/api/apps/daisy.live.free.background SUCCESS
# http://localhost:3000/api/apps/shix.camera.ipcview1 SUCCESS
# http://localhost:3000/api/apps/com.supermama.supermama SUCCESS
# http://localhost:3000/api/apps/com.mysewnet.husqvarnaviking.projectreader SUCCESS
# http://localhost:3000/api/apps/com.maps.appsmapsgps.navigationgpsi SUCCESS
# http://localhost:3000/api/apps/com.kbzbank.kbzconnect SUCCESS
# http://localhost:3000/api/apps/com.tradovate.topstep.trader SUCCESS
# http://localhost:3000/api/apps/net.daliv3.taac SUCCESS
# http://localhost:3000/api/apps/com.excelatlife.happiness SUCCESS
# http://localhost:3000/api/apps/com.exlivinapps.radioschlagerparadieskostenlosappde SUCCESS
# http://localhost:3000/api/apps/in.plash.dalalstreet SUCCESS
# http://localhost:3000/api/apps/dev.mobile.wallpaperschadwildclay SUCCESS
# http://localhost:3000/api/apps/com.cowon.aw1 SUCCESS
# http://localhost:3000/api/apps/ch.zhaw.nishtha_att_sys SUCCESS
# http://localhost:3000/api/apps/com.creativeimageapps.RosasConFrasesBonitas SUCCESS
# http://localhost:3000/api/apps/com.goodbarber.spaziointer SUCCESS
# http://localhost:3000/api/apps/net.sharewire.meterUP SUCCESS
# http://localhost:3000/api/apps/de.moemke.android.mycamino SUCCESS
# http://localhost:3000/api/apps/com.mukafaat.tarfeeh SUCCESS
# http://localhost:3000/api/apps/com.nta.live.earthview.maps.gpsroute.mapfinder.apps SUCCESS
# http://localhost:3000/api/apps/com.jb.gokeyboard.theme.zthalo.getjar SUCCESS
# http://localhost:3000/api/apps/com.boxybee.beenary SUCCESS
# http://localhost:3000/api/apps/com.aaglodapps.mathssolution10thstd SUCCESS
# http://localhost:3000/api/apps/com.ncconsulting.skipthedishes_android SUCCESS
# http://localhost:3000/api/apps/com.guaranteedrate.grloans SUCCESS
# http://localhost:3000/api/apps/com.france.voituredoccasion SUCCESS
# http://localhost:3000/api/apps/com.skyinfoway.waterfallphotoframes SUCCESS
# http://localhost:3000/api/apps/br.com.tapps.merge.goat SUCCESS
# http://localhost:3000/api/apps/com.rowdy.calculatorvault SUCCESS
# http://localhost:3000/api/apps/com.extricks.whatsdeleted SUCCESS
# http://localhost:3000/api/apps/jp.co.pit.select100 SUCCESS
# http://localhost:3000/api/apps/me.lfasmpao.tunnelcat SUCCESS
# http://localhost:3000/api/apps/io.voodoo.tenkyu SUCCESS
# http://localhost:3000/api/apps/app.free.dictionaryen_persion SUCCESS
# http://localhost:3000/api/apps/com.bajqjqjl.machmaxe.kafonix SUCCESS
# http://localhost:3000/api/apps/mob.franceantilles.gp SUCCESS
# http://localhost:3000/api/apps/my.smartech.mp3quran SUCCESS
# http://localhost:3000/api/apps/de.cheyennex.cc SUCCESS
# http://localhost:3000/api/apps/com.vajehyab.app SUCCESS
# http://localhost:3000/api/apps/com.bmwgroup.driversguide.usa SUCCESS
# http://localhost:3000/api/apps/com.cryart.sabbathschool SUCCESS
# http://localhost:3000/api/apps/io.smartup.learn SUCCESS
# http://localhost:3000/api/apps/com.unwinrecordsllc.turkimod SUCCESS
# http://localhost:3000/api/apps/com.softsquare.man.bike.moto.suit.photo.editor SUCCESS
# http://localhost:3000/api/apps/com.appybuilder.hossaintanger11.massagelove SUCCESS
# http://localhost:3000/api/apps/com.winsat.gtplayer SUCCESS
# http://localhost:3000/api/apps/com.elmurjee.BraidHairstyle SUCCESS
# http://localhost:3000/api/apps/com.nexttechgamesstudio.racing.cars.color.by.number.vehicles.coloring.book.pages SUCCESS
# http://localhost:3000/api/apps/com.mp3.music.download.search.musicplayer SUCCESS
# http://localhost:3000/api/apps/com.ensoft.imgurviewer SUCCESS
# http://localhost:3000/api/apps/com.azkar.sabah.masae SUCCESS
# http://localhost:3000/api/apps/com.novateam.englishspeak SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.euustours.myapp SUCCESS
# http://localhost:3000/api/apps/com.appmine.editing_apps.autocutimageediting SUCCESS
# http://localhost:3000/api/apps/com.gatedesignsforhome.rollingdev SUCCESS
# http://localhost:3000/api/apps/osa.ora.quran SUCCESS
# http://localhost:3000/api/apps/com.alhamdany.mustafa.stories SUCCESS
# http://localhost:3000/api/apps/com.futurecab SUCCESS
# http://localhost:3000/api/apps/com.shipt.groceries SUCCESS
# http://localhost:3000/api/apps/com.classlist.parent SUCCESS
# http://localhost:3000/api/apps/com.universl.mahapiritha SUCCESS
# http://localhost:3000/api/apps/com.actionjacquelyn.ActionAcademy SUCCESS
# http://localhost:3000/api/apps/com.uzurv.uzurv360Driver SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.diamond.pearl.heart SUCCESS
# http://localhost:3000/api/apps/com.ig.android.ta SUCCESS
# http://localhost:3000/api/apps/com.balanak.antoniosolis SUCCESS
# http://localhost:3000/api/apps/com.skor.app.player.free SUCCESS
# http://localhost:3000/api/apps/com.ufukmarmara.ezan SUCCESS
# http://localhost:3000/api/apps/com.eog.train.simulator.train.game SUCCESS
# http://localhost:3000/api/apps/com.magmon.cartooncraft SUCCESS
# http://localhost:3000/api/apps/jp.co.a_tm.android.plus_pastel_floral SUCCESS
# http://localhost:3000/api/apps/xyz.statedge.xlplorer.app SUCCESS
# http://localhost:3000/api/apps/com.hypertonicapps.xhosaenglishtranslator SUCCESS
# http://localhost:3000/api/apps/net.ciprianmarin.radioukraine SUCCESS
# http://localhost:3000/api/apps/com.alghazwafawatircrissapps SUCCESS
# http://localhost:3000/api/apps/tv.nexstar.id3570new SUCCESS
# http://localhost:3000/api/apps/br.com.zeroum.pequerruchosandroid SUCCESS
# http://localhost:3000/api/apps/ru.yandex.mobile.metrica SUCCESS
# http://localhost:3000/api/apps/com.mixlabapps.lifemotivationquotes SUCCESS
# http://localhost:3000/api/apps/com.involta.womencalendar SUCCESS
# http://localhost:3000/api/apps/com.veitch.themelodymaster.psajf SUCCESS
# http://localhost:3000/api/apps/org.zenbaei.kalematAlQuraan SUCCESS
# http://localhost:3000/api/apps/com.playquiz2win.ows.quiz SUCCESS
# http://localhost:3000/api/apps/com.ilikemycountry.af_flagfree SUCCESS
# http://localhost:3000/api/apps/com.imobaio.android.apps.ac24horas SUCCESS
# http://localhost:3000/api/apps/jp.co.a_tm.android.plus_baika SUCCESS
# http://localhost:3000/api/apps/bible.easy.to.read.version SUCCESS
# http://localhost:3000/api/apps/com.city.limousine.car.simulator SUCCESS
# http://localhost:3000/api/apps/app.opass.ccip SUCCESS
# http://localhost:3000/api/apps/com.tokyocoldstudio.farmGardenRoad SUCCESS
# http://localhost:3000/api/apps/com.jiwoosoft.pdfviewer SUCCESS
# http://localhost:3000/api/apps/com.nirkof.slim30 SUCCESS
# http://localhost:3000/api/apps/com.larixon.pin SUCCESS
# http://localhost:3000/api/apps/com.miko3apps.inspirationalbibleverses SUCCESS
# http://localhost:3000/api/apps/com.sc.breezenigeria.banking SUCCESS
# http://localhost:3000/api/apps/com.gopro.smarty SUCCESS
# http://localhost:3000/api/apps/com.video.tebamadya SUCCESS
# http://localhost:3000/api/apps/bpt.com.coopebombas SUCCESS
# http://localhost:3000/api/apps/com.keeate.appef02dff37cad8c10023372ea7f0c70f041da24e9 SUCCESS
# http://localhost:3000/api/apps/com.adelinolobao.hungarynews SUCCESS
# http://localhost:3000/api/apps/com.appsarfan.musicabachatagratis SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.amparosoft.progressivemetronome.free SUCCESS
# http://localhost:3000/api/apps/com.plus.music.playrv2 SUCCESS
# http://localhost:3000/api/apps/com.topfanringtones.breakingbadringtones SUCCESS
# http://localhost:3000/api/apps/com.islamisejati.ruqyahdiridansekitarnyaforextradingonline SUCCESS
# http://localhost:3000/api/apps/com.kigle.project.poli.english.lite.eng SUCCESS
# http://localhost:3000/api/apps/jp.sov.mediaapp SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.summer.holiday.seaside SUCCESS
# http://localhost:3000/api/apps/news.TamilNewsPaper SUCCESS
# http://localhost:3000/api/apps/com.samsung.android.soundassistant SUCCESS
# http://localhost:3000/api/apps/com.cadenas.cadmodels SUCCESS
# http://localhost:3000/api/apps/com.textbyvoice.audiototext.chat SUCCESS
# http://localhost:3000/api/apps/com.vpitv SUCCESS
# http://localhost:3000/api/apps/com.BorisTouvoli.robes_de_soiree_1 SUCCESS
# http://localhost:3000/api/apps/menion.android.locus.gis SUCCESS
# http://localhost:3000/api/apps/com.groupd.railway SUCCESS
# http://localhost:3000/api/apps/com.nieto.luis.hidro_i SUCCESS
# http://localhost:3000/api/apps/ar.com.santander.rio.mbanking SUCCESS
# http://localhost:3000/api/apps/ap.tvmak.com SUCCESS
# http://localhost:3000/api/apps/com.ite.lichamduong SUCCESS
# http://localhost:3000/api/apps/com.bestbaking.primex SUCCESS
# http://localhost:3000/api/apps/com.galaxy.s7.edge.theme.launcher SUCCESS
# http://localhost:3000/api/apps/com.hans.lotto.sa.nlotto SUCCESS
# http://localhost:3000/api/apps/com.zddapps.beautytips SUCCESS
# http://localhost:3000/api/apps/com.fxprotrader98.Forex_and_binary_Strategy_2019 SUCCESS
# http://localhost:3000/api/apps/ru.liogames.kidsframes SUCCESS
# http://localhost:3000/api/apps/net.grandpad.puma SUCCESS
# http://localhost:3000/api/apps/qanoon.asasi.com SUCCESS
# http://localhost:3000/api/apps/app.easytoken SUCCESS
# http://localhost:3000/api/apps/com.vusecurity.lapampa.token.android SUCCESS
# http://localhost:3000/api/apps/it.mls.barismart SUCCESS
# http://localhost:3000/api/apps/planetevoyance.raspoutine_voyance SUCCESS
# http://localhost:3000/api/apps/com.punchh.mod SUCCESS
# http://localhost:3000/api/apps/com.enlightment.appslocker SUCCESS
# http://localhost:3000/api/apps/com.snapbreak.escapeloganestate SUCCESS
# http://localhost:3000/api/apps/ps.wataniyamobile SUCCESS
# http://localhost:3000/api/apps/air.br.com.cacheta.mobile SUCCESS
# http://localhost:3000/api/apps/com.sharefunapp.topringtones2018 SUCCESS
# http://localhost:3000/api/apps/com.chegal.mobilesales SUCCESS
# http://localhost:3000/api/apps/com.farlex.dictionary.dutch SUCCESS
# http://localhost:3000/api/apps/com.trickyment.GurjarStatus SUCCESS
# http://localhost:3000/api/apps/com.plangrid.android SUCCESS
# http://localhost:3000/api/apps/nawatkorn.app.idontcare SUCCESS
# http://localhost:3000/api/apps/com.piki.reference.book.babytipsen SUCCESS
# http://localhost:3000/api/apps/com.bts.video.vvideo SUCCESS
# http://localhost:3000/api/apps/org.iaff.mobile SUCCESS
# http://localhost:3000/api/apps/mobi.abcmouse.zoo.google SUCCESS
# http://localhost:3000/api/apps/com.david_wallpapers.fruits SUCCESS
# http://localhost:3000/api/apps/com.language.learngreek SUCCESS
# http://localhost:3000/api/apps/com.chymmy.olauncher SUCCESS
# http://localhost:3000/api/apps/com.bugfiesta.torrenthunter SUCCESS
# http://localhost:3000/api/apps/com.tutfactory.vaasthusaasthram SUCCESS
# http://localhost:3000/api/apps/com.robinhood.android SUCCESS
# http://localhost:3000/api/apps/com.avelsoft.math SUCCESS
# http://localhost:3000/api/apps/ruslan.bahtyev.app SUCCESS
# http://localhost:3000/api/apps/air.com.noxgames.PuppetHockey SUCCESS
# http://localhost:3000/api/apps/com.bible.TwiBibleAsanteFree SUCCESS
# http://localhost:3000/api/apps/free_translator.koen SUCCESS
# http://localhost:3000/api/apps/com.gmanmi.entertainment.mobile SUCCESS
# http://localhost:3000/api/apps/com.emisora.olimpica SUCCESS
# http://localhost:3000/api/apps/com.sendoutcards.sendoutcards SUCCESS
# http://localhost:3000/api/apps/klwinkel.flexr.pro SUCCESS
# http://localhost:3000/api/apps/com.inkboard.app SUCCESS
# http://localhost:3000/api/apps/com.vti.homemate SUCCESS
# http://localhost:3000/api/apps/org.worldliturgy.anglicanchurchkenya SUCCESS
# http://localhost:3000/api/apps/com.darkcube.binnm SUCCESS
# PERMISSION EXIST
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-cb840c2a127d> in <module>()
#      66                     print("PERMISSION EXIST")
#      67                     app_ids.add(application_id )
# ---> 68                     cat = get_app_category(application_id)
#      69                     with open("{}/{}.txt".format(permission_type, cat), "a") as target:
#      70                         if application_id not in dowloaded_list:
#
# <ipython-input-5-9d4503f9f126> in get_app_category(app_id)
#       3     response = requests.get(base_url+app_id)
#       4     if response.status_code == 200:
# ----> 5         gid = response.json()["genreId"].upper()
#       6         return gid
#       7     else:
#
# KeyError: 'genreId'

# %%
print("TRAVERSING COMPLETED")
for url in waiting_urls:
    print(url, end=" ")
    response = requests.get(url)
    if response.status_code == 200:
        print("SUCCESS")
        json = response.json()
        if json["minInstalls"] > 10000 and json["priceText"] == "Free" and len(json["description"]) > 500:
            application_id = url.split('/')[-1]
            if application_id not in app_ids:
                if is_permission_exist(url):
                    try:
                        print("PERMISSION EXIST")
                        app_ids.add(application_id )
                        cat = get_app_category(application_id)
                        with open("{}/{}.txt".format(permission_type, cat), "a") as target:
                            if application_id not in dowloaded_list:
                                target.write(application_id + "\n")
                    except Exception:
                        pass
    else:
        print("FAIL")
# Out:
# TRAVERSING COMPLETED
# http://localhost:3000/api/apps/com.coco2games.whisper SUCCESS
# http://localhost:3000/api/apps/com.devemendous.telve SUCCESS
# http://localhost:3000/api/apps/br.com.aleluiah_apps.bibliasagrada.en_woman SUCCESS
# http://localhost:3000/api/apps/com.narvii.amino.x220474164 SUCCESS
# http://localhost:3000/api/apps/com.appFactory.wan SUCCESS
# http://localhost:3000/api/apps/org.kape.smartbooks SUCCESS
# http://localhost:3000/api/apps/com.bts.dance.line.dancing.music.song.kpop.freegame.magic SUCCESS
# http://localhost:3000/api/apps/com.hughesfcu.mobile SUCCESS
# http://localhost:3000/api/apps/com.cintexwireless SUCCESS
# http://localhost:3000/api/apps/com.forsbit.freecelladfree SUCCESS
# http://localhost:3000/api/apps/pine.game.skydancer SUCCESS
# http://localhost:3000/api/apps/mobmix.keralapscrepeatingquestions SUCCESS
# http://localhost:3000/api/apps/com.jundroo.SimplePlanes SUCCESS
# http://localhost:3000/api/apps/gis.android.map SUCCESS
# http://localhost:3000/api/apps/com.KingsIsle.RES SUCCESS
# http://localhost:3000/api/apps/com.bs.reader.pdfviewer SUCCESS
# http://localhost:3000/api/apps/com.raloco.qrcode SUCCESS
# http://localhost:3000/api/apps/net.bimmergeeks SUCCESS
# http://localhost:3000/api/apps/com.hallucind.flashcards SUCCESS
# http://localhost:3000/api/apps/ru.koljanych.faktyfree SUCCESS
# http://localhost:3000/api/apps/com.benoitgourdin.flammerougecompanion SUCCESS
# http://localhost:3000/api/apps/md.insights.vet.rsp SUCCESS
# http://localhost:3000/api/apps/ovh.sauzanaprod.meteohongrie SUCCESS
# http://localhost:3000/api/apps/com.hibapress.ar SUCCESS
# http://localhost:3000/api/apps/ru.yandex.mail SUCCESS
# http://localhost:3000/api/apps/xyz.blueowl.mobile.hiroad SUCCESS
# http://localhost:3000/api/apps/com.fitnesscircle.stickerart SUCCESS
# http://localhost:3000/api/apps/com.dwpproject.laguungu SUCCESS
# http://localhost:3000/api/apps/com.onezoneapps.lum.offline SUCCESS
# http://localhost:3000/api/apps/com.malauzai.DH25734 SUCCESS
# http://localhost:3000/api/apps/com.mssoft.todaysaju SUCCESS
# http://localhost:3000/api/apps/com.currencyconverter.jpykrw SUCCESS
# http://localhost:3000/api/apps/com.alijdeveloper.autoazanalarm SUCCESS
# http://localhost:3000/api/apps/com.Fabcab SUCCESS
# http://localhost:3000/api/apps/ramraksha.karlaapps.com.ramraksha SUCCESS
# http://localhost:3000/api/apps/com.app.HKcalendarOnly3 SUCCESS
# http://localhost:3000/api/apps/com.kumpulanhadistshahihterlengkap.onlineforextrading SUCCESS
# http://localhost:3000/api/apps/com.mobisystems.msdict.embedded.wireless.oxford.oxfordnursing SUCCESS
# http://localhost:3000/api/apps/com.shabakaty.muzikna SUCCESS
# http://localhost:3000/api/apps/com.sky.breakers.sickomode SUCCESS
# http://localhost:3000/api/apps/com.yapplications.unlockloghistory SUCCESS
# http://localhost:3000/api/apps/jp.dena.showroom SUCCESS
# http://localhost:3000/api/apps/english.arabic.besttranslate SUCCESS
# http://localhost:3000/api/apps/com.appbodia.translator.myen SUCCESS
# http://localhost:3000/api/apps/com.gercekzikirmatik.realtasbeehcounter SUCCESS
# http://localhost:3000/api/apps/com.venninteractive.ssfasting SUCCESS
# http://localhost:3000/api/apps/com.swash.transitworld.houston SUCCESS
# http://localhost:3000/api/apps/free_translator.roru SUCCESS
# http://localhost:3000/api/apps/com.tgif.girly.lock.screen.wallpaper.with.quotes SUCCESS
# http://localhost:3000/api/apps/com.punchh.graeters SUCCESS
# http://localhost:3000/api/apps/com.light.crown.effect.forselfie.camera SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev391844.app581015 SUCCESS
# http://localhost:3000/api/apps/myapp.all_offline_indian_recipes_hindi SUCCESS
# http://localhost:3000/api/apps/com.draftkings.dknativermgGP SUCCESS
# Permission link is failed
# http://localhost:3000/api/apps/com.studioraudhah.lagu60an SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev733677.app831251 SUCCESS
# http://localhost:3000/api/apps/com.nhlakaniphonkosi.k53southafricam SUCCESS
# http://localhost:3000/api/apps/com.kone.constant.mdtmugefci.gratuit SUCCESS
# http://localhost:3000/api/apps/com.dopewallpapers.trillwallpaper.hypebeast.streetwear.sick.cool.hype.backgrounds.hd SUCCESS
# http://localhost:3000/api/apps/com.useronestudio.radioguatemala SUCCESS
# http://localhost:3000/api/apps/com.mymobilewitness.seesend SUCCESS
# http://localhost:3000/api/apps/com.galleryvault SUCCESS
# http://localhost:3000/api/apps/com.spiritual.dakshinamoorthislokatamil SUCCESS
# http://localhost:3000/api/apps/com.dpiinc.ISBWV418B SUCCESS
# http://localhost:3000/api/apps/com.katakatabagusbuatupdatestatus.rumtanaallay SUCCESS
# http://localhost:3000/api/apps/com.nba.youngboykeyboard SUCCESS
# http://localhost:3000/api/apps/com.comput.samanyagk SUCCESS
# http://localhost:3000/api/apps/nauta.webmailv2 SUCCESS
# http://localhost:3000/api/apps/com.viapolares.playingpoetry.ru SUCCESS
# http://localhost:3000/api/apps/com.kpit.JSBApp SUCCESS
# http://localhost:3000/api/apps/com.klh.droniumzero SUCCESS
# http://localhost:3000/api/apps/com.visual3dscience.organs SUCCESS
# http://localhost:3000/api/apps/com.egnxt.facebook_video_downloader SUCCESS
# http://localhost:3000/api/apps/com.cowrywise.android SUCCESS
# http://localhost:3000/api/apps/com.mstoic.app.notesinnotification SUCCESS
# http://localhost:3000/api/apps/com.classlink.launchpad.android SUCCESS
# http://localhost:3000/api/apps/com.biquettestudio.neotravelyourmind.french SUCCESS
# http://localhost:3000/api/apps/de.waldau_webdesign.app.luxmeter SUCCESS
# http://localhost:3000/api/apps/joz2.lmojadala.lmaikli.ecrit SUCCESS
# http://localhost:3000/api/apps/org.alphons.programatamobile SUCCESS
# http://localhost:3000/api/apps/com.iyaltamizh.bluetoothprint SUCCESS
# http://localhost:3000/api/apps/rpf.n2018copy2 FAIL
# http://localhost:3000/api/apps/com.itsvibrant.yehiHaiJindagi SUCCESS
# http://localhost:3000/api/apps/com.Ftl.Marshmello.Live.Wallpapers SUCCESS
# http://localhost:3000/api/apps/com.valentin.baldalive SUCCESS
# http://localhost:3000/api/apps/org.openttd.sdl SUCCESS
# http://localhost:3000/api/apps/com.aaglodapps.mathssolution9thstdrdsharma SUCCESS
# http://localhost:3000/api/apps/bubble.coin SUCCESS
# http://localhost:3000/api/apps/com.gooddaytoday.naming SUCCESS
# http://localhost:3000/api/apps/ru.sports.atletico SUCCESS
# http://localhost:3000/api/apps/com.reader.book.anbiya SUCCESS
# http://localhost:3000/api/apps/de.westfunk.duisburg SUCCESS
# http://localhost:3000/api/apps/com.makeshop.powerapp.hellosuri SUCCESS
# http://localhost:3000/api/apps/com.allaboutradio.nederlandradio SUCCESS
# http://localhost:3000/api/apps/com.rayg.highvolumeringtones SUCCESS
# http://localhost:3000/api/apps/com.south.news SUCCESS
# http://localhost:3000/api/apps/app.nl.socialdeal SUCCESS
# http://localhost:3000/api/apps/com.safaroff.airport SUCCESS
# http://localhost:3000/api/apps/eu.womo_stellplatz.finder SUCCESS
# http://localhost:3000/api/apps/com.touchten.garden SUCCESS
# http://localhost:3000/api/apps/com.sinyee.babybus.moonexplorer.global SUCCESS
# http://localhost:3000/api/apps/jp.co.cyberagent.valencia SUCCESS
# http://localhost:3000/api/apps/pe.codespace.nanda SUCCESS
# http://localhost:3000/api/apps/ru.yandex.yandexmaps SUCCESS
# http://localhost:3000/api/apps/net.leafapps.baseballnews SUCCESS
# http://localhost:3000/api/apps/jp.co.excite.translate SUCCESS
# http://localhost:3000/api/apps/com.kiku.fluffybubble SUCCESS
# http://localhost:3000/api/apps/ru.serjik.hexshaders.premium SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev597108.app875820 SUCCESS
# http://localhost:3000/api/apps/nueva.traduccion.viviente.ntv SUCCESS
# http://localhost:3000/api/apps/com.wecut.artists SUCCESS
# http://localhost:3000/api/apps/com.djsoft.notepad SUCCESS
# http://localhost:3000/api/apps/com.msd.music.player SUCCESS
# http://localhost:3000/api/apps/de.oetker.android.rezeptideen SUCCESS
# http://localhost:3000/api/apps/de.dfbmedien.FussballDE SUCCESS
# http://localhost:3000/api/apps/com.poly.art.coloring.color.by.number SUCCESS
# http://localhost:3000/api/apps/br.com.tecnofit.mobileapp SUCCESS
# http://localhost:3000/api/apps/com.storyshare.jewelrybox SUCCESS
# http://localhost:3000/api/apps/com.alexandriabookseng.book001 SUCCESS
# http://localhost:3000/api/apps/com.doasido4u.jsquiz SUCCESS
# http://localhost:3000/api/apps/ch.energy.dab.rockit SUCCESS
# http://localhost:3000/api/apps/com.beatstech9.nepali066 SUCCESS
# http://localhost:3000/api/apps/aoki.taka.slideshowEX SUCCESS
# http://localhost:3000/api/apps/com.ftt.hwal2.gl.global SUCCESS
# http://localhost:3000/api/apps/air.PHPEditor SUCCESS
# http://localhost:3000/api/apps/conversor.conversaotaxasbasico.usdeur SUCCESS
# http://localhost:3000/api/apps/com.justride.bustang SUCCESS
# http://localhost:3000/api/apps/hr.asseco.android.jimba.mUCI.bl SUCCESS
# http://localhost:3000/api/apps/org.artsplanet.android.sunaoanalogclock SUCCESS
# http://localhost:3000/api/apps/com.kt.ydatabox SUCCESS
# http://localhost:3000/api/apps/com.kingofmyheart.maraholybible SUCCESS
# http://localhost:3000/api/apps/com.goldensoft.saadiinterpretation SUCCESS
# http://localhost:3000/api/apps/com.sobi.yalili SUCCESS
# http://localhost:3000/api/apps/com.tippingcanoe.hukd SUCCESS
# http://localhost:3000/api/apps/hu.bitbaro.bibolka SUCCESS
# http://localhost:3000/api/apps/com.idmobile.italymeteo SUCCESS
# http://localhost:3000/api/apps/com.allinone.jobsinusa SUCCESS
# http://localhost:3000/api/apps/com.hbs.translator.polish.de SUCCESS
# http://localhost:3000/api/apps/com.gamestart.oneline SUCCESS
# http://localhost:3000/api/apps/net.konos.mbtatracker SUCCESS
# http://localhost:3000/api/apps/kz.ertai.namaz SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev567297.app742676 SUCCESS
# http://localhost:3000/api/apps/france.terco.rosario SUCCESS
# http://localhost:3000/api/apps/park.outlook.sign.in.client SUCCESS
# http://localhost:3000/api/apps/com.frenzygames.fgs.uphill.offroad.suv.drive.simulator SUCCESS
# http://localhost:3000/api/apps/et.offline.swahili.bible SUCCESS
# http://localhost:3000/api/apps/admobileapps.koplobnyuwangi FAIL
# http://localhost:3000/api/apps/net.sslo.prodiarypay SUCCESS
# http://localhost:3000/api/apps/de.fu.zedat.EduroamConfig SUCCESS
# http://localhost:3000/api/apps/voto.movies.android.seehd FAIL
# http://localhost:3000/api/apps/com.elmedeen.maktabajibreel SUCCESS
# http://localhost:3000/api/apps/com.genesispure.mobilebackoffice SUCCESS
# http://localhost:3000/api/apps/com.islamicapps.quranbangla SUCCESS
# http://localhost:3000/api/apps/com.anthro.who SUCCESS
# http://localhost:3000/api/apps/com.istudentworld.aiimspreviouspapers SUCCESS
# http://localhost:3000/api/apps/com.ultimateapps.cse SUCCESS
# http://localhost:3000/api/apps/smartwatchstudios.app.gearfit20navigation SUCCESS
# http://localhost:3000/api/apps/com.photo.collage.maker.selfie.editor SUCCESS
# http://localhost:3000/api/apps/com.booksummaries.app SUCCESS
# http://localhost:3000/api/apps/com.oracle.ebs.atg.wf.Approvals SUCCESS
# http://localhost:3000/api/apps/com.fictionmomart.hp.momart SUCCESS
# http://localhost:3000/api/apps/com.superpuperok.dlyrostavolos SUCCESS
# http://localhost:3000/api/apps/com.universe.englishsomalidictionary SUCCESS
# http://localhost:3000/api/apps/uk.uaccount.android SUCCESS
# http://localhost:3000/api/apps/org.czo.badumtsss SUCCESS
# http://localhost:3000/api/apps/com.atsdev.luxurypictureframes SUCCESS
# http://localhost:3000/api/apps/com.imessage.text.ios SUCCESS
# http://localhost:3000/api/apps/com.navyblue.knowledge SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.tiger.night SUCCESS
# http://localhost:3000/api/apps/com.vedant.politician.wastickers SUCCESS
# http://localhost:3000/api/apps/com.aspyr.swkotor SUCCESS
# http://localhost:3000/api/apps/radha_soami.centra.com.radhasoami SUCCESS
# http://localhost:3000/api/apps/com.maxelus.twistedcolorslivewallpaper SUCCESS
# http://localhost:3000/api/apps/com.arabyfree.keyboard SUCCESS
# http://localhost:3000/api/apps/com.getindonesia.customer SUCCESS
# http://localhost:3000/api/apps/com.collectorz.javamobile.android.books SUCCESS
# http://localhost:3000/api/apps/com.gmv.preuniversitario.ucamp SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.sparkle.fairy.butterfly SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev623845.app680204 SUCCESS
# http://localhost:3000/api/apps/com.mycar.passenger SUCCESS
# http://localhost:3000/api/apps/ae.picasso.uaeshowtimes SUCCESS
# http://localhost:3000/api/apps/com.cerebralfix.ninjatobu SUCCESS
# http://localhost:3000/api/apps/com.proapplab.withad4.mycounter SUCCESS
# http://localhost:3000/api/apps/com.cm.samajapp SUCCESS
# http://localhost:3000/api/apps/com.jlaudio.tune SUCCESS
# http://localhost:3000/api/apps/com.mobiblanc.bourse SUCCESS
# http://localhost:3000/api/apps/de.twokit.video.tv.cast.browser.roku SUCCESS
# http://localhost:3000/api/apps/com.nhnent.SKRWBY SUCCESS
# http://localhost:3000/api/apps/com.addismatric.addisshopping SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev696732.app806493 SUCCESS
# http://localhost:3000/api/apps/com.vahancheck SUCCESS
# http://localhost:3000/api/apps/com.shooterswatgame.DiamondRoyal SUCCESS
# http://localhost:3000/api/apps/com.myteammanager SUCCESS
# http://localhost:3000/api/apps/com.gameone.fruittrip SUCCESS
# http://localhost:3000/api/apps/com.dabdaagames.animalsdrawingbeginner SUCCESS
# http://localhost:3000/api/apps/com.tasbeeh.tasbih SUCCESS
# http://localhost:3000/api/apps/com.angelicmiho.lowfodmapdietplanforbeginnersguide SUCCESS
# http://localhost:3000/api/apps/com.ggramm.aquabuilder SUCCESS
# http://localhost:3000/api/apps/com.cometdocs.pdftoword SUCCESS
# http://localhost:3000/api/apps/pixkart.typeface SUCCESS
# http://localhost:3000/api/apps/com.tapcrowd.ikeaeventapp5329 SUCCESS
# http://localhost:3000/api/apps/com.anabolicaliens.exerprise SUCCESS
# http://localhost:3000/api/apps/com.bikinaplikasi.muslimstore2018 SUCCESS
# http://localhost:3000/api/apps/io.vshengur.myappholidays SUCCESS
# http://localhost:3000/api/apps/com.eventbase.vmwareevents SUCCESS
# http://localhost:3000/api/apps/com.balda.bluetask SUCCESS
# http://localhost:3000/api/apps/com.scoreholio.android SUCCESS
# http://localhost:3000/api/apps/me.JR.holybibleAMPCEnglish SUCCESS
# http://localhost:3000/api/apps/jp.co.ciagram.otome.games.hoozukiforeign SUCCESS
# http://localhost:3000/api/apps/com.BorisTouvoli.tresses_et_nattes_africaines SUCCESS
# http://localhost:3000/api/apps/com.tagihan.indihome SUCCESS
# http://localhost:3000/api/apps/com.nippt.shona.free.bible SUCCESS
# http://localhost:3000/api/apps/com.everydaymobi.dailyaffirmations SUCCESS
# http://localhost:3000/api/apps/com.islamic.apps.extremecode.duaeganjalarsh SUCCESS
# http://localhost:3000/api/apps/com.ancestry.android.apps.ancestry SUCCESS
# http://localhost:3000/api/apps/com.ilotte.mc.ilotte SUCCESS
# http://localhost:3000/api/apps/com.app.maxxvoip SUCCESS
# http://localhost:3000/api/apps/com.moodle.coventry SUCCESS
# http://localhost:3000/api/apps/com.yunosolutions.jamaicacalendar SUCCESS
# http://localhost:3000/api/apps/com.chineseinspiration SUCCESS
# http://localhost:3000/api/apps/com.incsoftdev.book06 SUCCESS
# http://localhost:3000/api/apps/com.islamapp.yasenalger SUCCESS
# http://localhost:3000/api/apps/com.telstra.nrl.rabbitohs SUCCESS
# http://localhost:3000/api/apps/com.mizusoft.relaxandsleep SUCCESS
# http://localhost:3000/api/apps/com.goaloo.googleplay SUCCESS
# http://localhost:3000/api/apps/com.disney.datg.videoplatforms.android.abcf SUCCESS
# http://localhost:3000/api/apps/com.satriadev.sholawatyikhadi SUCCESS
# http://localhost:3000/api/apps/com.alhinpost.buzz SUCCESS
# http://localhost:3000/api/apps/com.gabblestudios.boredbutton SUCCESS
# http://localhost:3000/api/apps/com.parker.tubefitter SUCCESS
# http://localhost:3000/api/apps/com.creatorscorp.appusageviewer SUCCESS
# http://localhost:3000/api/apps/com.excelsior.app_frases_amor SUCCESS
# http://localhost:3000/api/apps/com.spanishdict.spanishdict SUCCESS
# http://localhost:3000/api/apps/com.imcbusiness.app SUCCESS
# http://localhost:3000/api/apps/com.feandroyuya.BabyShoesPatternsIdeas SUCCESS
# http://localhost:3000/api/apps/butterflies.neon.colorful.wallpapers.free.hd.backgrounds SUCCESS
# http://localhost:3000/api/apps/com.ghana.songs SUCCESS
# http://localhost:3000/api/apps/com.revesoft.mobiledialer.idial24_1505021112919_20243 SUCCESS
# http://localhost:3000/api/apps/uz.tillo.umsdealer SUCCESS
# http://localhost:3000/api/apps/nh.smart.card SUCCESS
# http://localhost:3000/api/apps/com.oasissolutions.duae.tawassul SUCCESS
# http://localhost:3000/api/apps/com.indihomestudy.app SUCCESS
# http://localhost:3000/api/apps/com.tafayor.hibernator SUCCESS
# http://localhost:3000/api/apps/com.company.ahmetunal.arizatespit SUCCESS
# http://localhost:3000/api/apps/com.hrjohnsonindia.app.johnsontiles SUCCESS
# http://localhost:3000/api/apps/com.pikasapps.cross.wallpapers SUCCESS
# http://localhost:3000/api/apps/com.capshun.co SUCCESS
# http://localhost:3000/api/apps/air.jpmstream SUCCESS
# http://localhost:3000/api/apps/com.midi.stickynoteswidget SUCCESS
# http://localhost:3000/api/apps/com.chillingo.warfriends.android.gplay SUCCESS
# http://localhost:3000/api/apps/com.im30.ROE.gp SUCCESS
# http://localhost:3000/api/apps/com.urbandroid.mind SUCCESS
# http://localhost:3000/api/apps/com.penandink.spoken_english_to_bengali SUCCESS
# http://localhost:3000/api/apps/com.royal_bengal_apps.tafsir_mareful_quran SUCCESS
# http://localhost:3000/api/apps/com.ing.lu.mobile SUCCESS
# http://localhost:3000/api/apps/com.inlogik.promaster.mobile SUCCESS
# http://localhost:3000/api/apps/com.elhorizonteapp SUCCESS
# http://localhost:3000/api/apps/ua.privatbank.ap24jur SUCCESS
# http://localhost:3000/api/apps/com.knighttrans.mobile SUCCESS
# http://localhost:3000/api/apps/com.voice.music.tone.changer.must.have SUCCESS
# http://localhost:3000/api/apps/cleanmaster.phone.memory.booster.cleaner SUCCESS
# http://localhost:3000/api/apps/com.fsu.gameday SUCCESS
# http://localhost:3000/api/apps/com.just4funmobile.duckinphone SUCCESS
# http://localhost:3000/api/apps/ru.rosfines.android SUCCESS
# http://localhost:3000/api/apps/qlnet.com.bbqgo SUCCESS
# http://localhost:3000/api/apps/com.diwan.muhtarifalkhat2 SUCCESS
# http://localhost:3000/api/apps/com.daerisoft.punch SUCCESS
# http://localhost:3000/api/apps/com.snorecare.lilly.snoreAppDemo SUCCESS
# http://localhost:3000/api/apps/com.devolver.downwell SUCCESS
# http://localhost:3000/api/apps/com.gamerguyz.learn.englishin.urdu SUCCESS
# http://localhost:3000/api/apps/com.mtvn.llamaspit SUCCESS
# http://localhost:3000/api/apps/com.phonegap.UP_RERA SUCCESS
# http://localhost:3000/api/apps/com.alidya.Belajar_Baca_Huruf_dan_Angka SUCCESS
# http://localhost:3000/api/apps/com.americasarmy.app.careernavigator SUCCESS
# http://localhost:3000/api/apps/nawakathasitha.com.sandawathi SUCCESS
# http://localhost:3000/api/apps/fat.burnning.plank.fitness.loseweight SUCCESS
# http://localhost:3000/api/apps/com.jamworks.bxlauncher SUCCESS
# http://localhost:3000/api/apps/com.codepur.ssb SUCCESS
# http://localhost:3000/api/apps/com.habyts.agent SUCCESS
# http://localhost:3000/api/apps/free.vpn.unblock.proxy.vpn.master.usavpn SUCCESS
# http://localhost:3000/api/apps/com.music.game.bluesky.fnaf SUCCESS
# http://localhost:3000/api/apps/com.sdgcode.runningcaloriecounter SUCCESS
# http://localhost:3000/api/apps/com.BestPhotoEditor.PhotoCollageEditor SUCCESS
# http://localhost:3000/api/apps/com.alhuda.learnquran SUCCESS
# http://localhost:3000/api/apps/tn.jetmultimedia.tarajimobile SUCCESS
# http://localhost:3000/api/apps/com.cleverapps.magicwords SUCCESS
# http://localhost:3000/api/apps/com.androidarab.dic.english SUCCESS
# http://localhost:3000/api/apps/com.colorfeel.mandalas.coloring SUCCESS
# http://localhost:3000/api/apps/com.oceanhouse_media.bookmulberrystreet_app SUCCESS
# http://localhost:3000/api/apps/com.mdh.vpn5g SUCCESS
# http://localhost:3000/api/apps/com.franciscan.ecare_pro SUCCESS
# http://localhost:3000/api/apps/com.freebasicapp.landscape.leafphotoframes.pv1 SUCCESS
# http://localhost:3000/api/apps/de.materna.bbk.mobile.app SUCCESS
# http://localhost:3000/api/apps/com.quickmobile.h2o16 SUCCESS
# http://localhost:3000/api/apps/com.daryanto.doa.app SUCCESS
# http://localhost:3000/api/apps/com.bestword.challenge.plus SUCCESS
# http://localhost:3000/api/apps/com.aswajacenter.maulidratibhizibwirid SUCCESS
# http://localhost:3000/api/apps/com.fungo.chapelet_joseph SUCCESS
# http://localhost:3000/api/apps/com.ta.mhav SUCCESS
# http://localhost:3000/api/apps/mu.natalie.my SUCCESS
# http://localhost:3000/api/apps/com.amber.launcher.skin.golden.butterfly SUCCESS
# http://localhost:3000/api/apps/com.mbh.azkari SUCCESS
# http://localhost:3000/api/apps/com.ayawalk SUCCESS
# http://localhost:3000/api/apps/com.golfervn.vga.vgagolfer SUCCESS
# http://localhost:3000/api/apps/rds.notes11chemistry SUCCESS
# http://localhost:3000/api/apps/com.sinyee.babybus.custom SUCCESS
# http://localhost:3000/api/apps/com.betterway.adkaratfal.azkar_noum_atfal SUCCESS
# http://localhost:3000/api/apps/com.Good.Morning.Gif SUCCESS
# http://localhost:3000/api/apps/com.elead.fdcrmpro SUCCESS
# http://localhost:3000/api/apps/com.prodigalfatherproductions.examen SUCCESS
# http://localhost:3000/api/apps/com.thunkable.android.niqtaoffice.sanduk2 SUCCESS
# http://localhost:3000/api/apps/com.arlab.verizon1 SUCCESS
# http://localhost:3000/api/apps/pe.com.contadoresyempresas.easylawtributariocontable SUCCESS
# http://localhost:3000/api/apps/org.npr.one SUCCESS
# http://localhost:3000/api/apps/com.homework.demo SUCCESS
# http://localhost:3000/api/apps/com.teliapp.powervolume SUCCESS
# http://localhost:3000/api/apps/nl.jool.isic SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev352756.app527495 SUCCESS
# http://localhost:3000/api/apps/com.mooveit.bancard.mpos SUCCESS
# http://localhost:3000/api/apps/com.securenettech.alder6production SUCCESS
# http://localhost:3000/api/apps/com.roufhapps.hunting.turkeycalls SUCCESS
# http://localhost:3000/api/apps/com.jubileeinsurance.jubileelifeinsurance SUCCESS
# http://localhost:3000/api/apps/com.advasoft.touchretouch SUCCESS
# http://localhost:3000/api/apps/com.mizo.real.gangster.crime.simulator SUCCESS
# http://localhost:3000/api/apps/com.youbitechdz.moshafWarch SUCCESS
# http://localhost:3000/api/apps/com.app.p9860DH SUCCESS
# http://localhost:3000/api/apps/com.golemtechapps.shrimannarayan SUCCESS
# http://localhost:3000/api/apps/com.droidworld.english.visayan.dictionary SUCCESS
# http://localhost:3000/api/apps/com.kr.vrainz.iinnk SUCCESS
# http://localhost:3000/api/apps/com.megafreeapps.all.language.translator.free SUCCESS
# http://localhost:3000/api/apps/com.appdevteambd.mobilebalancetransfer SUCCESS
# http://localhost:3000/api/apps/com.gregschier.toread SUCCESS
# http://localhost:3000/api/apps/com.americaneaglemobile.AEFCU SUCCESS
# http://localhost:3000/api/apps/com.sephora SUCCESS
# http://localhost:3000/api/apps/com.invaluable.auctionzip SUCCESS
# http://localhost:3000/api/apps/com.ofss.fcdb.mobile.android.phone.boc.launcher SUCCESS
# http://localhost:3000/api/apps/im.vector.alpha SUCCESS
# http://localhost:3000/api/apps/com.alexdib.miningpoolmonitor SUCCESS
# http://localhost:3000/api/apps/com.dynamicg.timerecording.pro SUCCESS
# http://localhost:3000/api/apps/com.samwood28 SUCCESS
# http://localhost:3000/api/apps/com.bitexen.exchange SUCCESS
# http://localhost:3000/api/apps/com.CurrentAffairGKHindi.MS SUCCESS
# http://localhost:3000/api/apps/org.kurbo.app SUCCESS
# http://localhost:3000/api/apps/com.shugo.hub SUCCESS
# http://localhost:3000/api/apps/com.americanapps.magnifier SUCCESS
# http://localhost:3000/api/apps/com.ifs.banking.fiid8117 SUCCESS
# http://localhost:3000/api/apps/com.fumbgames.blacksmith SUCCESS
# http://localhost:3000/api/apps/com.appsafs.constituciondelecuador SUCCESS
# http://localhost:3000/api/apps/com.tremendous.ringtones SUCCESS
# http://localhost:3000/api/apps/com.Infinity.puppy SUCCESS
# http://localhost:3000/api/apps/com.cyberlink.powerdirector.DRA140225_01 SUCCESS
# http://localhost:3000/api/apps/com.kic.kicapp SUCCESS
# http://localhost:3000/api/apps/com.wcyiu.tools.scoreboard SUCCESS
# http://localhost:3000/api/apps/com.livephoto.live_wallpaper.realaquarium SUCCESS
# http://localhost:3000/api/apps/com.eneasgesing.radios.am SUCCESS
# http://localhost:3000/api/apps/krok.exam SUCCESS
# http://localhost:3000/api/apps/com.equisense.motions SUCCESS
# http://localhost:3000/api/apps/co.easy.photo.print.walgreens SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.simple.black.glass SUCCESS
# http://localhost:3000/api/apps/com.TheHolyQuranAudio SUCCESS
# http://localhost:3000/api/apps/com.opalastudios.superlaunchpad SUCCESS
# http://localhost:3000/api/apps/fema.moviesfad SUCCESS
# http://localhost:3000/api/apps/kr.co.innoplus.kpopidol.BTS SUCCESS
# http://localhost:3000/api/apps/com.webshinobis.thepurposedrivenlife SUCCESS
# http://localhost:3000/api/apps/com.pakdata.QuranMajeed SUCCESS
# http://localhost:3000/api/apps/com.lexi.android SUCCESS
# http://localhost:3000/api/apps/com.thalia.clock.wallpapers.real.time SUCCESS
# http://localhost:3000/api/apps/com.softtrinity.mxplayer SUCCESS
# http://localhost:3000/api/apps/com.noviaapp.lagusheila0n7 SUCCESS
# http://localhost:3000/api/apps/and.mms.ezhuthani SUCCESS
# http://localhost:3000/api/apps/insult.rude.angry.status.pro SUCCESS
# http://localhost:3000/api/apps/rds.notes12chemistry SUCCESS
# http://localhost:3000/api/apps/gudev.book.foodbeveragesservices SUCCESS
# http://localhost:3000/api/apps/com.jb.gokeyboard.theme.ztpuregold.getjar SUCCESS
# http://localhost:3000/api/apps/bella.bellacleaner SUCCESS
# http://localhost:3000/api/apps/com.subletapp.sublet SUCCESS
# http://localhost:3000/api/apps/com.inditex.ecommerce.zarahome.android SUCCESS
# http://localhost:3000/api/apps/com.english.software.englishanimalsvocabulary SUCCESS
# http://localhost:3000/api/apps/com.giscloud.mdc SUCCESS
# http://localhost:3000/api/apps/com.breeze.ppongcar SUCCESS
# http://localhost:3000/api/apps/ravi.exchange SUCCESS
# http://localhost:3000/api/apps/com.aldakerin.tjweed SUCCESS
# http://localhost:3000/api/apps/com.arora.shivmantra SUCCESS
# http://localhost:3000/api/apps/com.andi.alquran.urdu SUCCESS
# http://localhost:3000/api/apps/smj.khadamat.mobser SUCCESS
# http://localhost:3000/api/apps/hk.easyvan.app.driver2 SUCCESS
# http://localhost:3000/api/apps/com.mobilplug.quicknote SUCCESS
# http://localhost:3000/api/apps/com.code3apps.EMTscenarios SUCCESS
# http://localhost:3000/api/apps/com.BMCE_prod.bad SUCCESS
# http://localhost:3000/api/apps/com.skinsilo.android SUCCESS
# http://localhost:3000/api/apps/com.dpsoriginalz.skinboysnew SUCCESS
# http://localhost:3000/api/apps/com.canersamut.squarepic SUCCESS
# http://localhost:3000/api/apps/com.thegreatkids.flowers_name_kids SUCCESS
# http://localhost:3000/api/apps/com.fiaformulae.formulae SUCCESS
# http://localhost:3000/api/apps/com.thinkerzone.love.gif SUCCESS
# http://localhost:3000/api/apps/com.hm.soft.namaz.surah.audio SUCCESS
# http://localhost:3000/api/apps/com.sense.androidclient SUCCESS
# http://localhost:3000/api/apps/com.zynga.FarmVilleTropicEscape SUCCESS
# http://localhost:3000/api/apps/com.yumkenya SUCCESS
# http://localhost:3000/api/apps/ru.tbankrot.ru SUCCESS
# http://localhost:3000/api/apps/a2z.Mobile.Event5476 SUCCESS
# http://localhost:3000/api/apps/com.ram.lovebirdsphotoframes SUCCESS
# http://localhost:3000/api/apps/com.keesing.android.Arrowword SUCCESS
# http://localhost:3000/api/apps/com.abdul.basit.quran.mp3.islamic SUCCESS
# http://localhost:3000/api/apps/com.viettran.INKrediblePro SUCCESS
# http://localhost:3000/api/apps/tv.stv.android.news SUCCESS
# http://localhost:3000/api/apps/shooter3.bubble SUCCESS
# http://localhost:3000/api/apps/com.innogames.elvenar SUCCESS
# http://localhost:3000/api/apps/com.afromium.amharic.translator SUCCESS
# http://localhost:3000/api/apps/com.funeasylearn.phrasebook.norwegian SUCCESS
# http://localhost:3000/api/apps/com.eagle4ye.muslimlife SUCCESS
# http://localhost:3000/api/apps/com.ssastudio.mukesholdhindisongs SUCCESS
# http://localhost:3000/api/apps/com.sduduzog.slimlauncher SUCCESS
# http://localhost:3000/api/apps/mobi.dailyapps.dataplanng SUCCESS
# http://localhost:3000/api/apps/com.bitgears.rds.discoradio SUCCESS
# http://localhost:3000/api/apps/roloeganga.asky SUCCESS
# http://localhost:3000/api/apps/com.kode4u.khmerhoroscope2 SUCCESS
# http://localhost:3000/api/apps/com.narvii.amino.x17717710 SUCCESS
# http://localhost:3000/api/apps/hr.apps.n1010272 SUCCESS
# http://localhost:3000/api/apps/com.bruyere.android.solitaire SUCCESS
# http://localhost:3000/api/apps/com.autofillwand.mizoramlotteryresult SUCCESS
# http://localhost:3000/api/apps/com.euresults SUCCESS
# http://localhost:3000/api/apps/jp.co.a_tm.android.plus_koubai SUCCESS
# http://localhost:3000/api/apps/co.seekster.android.seeker.production SUCCESS
# http://localhost:3000/api/apps/com.sflpro.inecomobile SUCCESS
# http://localhost:3000/api/apps/clear.sdiary SUCCESS
# http://localhost:3000/api/apps/com.esttp.gasable SUCCESS
# http://localhost:3000/api/apps/com.intothewhitebox.radios.lared SUCCESS
# http://localhost:3000/api/apps/com.parthsofttech.marathidpstatus SUCCESS
# http://localhost:3000/api/apps/com.fis.mobile.android SUCCESS
# http://localhost:3000/api/apps/ru.finam.android SUCCESS
# http://localhost:3000/api/apps/com.mobincube.draw_car_super.sc_DSKTRZ SUCCESS
# http://localhost:3000/api/apps/com.guidebook.apps.UCdavisnow.android SUCCESS
# http://localhost:3000/api/apps/ta.cmi SUCCESS
# http://localhost:3000/api/apps/com.pixcellant.flyingkimchi SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev27966.app197173 SUCCESS
# http://localhost:3000/api/apps/com.appchoose.choose.android SUCCESS
# http://localhost:3000/api/apps/com.dailyword.mlr SUCCESS
# http://localhost:3000/api/apps/com.zdn35.music.songs.audio.workoutmusicforthegymfreeapp SUCCESS
# http://localhost:3000/api/apps/net.ciprianmarin.radio_caracas_Venezuela SUCCESS
# http://localhost:3000/api/apps/com.colorfx.android SUCCESS
# http://localhost:3000/api/apps/id.wilik.android.youtubert SUCCESS
# http://localhost:3000/api/apps/com.fidelity.mobile SUCCESS
# http://localhost:3000/api/apps/com.bytessystem.marutistotram SUCCESS
# http://localhost:3000/api/apps/com.nm.nm SUCCESS
# http://localhost:3000/api/apps/com.converter.phptosar SUCCESS
# http://localhost:3000/api/apps/com.fahima.abdalla3.oumniadev SUCCESS
# http://localhost:3000/api/apps/com.assets.effective.bestussrcartoons SUCCESS
# http://localhost:3000/api/apps/edu.utexas.tacc.token SUCCESS
# http://localhost:3000/api/apps/com.mobileguru.candyfever.free SUCCESS
# http://localhost:3000/api/apps/com.medianet.watania1 SUCCESS
# http://localhost:3000/api/apps/com.klovastudios.wasticker SUCCESS
# http://localhost:3000/api/apps/com.Phone.Photo.Frames.Selfie.Camera SUCCESS
# http://localhost:3000/api/apps/com.luutinhit.smartscreenonoff SUCCESS
# http://localhost:3000/api/apps/com.rehegoo.binauralbeatsdelta SUCCESS
# http://localhost:3000/api/apps/pl.wp.pocztao2 SUCCESS
# http://localhost:3000/api/apps/com.Awesome.wallpaper.awesomepicture.awesomeimage.background.wallpaper SUCCESS
# http://localhost:3000/api/apps/com.Hastamev.WallHubFree SUCCESS
# http://localhost:3000/api/apps/fr.thema.wear.watch.feisar SUCCESS
# http://localhost:3000/api/apps/ai.driveway.insurance SUCCESS
# http://localhost:3000/api/apps/krk.joker.jokerkeyboard SUCCESS
# http://localhost:3000/api/apps/com.adguard.android.contentblocker SUCCESS
# http://localhost:3000/api/apps/style_7.analogclock_7 SUCCESS
# http://localhost:3000/api/apps/com.cdg.traditional.dress.photo.suit SUCCESS
# http://localhost:3000/api/apps/com.exien.sasel SUCCESS
# http://localhost:3000/api/apps/com.makingfun.ironbound SUCCESS
# http://localhost:3000/api/apps/com.energysh.onlinecamera1 SUCCESS
# http://localhost:3000/api/apps/com.golap.hefzquran SUCCESS
# http://localhost:3000/api/apps/com.thriftbooks.mobile SUCCESS
# http://localhost:3000/api/apps/com.goodgif.morning SUCCESS
# http://localhost:3000/api/apps/com.catholicmp3vauls.fultonsheen SUCCESS
# http://localhost:3000/api/apps/intermaps.iskifrance SUCCESS
# http://localhost:3000/api/apps/com.ChrisTowles.RightAngledTriangleSolver SUCCESS
# http://localhost:3000/api/apps/at.bchjoerni.kleinersanitaeter SUCCESS
# http://localhost:3000/api/apps/com.fairyoid.quranplayer5 SUCCESS
# http://localhost:3000/api/apps/com.emberfund.ember SUCCESS
# http://localhost:3000/api/apps/net.phlam.android.clockworktomato SUCCESS
# http://localhost:3000/api/apps/com.att.turbo SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.pastel.galaxy.colors SUCCESS
# http://localhost:3000/api/apps/org.duckdodo.baikoh SUCCESS
# http://localhost:3000/api/apps/com.sonymusic.petta_tamil_movie_songs SUCCESS
# http://localhost:3000/api/apps/com.yovic.oumi.mothersimages SUCCESS
# http://localhost:3000/api/apps/org.aagrapevine.aagrapevinemag SUCCESS
# http://localhost:3000/api/apps/com.dopravo.sp SUCCESS
# http://localhost:3000/api/apps/us.stanwu.screenoff SUCCESS
# http://localhost:3000/api/apps/co.jonathandavies.freespeedometer SUCCESS
# http://localhost:3000/api/apps/com.prisonlab.trifftandroid SUCCESS
# http://localhost:3000/api/apps/org.artsplanet.android.hagemashinyanstamp SUCCESS
# http://localhost:3000/api/apps/com.pavahainc.magicpictureframes SUCCESS
# http://localhost:3000/api/apps/com.usatvradio SUCCESS
# http://localhost:3000/api/apps/com.mobincube.draw_battle_tanks.sc_DXSFF1 SUCCESS
# http://localhost:3000/api/apps/com.mapify SUCCESS
# http://localhost:3000/api/apps/com.peterhohsy.timer555calculator SUCCESS
# http://localhost:3000/api/apps/com.humanaware.ebulksms SUCCESS
# http://localhost:3000/api/apps/de.johanneslauber.android.hue SUCCESS
# http://localhost:3000/api/apps/com.richest.man.babylon SUCCESS
# http://localhost:3000/api/apps/konstraction.myteam SUCCESS
# http://localhost:3000/api/apps/ejoy.learning.english SUCCESS
# http://localhost:3000/api/apps/com.nexstar.id3569new SUCCESS
# http://localhost:3000/api/apps/com.ninetailgames.roguehearts.paid SUCCESS
# http://localhost:3000/api/apps/ir.duck.nanegha SUCCESS
# http://localhost:3000/api/apps/com.viion.binauralbeats SUCCESS
# http://localhost:3000/api/apps/com.veryfit2hr.second SUCCESS
# http://localhost:3000/api/apps/my.pro.imagination.kalam SUCCESS
# http://localhost:3000/api/apps/bcpl.jain SUCCESS
# http://localhost:3000/api/apps/com.hdwcar.newspring SUCCESS
# http://localhost:3000/api/apps/com.wealthsimple SUCCESS
# http://localhost:3000/api/apps/jfs.InvestigaCoches SUCCESS
# http://localhost:3000/api/apps/com.kitoved.skmine.manskinsforminecraft SUCCESS
# http://localhost:3000/api/apps/com.datamovil.datamovil SUCCESS
# http://localhost:3000/api/apps/ru.otkritkiok.pozdravleniya SUCCESS
# http://localhost:3000/api/apps/com.gowebia.aptitudereasoningtricks SUCCESS
# http://localhost:3000/api/apps/com.happay.android.v2 SUCCESS
# http://localhost:3000/api/apps/com.myzap.bhgre SUCCESS
# http://localhost:3000/api/apps/com.cobaltsign.readysetholiday SUCCESS
# http://localhost:3000/api/apps/com.mezistudios.rokia_ain_hassad SUCCESS
# http://localhost:3000/api/apps/com.dwidasa.bpdbali.mb.android SUCCESS
# http://localhost:3000/api/apps/com.aaglodapps.lawsofpower48 SUCCESS
# http://localhost:3000/api/apps/com.rsoft.cutecat.hdwallpapers SUCCESS
# http://localhost:3000/api/apps/com.tradetu.bhagavadgita.quotes SUCCESS
# http://localhost:3000/api/apps/com.biquettestudio.neotravelyourmind SUCCESS
# http://localhost:3000/api/apps/com.collagestudioapps.relaxing.sound SUCCESS
# http://localhost:3000/api/apps/com.king.candycrush4 SUCCESS
# http://localhost:3000/api/apps/com.MindBlossom.WorldTreeVIP SUCCESS
# http://localhost:3000/api/apps/com.jituhasan.al_koraan SUCCESS
# http://localhost:3000/api/apps/com.alexandre.oliveira.meutimeapp SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev680484.app796936 SUCCESS
# http://localhost:3000/api/apps/com.kaspersky.passwordmanager SUCCESS
# http://localhost:3000/api/apps/com.passport.mobile.parkright SUCCESS
# http://localhost:3000/api/apps/com.perintissoft.math4sd SUCCESS
# http://localhost:3000/api/apps/com.tymate.domyos.connected SUCCESS
# http://localhost:3000/api/apps/com.amtgames.ewtd2 SUCCESS
# http://localhost:3000/api/apps/utel.gold SUCCESS
# http://localhost:3000/api/apps/com.goodperson.paintandwrite SUCCESS
# http://localhost:3000/api/apps/fr.cnamts.it.activity SUCCESS
# http://localhost:3000/api/apps/jp.smarteducation.tofusushi SUCCESS
# http://localhost:3000/api/apps/vina.pod2.friday SUCCESS
# http://localhost:3000/api/apps/ua.rusradio.app SUCCESS
# http://localhost:3000/api/apps/eg.com.qnb.eazymobile SUCCESS
# http://localhost:3000/api/apps/fr.digitalproximity.secretsdeparis SUCCESS
# http://localhost:3000/api/apps/com.revogi.delite SUCCESS
# http://localhost:3000/api/apps/wan.app.kbo SUCCESS
# http://localhost:3000/api/apps/ca.diabetes.guidelines.cpg SUCCESS
# http://localhost:3000/api/apps/com.navixy.xgps.client.app SUCCESS
# http://localhost:3000/api/apps/com.alideveloper7.hamasea1 SUCCESS
# http://localhost:3000/api/apps/postales.amor.sanvalentin SUCCESS
# http://localhost:3000/api/apps/nl.imin SUCCESS
# http://localhost:3000/api/apps/com.evamuchtar.abc.muslim_book SUCCESS
# http://localhost:3000/api/apps/com.krazeapps.kotlinprogrammingcompiler SUCCESS
# http://localhost:3000/api/apps/com.sabyan.remix.sholawat.chayrilapp SUCCESS
# http://localhost:3000/api/apps/com.lory.HiddenObjects.MagicLandHiddenObjectsGameWizardWorld.SeekAndFindGamesFree SUCCESS
# http://localhost:3000/api/apps/button.urss.anthem.communism.hymn SUCCESS
# http://localhost:3000/api/apps/com.h2osystech.smartalimi.servicealimi.IMeritzService SUCCESS
# http://localhost:3000/api/apps/com.impp.truck.simulator.rescueexcavator SUCCESS
# http://localhost:3000/api/apps/com.outplayentertainment.castlecreepstd SUCCESS
# http://localhost:3000/api/apps/labonneaventure.venus_voyance SUCCESS
# http://localhost:3000/api/apps/com.abba.lmeallem SUCCESS
# http://localhost:3000/api/apps/com.markate.markatepro SUCCESS
# http://localhost:3000/api/apps/com.imeji.trot SUCCESS
# http://localhost:3000/api/apps/com.phonevalley.progressive SUCCESS
# http://localhost:3000/api/apps/com.tabtale.hotdoghero SUCCESS
# http://localhost:3000/api/apps/com.mement.word SUCCESS
# http://localhost:3000/api/apps/com.drpanda.city2 SUCCESS
# http://localhost:3000/api/apps/com.plumamazing.iwatermark SUCCESS
# http://localhost:3000/api/apps/uep.mallorca SUCCESS
# http://localhost:3000/api/apps/com.pixel.coloring.color.by.number SUCCESS
# http://localhost:3000/api/apps/com.merojob.merojobapp SUCCESS
# http://localhost:3000/api/apps/com.ifs.banking.fiid3539 SUCCESS
# http://localhost:3000/api/apps/pe.codespace.cpch SUCCESS
# http://localhost:3000/api/apps/com.colehaan.android SUCCESS
# http://localhost:3000/api/apps/com.kahvedunyasi.app SUCCESS
# http://localhost:3000/api/apps/org.blokada.alarm.dnschanger SUCCESS
# http://localhost:3000/api/apps/com.vsoft.crosswallpapers SUCCESS
# http://localhost:3000/api/apps/com.ibyteapps.sobertoday SUCCESS
# http://localhost:3000/api/apps/soo.util.uninstall SUCCESS
# http://localhost:3000/api/apps/com.evsoft.frames.love1 SUCCESS
# http://localhost:3000/api/apps/com.butacapremium.play SUCCESS
# http://localhost:3000/api/apps/com.ChristianLiveWallpaperApp SUCCESS
# http://localhost:3000/api/apps/com.izapps.gombalangokil SUCCESS
# http://localhost:3000/api/apps/com.ups.mobile.android SUCCESS
# http://localhost:3000/api/apps/org.mapapps.mapyourtown.uae SUCCESS
# http://localhost:3000/api/apps/com.myadridev.mypocketcave SUCCESS
# http://localhost:3000/api/apps/com.davidgiga1993.mixingstation SUCCESS
# http://localhost:3000/api/apps/com.first.shanu.aleconomicpapers SUCCESS
# http://localhost:3000/api/apps/com.xs.pooltd SUCCESS
# http://localhost:3000/api/apps/ru.yandex.taxi SUCCESS
# http://localhost:3000/api/apps/app.supremecommunity.android SUCCESS
# http://localhost:3000/api/apps/com.tadaoyamaoka.vocalpitchmonitor SUCCESS
# http://localhost:3000/api/apps/com.swg.andrea.auriga SUCCESS
# http://localhost:3000/api/apps/com.ninexgen.cleaner SUCCESS
# http://localhost:3000/api/apps/vikrams.Inspirations SUCCESS
# http://localhost:3000/api/apps/com.Infinity.anchor SUCCESS
# http://localhost:3000/api/apps/com.alivemedia.hkgrn SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.neon.wolf.galaxy SUCCESS
# http://localhost:3000/api/apps/net.shalafi.android.mtg.free SUCCESS
# http://localhost:3000/api/apps/com.arkea.android.application.cmb SUCCESS
# http://localhost:3000/api/apps/com.armorgames.sodadungeon SUCCESS
# http://localhost:3000/api/apps/com.azwstudios.theholybible.em SUCCESS
# http://localhost:3000/api/apps/com.quoord.tapatalkxdapre.activity SUCCESS
# http://localhost:3000/api/apps/com.mobint.hololauncher SUCCESS
# http://localhost:3000/api/apps/com.learningappchinese SUCCESS
# http://localhost:3000/api/apps/com.at.ewalk.free SUCCESS
# http://localhost:3000/api/apps/com.music.rai.sudan SUCCESS
# http://localhost:3000/api/apps/com.csod.mobile.CSOD SUCCESS
# http://localhost:3000/api/apps/biart.com.flashlight SUCCESS
# http://localhost:3000/api/apps/com.skyunion.android.keeplock SUCCESS
# http://localhost:3000/api/apps/com.tachibyte.timeflow SUCCESS
# http://localhost:3000/api/apps/org.marqoom.adorAlmokhtarWaHasyatEbnAbdeen SUCCESS
# http://localhost:3000/api/apps/concordancia.biblica.brasil SUCCESS
# http://localhost:3000/api/apps/com.odoo.mobile SUCCESS
# http://localhost:3000/api/apps/an.UkraineRadio SUCCESS
# http://localhost:3000/api/apps/com.iabuzz.Robot SUCCESS
# http://localhost:3000/api/apps/net.manhajona.Sourat_Al_Baqara SUCCESS
# http://localhost:3000/api/apps/com.geonotes.fieldnotesproidfree SUCCESS
# http://localhost:3000/api/apps/com.Best.Catholic.App.Mp3.Doa.Rosario.Katolik.Audio.offline SUCCESS
# http://localhost:3000/api/apps/com.narvii.amino.x23 SUCCESS
# http://localhost:3000/api/apps/com.studioraudhah.surahyasin SUCCESS
# http://localhost:3000/api/apps/com.playdigious.whitenight SUCCESS
# http://localhost:3000/api/apps/com.synovus.mobilebanking SUCCESS
# http://localhost:3000/api/apps/com.uffizio.trakzee SUCCESS
# http://localhost:3000/api/apps/com.mmb.kwenoffers SUCCESS
# http://localhost:3000/api/apps/com.penguinsofeware.namegenerator SUCCESS
# http://localhost:3000/api/apps/mobi.abcmousemv.academy_goo SUCCESS
# http://localhost:3000/api/apps/com.bibleseuropean2 SUCCESS
# http://localhost:3000/api/apps/com.HahnFilm.MiaAndMe.FreeTheUnicorns SUCCESS
# http://localhost:3000/api/apps/com.voxy.news SUCCESS
# http://localhost:3000/api/apps/com.locknlockmall SUCCESS
# http://localhost:3000/api/apps/com.argenti.rerinfo SUCCESS
# http://localhost:3000/api/apps/com.tudorspan.recipekeeper SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev750372.app905545 SUCCESS
# http://localhost:3000/api/apps/com.peakpocketstudios.atmospherebinauraltherapy SUCCESS
# http://localhost:3000/api/apps/com.armondev.resepkue SUCCESS
# http://localhost:3000/api/apps/com.thennakam.tettamil SUCCESS
# http://localhost:3000/api/apps/videogames.news.braindevs.com.tempproject SUCCESS
# http://localhost:3000/api/apps/com.innovecto.etalastic SUCCESS
# http://localhost:3000/api/apps/com.neygavets.livewallpaper.poppies SUCCESS
# http://localhost:3000/api/apps/com.ahlayc.mahnaati.tibi SUCCESS
# http://localhost:3000/api/apps/vivdh.bhartriandair SUCCESS
# http://localhost:3000/api/apps/appgreetingsimagecom.wpapp SUCCESS
# http://localhost:3000/api/apps/com.multibrains.taxi.driver.ridepassengeret SUCCESS
# http://localhost:3000/api/apps/com.macropinch.axe SUCCESS
# http://localhost:3000/api/apps/ru.dailymistika.runeoftheday SUCCESS
# http://localhost:3000/api/apps/uy.com.itau.pagocuentas SUCCESS
# http://localhost:3000/api/apps/com.com2us.golfstarworldtour.normal.freefull.google.global.android.common SUCCESS
# http://localhost:3000/api/apps/edu.uoregon.UO360 SUCCESS
# http://localhost:3000/api/apps/com.visualit.tubeLondonCity SUCCESS
# http://localhost:3000/api/apps/com.quranoffline.quranmajeed.ahmedmohamedtaher SUCCESS
# http://localhost:3000/api/apps/com.mohameedsalah.Grammer SUCCESS
# http://localhost:3000/api/apps/com.bitmango.go.wordcookiescross SUCCESS
# http://localhost:3000/api/apps/com.kudsi40ru.zopoz.com SUCCESS
# http://localhost:3000/api/apps/com.ssafitness.flatstomachworkout SUCCESS
# http://localhost:3000/api/apps/com.revesoft.mobiledialer.hello_india_1537089273569_73683 SUCCESS
# http://localhost:3000/api/apps/shivam.desi_upchar SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev597108.app927161 SUCCESS
# http://localhost:3000/api/apps/com.migueladangn.blocknotas SUCCESS
# http://localhost:3000/api/apps/com.hoc.tieng.han.test.bai.tap SUCCESS
# http://localhost:3000/api/apps/com.bmksservices.flowersphotoframeshd SUCCESS
# http://localhost:3000/api/apps/com.rudranshiapps.shivaringtones SUCCESS
# http://localhost:3000/api/apps/com.lapp.nsw.heavyrigid.demo SUCCESS
# http://localhost:3000/api/apps/com.bigartwall.mobile SUCCESS
# http://localhost:3000/api/apps/com.english.learnword SUCCESS
# http://localhost:3000/api/apps/com.ipek.biletall SUCCESS
# http://localhost:3000/api/apps/rnr.tlnbuss SUCCESS
# http://localhost:3000/api/apps/com.braveglobalsolutions.whatsappstatussaver SUCCESS
# http://localhost:3000/api/apps/com.incometax.efilling.tds.tax FAIL
# http://localhost:3000/api/apps/com.bt.bms SUCCESS
# http://localhost:3000/api/apps/nz.co.radionz.android SUCCESS
# http://localhost:3000/api/apps/zw.co.mobility.drive SUCCESS
# http://localhost:3000/api/apps/com.Zona.Wayang.Kulit.Mp3.Seno.Nugroho.Semar.Mbangun.Kahyangan.Audio.Offline SUCCESS
# http://localhost:3000/api/apps/com.worldlease.wlsom SUCCESS
# http://localhost:3000/api/apps/de.eos.uptrade.android.fahrinfo.berlin SUCCESS
# http://localhost:3000/api/apps/com.jiubang.gosms.wallpaperplugin SUCCESS
# http://localhost:3000/api/apps/io.raindrop.raindropio SUCCESS
# http://localhost:3000/api/apps/com.marcoaltomonte.bikemimap SUCCESS
# http://localhost:3000/api/apps/com.droidmentor.turban_pathan_afghan.balochi_panjabi_sardar_photo_editor SUCCESS
# http://localhost:3000/api/apps/com.b3g.cih.wepay SUCCESS
# http://localhost:3000/api/apps/com.ultimatevideoapp.haryanavisongs SUCCESS
# http://localhost:3000/api/apps/cat.joanpujol.eltemps.android.uk SUCCESS
# http://localhost:3000/api/apps/com.subsplashconsulting.s_NBKDPS SUCCESS
# http://localhost:3000/api/apps/com.urbanmap.istanbul SUCCESS
# http://localhost:3000/api/apps/com.kme.cellotuner SUCCESS
# http://localhost:3000/api/apps/com.newgenerationapps.ImagenesBonitasParaPerfil SUCCESS
# http://localhost:3000/api/apps/com.turbocms.mindmap.todolist.todomaps SUCCESS
# http://localhost:3000/api/apps/com.sedevelop.dict.entagalogfl.free SUCCESS
# http://localhost:3000/api/apps/com.colonybank.mobile SUCCESS
# http://localhost:3000/api/apps/gr.viva.vivagr SUCCESS
# http://localhost:3000/api/apps/money.com.e_magazine SUCCESS
# http://localhost:3000/api/apps/com.dwrandaz.hazhirdictionary SUCCESS
# http://localhost:3000/api/apps/kr.co.momhoney SUCCESS
# http://localhost:3000/api/apps/com.UApps.Palmistry.HathKiLakeer SUCCESS
# http://localhost:3000/api/apps/com.fansided.tomahawktake SUCCESS
# http://localhost:3000/api/apps/com.popcore.foldingblocks SUCCESS
# http://localhost:3000/api/apps/com.bharati.radio.india SUCCESS
# http://localhost:3000/api/apps/com.softek.ofxclmobile.northernfcu SUCCESS
# http://localhost:3000/api/apps/com.bikinaplikasi.nurstorebatam SUCCESS
# http://localhost:3000/api/apps/com.visanet.visaapp2 SUCCESS
# http://localhost:3000/api/apps/com.consultali.izitime SUCCESS
# http://localhost:3000/api/apps/com.catcolorbynumber.pixelartcoloringpages SUCCESS
# http://localhost:3000/api/apps/io.dvlt.blaze SUCCESS
# http://localhost:3000/api/apps/com.amarcokolatos.AplikasiAndroidBelajarBahasaJepangSehariHari SUCCESS
# http://localhost:3000/api/apps/com.baslanapps.hijricalendar SUCCESS
# http://localhost:3000/api/apps/com.launchpadappsworld.grammersikhohindime SUCCESS
# http://localhost:3000/api/apps/com.poolchemicalcalculator.poolcalc SUCCESS
# http://localhost:3000/api/apps/com.mmohamedy.mowhhiy.aganey SUCCESS
# http://localhost:3000/api/apps/learnerapp.dictionary.english SUCCESS
# http://localhost:3000/api/apps/aero.com.koenawin SUCCESS
# http://localhost:3000/api/apps/com.fevdev.nakedbrowser SUCCESS
# http://localhost:3000/api/apps/com.allnewspaper.kuwaitnewspaper SUCCESS
# http://localhost:3000/api/apps/air.com.winkypinky.princesshorsecaring SUCCESS
# http://localhost:3000/api/apps/com.app.nirantharanews SUCCESS
# http://localhost:3000/api/apps/com.nckk.myanmarzodiac SUCCESS
# http://localhost:3000/api/apps/com.dola.workout SUCCESS
# http://localhost:3000/api/apps/com.rt.qpay99 SUCCESS
# http://localhost:3000/api/apps/com.subsplashconsulting.s_58XN8B SUCCESS
# http://localhost:3000/api/apps/com.biika.historylove SUCCESS
# http://localhost:3000/api/apps/com.bastous.good_morning.stickers SUCCESS
# http://localhost:3000/api/apps/com.unbound.android.ubnc2l SUCCESS
# http://localhost:3000/api/apps/ca.eastcoastcu.mobileapp SUCCESS
# http://localhost:3000/api/apps/com.kabam.newcnhoc SUCCESS
# http://localhost:3000/api/apps/com.mobile.android.grptalk SUCCESS
# http://localhost:3000/api/apps/com.king.studio.arirangkaraokelist SUCCESS
# ...
# http://localhost:3000/api/apps/nl.snappcar.app SUCCESS
# http://localhost:3000/api/apps/com.pitchero.manager SUCCESS
# http://localhost:3000/api/apps/com.lightdotnet.digitalclock SUCCESS
# http://localhost:3000/api/apps/com.fi9940.godough SUCCESS
# http://localhost:3000/api/apps/com.apps23.heartrate SUCCESS
# http://localhost:3000/api/apps/com.free.fast.master.unblock.proxy.vpn SUCCESS
# http://localhost:3000/api/apps/vadb.hht.de.hamburgvadb SUCCESS
# http://localhost:3000/api/apps/com.indoriapps.asmHindi SUCCESS
# http://localhost:3000/api/apps/com.mifthi.mayyith.niskaram SUCCESS
# http://localhost:3000/api/apps/com.hearst.android.wlky SUCCESS
# http://localhost:3000/api/apps/com.x21Techis.IPay SUCCESS
# http://localhost:3000/api/apps/com.visiotech.duroodsalam SUCCESS
# http://localhost:3000/api/apps/com.wordboxmalawiRadio SUCCESS
# http://localhost:3000/api/apps/com.cootek.smartinputv5.font.alice_regular SUCCESS
# http://localhost:3000/api/apps/com.Cute.KawaiiStickers.PhotoEditor.For.Girls SUCCESS
# http://localhost:3000/api/apps/com.sandboxol.indiegame.hideandseek SUCCESS
# http://localhost:3000/api/apps/com.safari.pipcameraeffect.app SUCCESS
# http://localhost:3000/api/apps/vn.soft.batterydoctor.batterysaver SUCCESS
# http://localhost:3000/api/apps/net.jandaya.vrbsqrtenfrfree SUCCESS
# http://localhost:3000/api/apps/typo.swipe.type.curve SUCCESS
# http://localhost:3000/api/apps/com.poppin_games.peterrabbit_hog SUCCESS
# http://localhost:3000/api/apps/gs.envios.app.mx SUCCESS
# http://localhost:3000/api/apps/pl.zabka.apb2c SUCCESS
# http://localhost:3000/api/apps/com.mobincube.estudios_biblicos_para_mujeres.sc_3NEWWR SUCCESS
# http://localhost:3000/api/apps/com.fidelity.android SUCCESS
# http://localhost:3000/api/apps/com.tukanajans.soundboard.freddy SUCCESS
# http://localhost:3000/api/apps/jp.co.a_tm.android.plus_golden_owl SUCCESS
# http://localhost:3000/api/apps/com.fi6254.godough SUCCESS
# http://localhost:3000/api/apps/silverbeach.rbleipzigsupport SUCCESS
# http://localhost:3000/api/apps/com.swordisme.tracks.mhd SUCCESS
# http://localhost:3000/api/apps/im.johngalt.selvi SUCCESS
# http://localhost:3000/api/apps/com.ram.babyphotoframes SUCCESS
# http://localhost:3000/api/apps/com.voixme.d4d SUCCESS
# http://localhost:3000/api/apps/com.alphainventor.plugin.fileuri SUCCESS
# http://localhost:3000/api/apps/com.kittoboy.repeatalarm SUCCESS
# http://localhost:3000/api/apps/com.E.L.I.lab.dev3939.andapps058 SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev663676.app799404 SUCCESS
# http://localhost:3000/api/apps/pe.com.scotiabank.blpm.android.client SUCCESS
# http://localhost:3000/api/apps/jediarstudios.pubgmct SUCCESS
# http://localhost:3000/api/apps/com.max.optimizer.batterysaver SUCCESS
# http://localhost:3000/api/apps/team.parkmobile.android.client SUCCESS
# http://localhost:3000/api/apps/com.lguplus.fivewidget SUCCESS
# http://localhost:3000/api/apps/tartil.quran.parhizgar SUCCESS
# http://localhost:3000/api/apps/md.insights.ort.rsp SUCCESS
# http://localhost:3000/api/apps/com.carrot.horror SUCCESS
# http://localhost:3000/api/apps/com.ImaginaryTech.TafsirIbnKaseerUrdu SUCCESS
# http://localhost:3000/api/apps/com.matchpointgps.app SUCCESS
# http://localhost:3000/api/apps/com.bts.jungkook.kpop.livewallpaper.pro SUCCESS
# http://localhost:3000/api/apps/com.app.p5277EH SUCCESS
# http://localhost:3000/api/apps/com.krackit.dhruva.moh SUCCESS
# http://localhost:3000/api/apps/com.pocketprep.nclexrn SUCCESS
# http://localhost:3000/api/apps/com.streann.majestad_go SUCCESS
# http://localhost:3000/api/apps/horario.salat.adan.espana SUCCESS
# http://localhost:3000/api/apps/com.portugese.innepal SUCCESS
# http://localhost:3000/api/apps/com.zephyrzonestudios.lessonsinlifequotes SUCCESS
# http://localhost:3000/api/apps/com.oracle.obi SUCCESS
# http://localhost:3000/api/apps/com.spotterlook.driverstartin SUCCESS
# http://localhost:3000/api/apps/bvm.bvmapp SUCCESS
# http://localhost:3000/api/apps/com.seenit.hsbcnow SUCCESS
# http://localhost:3000/api/apps/com.gamooz.gyanadhigam SUCCESS
# http://localhost:3000/api/apps/com.mobirate.rovercraft.gplay SUCCESS
# http://localhost:3000/api/apps/com.tinashe.bible SUCCESS
# http://localhost:3000/api/apps/com.bayteq.loja.bancamovil SUCCESS
# http://localhost:3000/api/apps/com.tgs.MultiSpiderRobot.AmazingSpider.GrandRobotBattle SUCCESS
# http://localhost:3000/api/apps/com.cadmiumcd.aorn2019 SUCCESS
# http://localhost:3000/api/apps/com.apgems.americanenglishstory SUCCESS
# http://localhost:3000/api/apps/ysh.nursery.songsaudio SUCCESS
# http://localhost:3000/api/apps/in.softecks.sixsigma SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev660523.app843901 SUCCESS
# http://localhost:3000/api/apps/se.sweetstone.yatzy SUCCESS
# http://localhost:3000/api/apps/com.ionicframework.bhajansangrah776952 SUCCESS
# http://localhost:3000/api/apps/com.tmmmt.tmmmtpartners SUCCESS
# http://localhost:3000/api/apps/com.geekbuy.geekbuying SUCCESS
# http://localhost:3000/api/apps/com.maximebertheau.uninstaller SUCCESS
# http://localhost:3000/api/apps/com.news.bbcnews SUCCESS
# http://localhost:3000/api/apps/com.noticesoftware.FanSided SUCCESS
# http://localhost:3000/api/apps/com.kwad.chime SUCCESS
# http://localhost:3000/api/apps/com.cellartracker.app SUCCESS
# http://localhost:3000/api/apps/co.easy4u.writer SUCCESS
# http://localhost:3000/api/apps/com.dunamu.trading SUCCESS
# http://localhost:3000/api/apps/com.app.basso.ternium SUCCESS
# http://localhost:3000/api/apps/com.prokrite.android.doctor SUCCESS
# http://localhost:3000/api/apps/com.la.tragedie.des.siecles.ellen.white SUCCESS
# http://localhost:3000/api/apps/com.Avni.Vestig.SupplementsC SUCCESS
# http://localhost:3000/api/apps/easter.live.wallpaper SUCCESS
# http://localhost:3000/api/apps/com.blablacast.radio SUCCESS
# http://localhost:3000/api/apps/com.hamada.abasiya.bahadev SUCCESS
# http://localhost:3000/api/apps/com.g5e.twinmoonspg.android SUCCESS
# http://localhost:3000/api/apps/com.ilovepapa.kokkoksl SUCCESS
# http://localhost:3000/api/apps/com.doublerouble.counter SUCCESS
# http://localhost:3000/api/apps/com.mobilepioneers.tvgidstv SUCCESS
# http://localhost:3000/api/apps/com.intervale.sendme SUCCESS
# http://localhost:3000/api/apps/com.offline.ocr.english.image.to.text SUCCESS
# http://localhost:3000/api/apps/com.fong.yoong.kamusbmprpm SUCCESS
# http://localhost:3000/api/apps/com.fasterthanmonkeys.iscore SUCCESS
# http://localhost:3000/api/apps/nl.routit.iam.android SUCCESS
# http://localhost:3000/api/apps/com.newverstheSMSBonneNuit.meiilleurNuitromantique SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.thunder.neon.lights SUCCESS
# http://localhost:3000/api/apps/com.electronicbugdetector.bugdetectorscanner SUCCESS
# http://localhost:3000/api/apps/com.honestbee.consumer SUCCESS
# http://localhost:3000/api/apps/com.easemytrip.android.b2b SUCCESS
# http://localhost:3000/api/apps/mobile.visuals.hypnotic.mandala SUCCESS
# http://localhost:3000/api/apps/com.ucare.we SUCCESS
# http://localhost:3000/api/apps/de.rodemerk.vocabulary_trainer SUCCESS
# http://localhost:3000/api/apps/sleepsounds.relaxandsleep.whitenoise SUCCESS
# http://localhost:3000/api/apps/com.CU.cinesunidosAndroid SUCCESS
# http://localhost:3000/api/apps/com.allringtone.lordram.ringtone SUCCESS
# http://localhost:3000/api/apps/com.scottish.news SUCCESS
# http://localhost:3000/api/apps/it.purplepixel.planetaryhours SUCCESS
# http://localhost:3000/api/apps/com.jankari.apps.medihand SUCCESS
# http://localhost:3000/api/apps/com.ionic.soaringsafe SUCCESS
# http://localhost:3000/api/apps/com.goodbarber.coranethadiths SUCCESS
# http://localhost:3000/api/apps/com.futureapps.banglanewspapers SUCCESS
# http://localhost:3000/api/apps/com.rtaapps.askforalexa SUCCESS
# http://localhost:3000/api/apps/com.creditfreedomapp SUCCESS
# http://localhost:3000/api/apps/com.tebakgambar SUCCESS
# http://localhost:3000/api/apps/sk.markiza.videoarchiv.other SUCCESS
# http://localhost:3000/api/apps/com.bbc.heyduggeetinselbadgeapp SUCCESS
# http://localhost:3000/api/apps/com.hssmartfreeapps.ramspeedbooster.ramcleaner SUCCESS
# http://localhost:3000/api/apps/com.itworx.teacherkitstudent SUCCESS
# http://localhost:3000/api/apps/black.orange.textwith.smoke.effect.corner SUCCESS
# http://localhost:3000/api/apps/de.mobileconcepts.cyberghost SUCCESS
# http://localhost:3000/api/apps/academia.bracu.com.academia SUCCESS
# http://localhost:3000/api/apps/com.lasri.shemaelectrique_fr SUCCESS
# http://localhost:3000/api/apps/com.deerlabs.kilo SUCCESS
# http://localhost:3000/api/apps/com.fascard.mobile SUCCESS
# http://localhost:3000/api/apps/com.hthworldwide.GeoBlue SUCCESS
# http://localhost:3000/api/apps/com.eyewitnessnewsbahamas.android SUCCESS
# http://localhost:3000/api/apps/com.playermusic.musicplayerapp SUCCESS
# http://localhost:3000/api/apps/ma.babaliste SUCCESS
# http://localhost:3000/api/apps/com.trendapps.mirror.photoreflectioneditor SUCCESS
# http://localhost:3000/api/apps/com.hdwcar.god150818 SUCCESS
# http://localhost:3000/api/apps/com.cardgame.solitaire.fishdom SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev352756.app465179 SUCCESS
# http://localhost:3000/api/apps/com.solangi.shahjorisalosindhi SUCCESS
# http://localhost:3000/api/apps/com.dhn.tattoo.photo SUCCESS
# http://localhost:3000/api/apps/nu.area.measurement SUCCESS
# http://localhost:3000/api/apps/com.mrgreensoft.nrg.player SUCCESS
# http://localhost:3000/api/apps/jp.dip.muracoro.comitton SUCCESS
# http://localhost:3000/api/apps/com.appstrend.policerobot.speedster.hero SUCCESS
# http://localhost:3000/api/apps/com.elds.com SUCCESS
# http://localhost:3000/api/apps/at.spardat.bcrmobile SUCCESS
# http://localhost:3000/api/apps/com.americanwell.android.member.clevelandclinic SUCCESS
# http://localhost:3000/api/apps/com.enarmpas.pdf.elzahir SUCCESS
# http://localhost:3000/api/apps/com.spinmaster.boxer SUCCESS
# http://localhost:3000/api/apps/com.wring.android.truehb SUCCESS
# http://localhost:3000/api/apps/com.futureplay.boots SUCCESS
# http://localhost:3000/api/apps/com.mm.android.direct.gdmsspadLite SUCCESS
# http://localhost:3000/api/apps/th.co.muangthai.android.smileservice SUCCESS
# http://localhost:3000/api/apps/com.whisperarts.kidsshell SUCCESS
# http://localhost:3000/api/apps/com.neighbfav.neighborfavor.runner SUCCESS
# http://localhost:3000/api/apps/app.neterra.tv SUCCESS
# http://localhost:3000/api/apps/com.nomadeducation.bacs SUCCESS
# http://localhost:3000/api/apps/com.applicality.mobiletopographergis SUCCESS
# http://localhost:3000/api/apps/dev.redfmdigital.android.redfm SUCCESS
# http://localhost:3000/api/apps/com.ImaginaryTech.SurahArRahman SUCCESS
# http://localhost:3000/api/apps/anasun.magnifier SUCCESS
# http://localhost:3000/api/apps/com.helpfullapps.rtovehicleinformationapp.vehicleregistrationdetails SUCCESS
# http://localhost:3000/api/apps/com.wegow.wegow SUCCESS
# http://localhost:3000/api/apps/com.b7apps.downloader SUCCESS
# http://localhost:3000/api/apps/com.minube.guides.vienna SUCCESS
# http://localhost:3000/api/apps/com.swd.edeeremit SUCCESS
# http://localhost:3000/api/apps/com.madinsweden.sleeptalk SUCCESS
# http://localhost:3000/api/apps/com.icsfs.safwa SUCCESS
# http://localhost:3000/api/apps/com.gootax.asian SUCCESS
# http://localhost:3000/api/apps/com.theunderbelly SUCCESS
# http://localhost:3000/api/apps/com.SoftBeatSoft.Social_Network SUCCESS
# http://localhost:3000/api/apps/com.arifchereta SUCCESS
# http://localhost:3000/api/apps/coffee.cup.art.beans.lwp SUCCESS
# http://localhost:3000/api/apps/com.icemobile.brightstamps.alfamart SUCCESS
# http://localhost:3000/api/apps/com.tencent.ig SUCCESS
# http://localhost:3000/api/apps/com.bravolol.bravolang.englishchinesecdictionary SUCCESS
# http://localhost:3000/api/apps/com.pavahainc.cyborgcameraphotoeditor
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-340508701d46> in <module>()
#       2 for url in waiting_urls:
#       3     print(url, end=" ")
# ----> 4     response = requests.get(url)
#       5     if response.status_code == 200:
#       6         print("SUCCESS")
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     443                     decode_content=False,
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#     447
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Out:
# 99513
